# %% [markdown]
# # Yahooニュースのスクレイピング
# 今回はYahooニュースのスクレイピングを行いました。
# データ取得・分析に役立てていただきたく、今回構築した関数を紹介します！
# ### 必要な知識
# Python
# BeautifulSoup

# %%
import requests
from bs4 import BeautifulSoup
import re
import itertools
import pandas as pd, numpy as np
import os
import glob
import pathlib
import re
import janome
import jaconv
from janome.tokenizer import Tokenizer
from janome.analyzer import Analyzer
from janome.charfilter import *
import string
import MeCab
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
import unicodedata
from gensim import corpora
from gensim import models
from pprint import pprint
import time
import math

import numpy as np
from sklearn.decomposition import PCA
from matplotlib import pyplot as plt
from sklearn import preprocessing

# %%
# MeCabの辞書にNEologdを指定。
# mecabは携帯素解析用、wakatiは分かち書き用
mecab = MeCab.Tagger('-d /usr/lib/x86_64-linux-gnu/mecab/dic/mecab-ipadic-neologd/')
wakati = MeCab.Tagger("-Owakati -d /usr/lib/x86_64-linux-gnu/mecab/dic/mecab-ipadic-neologd/")

# %%
# 形態素解析を行う関数を定義
# ファイルを入力するとファイルを出力し、文字列を渡すと文字列を返します。引数fileで変更します。  
# 単に分かち書きしたいだけの場合は引数にmecab=wakatiとすると実現できます。
def MecabMorphologicalAnalysis(path='./text.txt', output_file='wakati.txt', mecab=mecab, file=False):
    mecab_text = ''
    if file:
        with open(path) as f:
            for line in f:
                mecab_text += mecab.parse(line)
        with open(output_file, 'w') as f:
            print(mecab_text, file=f)
    else:
        for path in path.split('\n'):
            mecab_text += mecab.parse(path)
        return mecab_text

# %%
def sortedTFIDF(sentences):
    
    # 単語にIDを添付します。
    dictionary = corpora.Dictionary(sentences)
    
    # 作品ごとの単語の出現回数をカウント
    corpus = list(map(dictionary.doc2bow, sentences))
    
    # 単語ごとにTF-IDFを算出
    test_model = models.TfidfModel(corpus)
    corpus_tfidf = test_model[corpus]
    
    # ID:TF-IDF → TF-IDF:単語 に変換。TF-IDFを左に持ってくることで、sortedを用いてTF-IDFを基準にソートすることができます。
    texts_tfidf = []
    for doc in corpus_tfidf:
        text_tfidf = []
        for word in doc:
            text_tfidf.append([word[1], dictionary[word[0]]])
        texts_tfidf.append(text_tfidf)
    
    # TF-IDFを基準にソートを行います。
    sorted_texts_tfidf = []
    for text in texts_tfidf:
        sorted_text = sorted(text, reverse=True)
        sorted_texts_tfidf.append(sorted_text)

    return sorted_texts_tfidf

# %%
def YahooNews(n=30):
    url = "https://news.yahoo.co.jp/topics/top-picks"
    URL = "https://news.yahoo.co.jp/"
    res = requests.get(url)
    soup = BeautifulSoup(res.text, "html.parser")
    all_page_links = []
    all_page_links.append(url)
    all_links = []
    while True:
        try:
            next = soup.find("li", class_="pagination_item-next").find("a")["href"]
            next_link = URL + next
            all_page_links.append(next_link)
            next_res = requests.get(next_link)
            soup = BeautifulSoup(next_res.text, "html.parser")
        except:
            break
            
    title_list = []
    category_list = []
    text_list = []
    for url in all_page_links: # all_page_links: 全てのニュースのリスト
            res = requests.get(url) # url: 25個分のニュースのリスト
            soup = BeautifulSoup(res.text, "html.parser")
            page_soup = soup.find_all("a", class_="newsFeed_item_link")
            for href in page_soup:
                link = href["href"] # link: 一つのニュースのリンク(本文は一部のみ)
                all_links.append(link)
    
    if len(all_links) <= n:
        n = len(all_links)
    
    i = 0
    for link in all_links:
        link_res = requests.get(link)
        href_soup = BeautifulSoup(link_res.text, "html.parser")
        try:
            title = href_soup.find("h1", class_=re.compile("^sc")).string
        except:
            continue
        title_link = href_soup.find("a", class_="sc-eAyhxF")["href"] # title_link: 本文
        res = requests.get(title_link)
        soup = BeautifulSoup(res.text, "html.parser")

        category = soup.find_all("li", class_="current")
        try:
            category = category[1].string
        except:
            continue
        else:
            for tag in soup.find_all(["a"]):
                tag.decompose()
            try:
                soup = soup.find("div", class_="article_body").get_text()
                soup = symbol_removal(soup)
                
                text_list.append(soup)
                title_list.append(title)
                category_list.append(category)
                i += 1 # 本文が正常に保存できたことをトリガーにしてカウントを一つ増やすことにします。
                pro_bar = ('=' * math.ceil(i / (n / 20))) + (' ' * int((n / (n / 20)) - math.ceil(i / (n / 20))))
                print('\r[{0}] {1}記事'.format(pro_bar, i), end='')
                if i >= n:
                    df = pd.DataFrame({'title': title_list, 'category': category_list, 'text': text_list})
                    return df
            except:
                continue
    df = pd.DataFrame({'title': title_list, 'category': category_list, 'text': text_list})
    return df

# %%
def symbol_removal(soup):
    soup = unicodedata.normalize("NFKC", soup)
    exclusion = "「」『』【】《》≪≫、。・◇◆" + "\n" + "\r" + "\u3000"
    soup = soup.translate(str.maketrans("", "", string.punctuation  + exclusion))
    return soup

# %%
df = YahooNews(1000)
# Out:
# [====================] 466記事

# %%
df.shape
# Out:
# (466, 3)

# %%
df.head()
# Out:
#             title category                                               text
# 0  鬼滅の刃 歴代興収が10位に     エンタメ   10月16日に公開されたアニメ映画劇場版鬼滅の刃無限列車編の最新の興行収入が2日発表された...
# 1    ニッチェ近藤が結婚を報告     エンタメ   お笑いコンビニッチェの近藤くみこ37が2日所属事務所マセキ芸能社の公式サイトを通じてかねて...
# 2   首相 学術会議は既得権益化       国内   衆院予算委員会は2日午前菅義偉首相と全閣僚が出席して基本的質疑に入った 首相は日本学術会議...
# 3   紅白司会 紅組は二階堂ふみ     エンタメ   NHKは2日今年の大晦日に放送される第71回 NHK紅白歌合戦12月31日午後7時30分の...
# 4    松井秀喜氏が愛した店閉店     スポーツ  お世話になってばかりで寂しいです巨人やヤンキースなどで活躍した松井秀喜氏46が知人を介してあ...

# %%
texts = []
for i in range(len(df)):
    texts.append(MecabMorphologicalAnalysis(df['text'][i], mecab=wakati))

# %%
# 分かち書きができたか確認します。5作品を表示。
for i, text in enumerate(texts):
    if i < 5:
        display(text[:100])
# Out:
# '10月16日 に 公開 さ れ た アニメ映画 劇場版 鬼滅の刃 無限 列車 編 の 最新 の 興行収入 が 2日 発表 さ れ た 初日 から 17日間 1日 まで の 興行収入 が 興行収入 15'
# 'お笑いコンビ ニッチェ の 近藤くみこ 37 が 2日 所属事務所 マセキ芸能社 の 公式サイト を 通じ て かね て よ てり 交際 し て い た 一般男性 と 結婚 し たこ を 報告 し た'
# '衆院 予算委員会 は 2日 午前 菅義偉 首相 と 全閣僚 が 出席 し て 基本的 質疑 に 入っ た 首相 は 日本学術会議 の 会員 選考 について 閉鎖 的 で 既得権益 の よう に なっ '
# 'NHK は 2日 今年 の 大晦日 に 放送 さ れる 第 71回 NHK紅白歌合戦 12月31日 午後7時 30分 の 司会者 を 発表 し た 白組 は 俳優 の 大泉 洋紅 組 は 女優 の 二'
# 'お世話 に なっ て ばかり で 寂しい です 巨人 や ヤンキース など で 活躍 し た 松井秀喜 氏 46 が 知人 を 介し て ある 居酒屋 の 店長 に こんな メッセージ を 送っ て '

# %%
# リストに変換
sentences = []
for text in texts:
    text_list = text.split(' ')
    sentences.append(text_list)

# %%
# まずdocumentsを作り、モデルに渡す。
documents1 = [TaggedDocument(doc, [i]) for i, doc in enumerate(sentences)]
model1 = Doc2Vec(documents1, vector_size=100, window=7, min_count=1)

# %%
# モデルに渡したdocumentsの中身は番号と本文が対応したリストです。ここでは参考のため、作者も表示しています。
for i, doc in enumerate(documents1):
    print(doc[1], df['title'][i], df['category'][i], doc[0][:8])
# Out:
# [0] 鬼滅の刃 歴代興収が10位に エンタメ ['10月16日', 'に', '公開', 'さ', 'れ', 'た', 'アニメ映画', '劇場版']
# [1] ニッチェ近藤が結婚を報告 エンタメ ['お笑いコンビ', 'ニッチェ', 'の', '近藤くみこ', '37', 'が', '2日', '所属事務所']
# [2] 首相 学術会議は既得権益化 国内 ['衆院', '予算委員会', 'は', '2日', '午前', '菅義偉', '首相', 'と']
# [3] 紅白司会 紅組は二階堂ふみ エンタメ ['NHK', 'は', '2日', '今年', 'の', '大晦日', 'に', '放送']
# [4] 松井秀喜氏が愛した店閉店 スポーツ ['お世話', 'に', 'なっ', 'て', 'ばかり', 'で', '寂しい', 'です']
# [5] ハンド宮崎大輔容疑者を逮捕 国内 ['FNN', 'プライムオンラインハンドボール', '元日本代表', 'の', '宮崎大輔', '選手', 'が', '2日']
# [6] 尚弥の超速パンチ 実は新兵器 スポーツ ['試合前', 'スパー', 'で', '見せ', 'た', '進化', '衝撃', 'の']
# [7] やっぱり青学が本命?箱根駅伝 スポーツ ['前回大会', 'の', 'トップ3', 'で', 'ある', '東海大', '青学大', '駒大']
# [8] WHO事務局長が自主隔離 国際 ['AFP', '時事', '更新', '世界保健機関', 'WHO', 'の', 'テドロスアダノムゲブレイェスス', 'Tedros']
# [9] 西武 内海哲也と契約更新へ スポーツ ['西武', 'が', '内海哲也', '投手', '38', 'と', '来季契約', '更新']
# [10] 尖閣周辺に中国船 年最多更新 国内 ['沖縄県', '尖閣諸島', '周辺', 'の', '領', '海外', '側', 'に']
# [11] 千葉市長 知事選出馬を表明 地域 ['来春', 'の', '知事選', 'で', '千葉市', 'の', '熊谷俊人', '市長']
# [12] 高橋留美子さんに紫綬褒章 エンタメ ['政府', 'は', '2020年', '秋', 'の', '褒章', '受章', '者']
# [13] 札幌2歳衰弱死 母は無罪主張 地域 ['去年6月', '札幌', 'で', '当時', '2歳', 'の', '池田', '詩']
# [14] ハロウィンに偽パトカー疾走? 国内 ['ハロウィーン', 'の', '10月31日', '夜', '札幌市内', 'で', 'パトカー', 'に']
# [15] 都構想関連に公金100億円超 国内 ['地域政党', '大阪維新の会', 'は', '2010年', 'に', '結党', 'し', 'て']
# [16] 2700ツネ キッチンカーで働く エンタメ ['昨年6月', '大', '騒動', 'に', 'なっ', 'た', '吉本芸人', 'による']
# [17] 本田望結 サッカー応援マネに エンタメ ['女優', 'で', 'フィギュアスケート', '選手', 'の', '本田望結', 'みゆ', '16']
# [18] コネリーさん 認知症だった エンタメ ['AFP', '時事', '先日', '90歳', 'で', '死去', 'し', 'た']
# [19] レナウン 再建断念し破産へ 経済 ['名門', 'レナウン', '月内', 'に', '破産', 'へ', '移行', '5月15日']
# [20] 米大統領選 期日前が過去最高 国際 ['デトロイト', 'ミシガン州', 'レディング', 'ペンシル', 'べ', 'ニア', '州', '31日']
# [21] 中韓などから入国 検査不要に 国内 ['新型コロナウイルス', 'の', '水際対策', 'が', '1日', '緩和', 'さ', 'れ']
# [22] 首相 都構想は「一石投じた」 国内 ['菅義偉', '首相', 'は', '2日', '大阪都構想', 'に関する', '住民投票', '否決']
# [23] 居酒屋大手5社 全体の1割閉店 経済 ['居酒屋チェーン', 'で', '店舗', '閉鎖', 'が', '広がっ', 'て', 'いる']
# [24] マー君 全球団との交渉可能に スポーツ ['ヤンキース', 'から', 'FA', 'フリーエージェント', 'と', 'なっ', 'た', '田中将大']
# [25] 遠隔は悪?大学名公表で波紋 ライフ ['後期', 'の', '対面', '授業', 'が', '5割', '未満', 'の']
# [26] 都幹部「首都2つに見える」 国内 ['東京都', 'の', '関係者', 'は', '都', 'が', '二つ', 'できる']
# [27] 否決で打撃 維新立て直し急務 国内 ['大阪都構想', 'という', '看板', '政策', 'の', '再', '否決', 'と']
# [28] 秋の褒章 尾畠春夫さんに緑綬 国内 ['赤い', 'ねじり', 'はちまき', 'に', 'オレンジ', 'の', 'シャツ', '姿']
# [29] 公園の乳児遺体 母親を逮捕 国内 ['東京', '新橋', 'の', '公園', 'で', '2019年', '生後', '間']
# [30] ヤクルト井野卓 現役引退へ スポーツ ['ヤクルト', '井野卓', '捕手', '36', 'が', '今季限り', 'で', '現役']
# [31] ヤクルトがSB内川の獲得調査 スポーツ ['ヤクルト', 'が', '今季限り', 'で', 'ソフトバンク', 'を', '退団', 'する']
# [32] 紅白 白組司会は大泉洋で調整 エンタメ ['大みそか', 'の', '第', '71回', '紅白歌合戦', 'で', 'NHK', 'が']
# [33] トルコ地震 迫る「72時間」 国際 ['エルサレム', '時事', 'トルコ', 'と', 'ギリシャ', 'の', '沖合', 'の']
# [34] 大阪都構想を阻止 自民は安堵 国内 ['地域政党', '大阪維新の会', 'が', '推進', 'し', 'て', 'き', 'た']
# [35] 西武・松坂 来季も現役続行へ スポーツ ['西武', 'が', '松坂大輔', '投手', '40', 'と', '来季', 'も']
# [36] ATSUSHI EXILE卒業しソロ専念 エンタメ ['EXILE', 'ATSUSHI', '40', 'が', '11月2日', 'を', 'もっ', 'て']
# [37] 板で窓覆う 米大統領選を警戒 国際 ['3日', '投開票', 'の', '米大統領選', 'で', '選挙結果', 'をめぐって', '共和党候補']
# [38] 知事 僕は都構想再挑戦ない 国内 ['1日', '投開票', 'さ', 'れ', 'た', '住民投票', 'で', '大阪都構想']
# [39] 接戦の都構想 悩んだ有権者 国内 ['大阪都構想', 'の', '賛否', 'を', '問う', '住民投票', 'は', '1日']
# [40] 天心42連勝 惜別の跳び膝蹴り スポーツ ['RISE', '1日', 'エディオンアリーナ大阪', 'キックボクシング', '界', 'の', '神童', '那須川天心']
# [41] 大阪市長 任期満了で政界引退 地域 ['速報', '大阪都構想', '反対', '多数', 'の', '結果', 'を', '受けて']
# [42] 否決 大阪市長「私の力不足」 国内 ['政令指定都市', 'の', '大阪市', 'を', '廃止', 'し', 'て', '4つ']
# [43] 元withB アメフト会心プレー スポーツ ['社会人', 'アメリカンフットボール', 'の', 'X1', 'エリア', '西日本', 'トーナメント', 'の']
# [44] 反対多数 大阪市は存続へ 国内 ['大阪市', 'を', '廃止', 'し', 'て', '四つ', 'の', '特別区']
# [45] ハナコ岡部 絶妙なかわいさ エンタメ ['コント師', 'ハナコ', '秋山寛貴', '岡部大', '菊田竜大', 'の', '3人', 'から']
# [46] 大阪投票率62.35% 前回下回る 国内 ['2度目', 'に', 'なっ', 'た', '住民投票', 'の', '投票率', 'は']
# [47] 8冠 騎手ルメールも目真っ赤 スポーツ ['第', '162回', '天皇賞秋', 'G11', '日', '東京', '芝', '2000メートル']
# [48] 大阪都構想 賛否は拮抗 国内 ['大阪市民', 'を', '対象', 'に', '大阪都構想', 'の', '是非', 'を']
# [49] 都構想 18時投票率37.60% 国内 ['大阪市民', 'を', '対象', 'に', '大阪都構想', 'の', '是非', 'を']
# [50] ネコの絵も 謎は深まるナスカ 国際 ['考古学', 'の', '大きな', '謎', 'に', '新', '技術', 'で']
# [51] 台風横断 フィリピン各地洪水 国際 ['FNN', 'プライム', 'オンライン', '非常', 'に', '強い', '台風19号', 'が']
# [52] 西武平尾コーチ解雇 私物窃取 スポーツ ['西武', 'は', '1日', '平尾', '博司', '2軍', '打撃', 'コーチ']
# [53] 安倍氏 父墓前に首相辞任報告 国内 ['安倍晋三', '前', '首相', 'は', '1日', '持病', 'の', '潰瘍性大腸炎']
# [54] 大下容子アナ 30歳定年説語る エンタメ ['情報番組', 'や', 'バラエティー', 'や', '番組', 'など', 'で', '幅広く']
# [55] 米大統領選 かたずのむイラン 国際 ['テヘラン', '共同', '米国', 'と', '敵対', 'する', 'イラン', 'で']
# [56] VTuber人気けん引 upd8終了へ エンタメ ['Activ', '8', '株式会社', 'が', '展開', 'する', 'バーチャルYouTuber', 'の']
# [57] 憲剛引退 冷静で「口達者」 スポーツ ['サッカー', 'の', 'J1', '川崎F', 'の', '元日本代表', 'MF', '中村憲剛']
# [58] SB内川 涙こらえファンに別れ スポーツ ['ウエスタンリーグ', 'ソフトバンク', '51', '阪神', '1日', 'タマスタ', '筑後', '今季限り']
# [59] 軒並み赤字 外食チェーン岐路 経済 ['居酒屋', 'など', '外食チェーン', '大手', 'の', 'ワタミ', 'は', '10月5日']
# [60] 都構想 130年の歴史変わるか 国内 ['大阪市', 'を', '廃止', 'し', 'て', '四つ', 'の', '特別区']
# [61] アーモンドアイ GI初の8冠馬 スポーツ ['11月1日', 'の', '東京', '11', 'R', 'で', '行わ', 'れ']
# [62] 都新たに116人 感染数横ばい 国内 ['東京都', 'は', '1日', '新型コロナウイルス', 'の', '感染者', 'が', '新た']
# [63] 毒ガスのよう 香害に苦しむ声 国内 ['小学生', 'の', '子ども', 'の', '友だち', 'を', '家', 'に']
# [64] 板東英二 今は仕事セーブ中 エンタメ ['ラジオ番組', 'も', 'すべて', '終了', '姿', 'も', '見', 'なく']
# [65] MF中村憲剛 今季限りで引退 スポーツ ['J1', '川崎', 'の', '元日本代表', 'MF', '中村憲剛', '40', 'が']
# [66] 福岡のハロウィン 2人を逮捕 地域 ['テレビ西日本', 'ハロウィーン', 'の', '10月31日', '夜', '福岡市天神', 'の', '公園']
# [67] 北陸新幹線 延伸遅れで懸念も 地域 ['北陸新幹線', '金沢', '―', '敦賀', '間', 'の', '2023年', '春']
# [68] トルコ 救出は時間との闘い 国際 ['AFP', '時事', 'トルコ', 'ギリシャ', '沖の', 'エーゲ海', 'Aegean', 'Sea']
# [69] 元ジャニ7人組 来年デビュー エンタメ ['タレント', 'の', '安井謙太郎', '真田佑馬', '諸星翔希', '森田美勇人', '萩谷慧悟', '阿部顕嵐']
# [70] 駅伝 駒大が「3強」激戦制す スポーツ ['学生', '3', '大', '駅伝', '開幕戦', '全日本大学駅伝', '1日', '名古屋市']
# [71] 尚弥KO勝ち 試合中に戦略変更 スポーツ ['ボクシング', 'WBA', 'IBF', '世界', 'バンタム級', 'タイトルマッチ', '31日', 'ラスベガス']
# [72] はんこ店 鬼滅キャラ名あるよ ライフ ['竈門', 'かまど', '我妻', 'あ', 'が', 'つま', '不死川', 'しな']
# [73] 山口組総本部 菓子配らず 国内 ['暴力団員', 'の', '青少年', 'へ', 'の', '菓子', '提供', 'など']
# [74] 都構想 正午時点の投票率16% 国内 ['大阪市民', 'を', '対象', 'に', '大阪都構想', 'の', '是非', 'を']
# [75] イージス代替艦 大型化を検討 国内 ['政府', 'は', '地上', '配備', '型', '迎撃', 'システム', 'イージスアショア']
# [76] 仏で教会司祭撃たれ重傷 逮捕 国際 ['AFP', '時事', '仏', 'リヨン', 'Lyon', 'で', '10月31日', '銃身']
# [77] ものすごい量 服在庫処分の今 経済 ['新型コロナウイルス', 'の', '感染拡大', 'で', 'アパレル', '業界', 'が', '苦境']
# [78] 豚解体 ベトナム人を再逮捕 国内 ['埼玉県警', 'は', '1日', '自宅', 'で', '食用', 'に', '豚']
# [79] 尚弥 ラスベガスで7回KO勝ち スポーツ ['プロボクシング', 'WBA', 'IBF', '世界', 'バンタム級', 'タイトルマッチ', '31日', '日本時間']
# [80] 火災で救助中 消防署員が死亡 国内 ['盛岡市', 'の', 'マンション', 'で', '10月31日', '夜', 'に', '起き']
# [81] 1万人超に抗体検査へ 厚労省 ライフ ['厚生労働省', 'は', '一般住民', 'を', '対象', 'に', '新型コロナウイルス', 'の']
# [82] 「誰も頼れず」産後うつ倍増 国内 ['コロナ禍', 'で', '女性', 'の', '産後うつ', 'の', 'リスク', 'が']
# [83] トルコ なお多数閉じ込めか 国際 ['エルサレム', 'パリ', '時事', 'トルコ', 'と', 'ギリシャ', 'の', '沖合']
# [84] あと3日 米大統領選追い込み 国際 ['Nippon', 'News', 'Network', 'NNN', 'アメリカ大統領選挙', 'まで', 'あと', '3日']
# [85] 元祖JJガール「本当に休刊?」 エンタメ ['光文社', 'は', '女性ファッション誌', 'JJ', 'を', '2021年', '2月', '号']
# [86] 都構想 議論かみ合わぬまま 国内 ['大阪市', 'を', 'なくし', 'て', '四つ', 'の', '特別区', 'に']
# [87] ジャポニカ表紙 写真家探検記 国内 ['小学生', 'の', 'ころ', '誰', 'も', 'が', '手', 'に']
# [88] 北海道 4日は平地でも雪か 国内 ['2日', '月', 'は', '寒冷前線', 'の', '通過', 'で', '広く']
# [89] 吉見引退へ 中日の黄金期支え スポーツ ['中日', '吉見一起', '投手', '36', 'が', '今季限り', 'で', '現役']
# [90] 「大江戸線延伸を」どんな街? 経済 ['ミニ', '地下鉄', '幅', '5km', 'の', '鉄道空白地帯', 'を', '埋める']
# [91] 危険な状況 北海道で感染急増 地域 ['10月', 'GoTo', 'や', '札幌', '往来', '増', '道内', 'の']
# [92] 現金化商法に注意 手口巧妙化 国内 ['金融庁', 'が', '3月', '給与', 'を', '受け取る', '権利', 'を']
# [93] 秋元氏「金で転ぶ」買収指示か 国内 ['金', 'を', 'ぶつけ', 'て', 'ほしい', 'と', 'の', '指示']
# [94] 迷える渋野日向子 解けぬ呪縛 スポーツ ['女子', 'ゴルフツアー', '樋口久子', '三菱電機', 'レディース', '第', '2日', '2020年']
# [95] 大阪都構想 住民投票始まる 国内 ['大阪市', 'を', '廃止', 'し', '4つ', 'の', '特別区', 'に']
# [96] 花澤香菜 棒読みだった過去 エンタメ ['昨年', '字幕版', 'が', '上映', 'と', 'なり', 'SNS', 'で']
# [97] 感染拡大 英で再び外出自粛へ 国際 ['ロンドン', '広瀬誠', '英国', 'の', 'ジョンソン首相', 'は', '10月31日', '新型コロナウイルス']
# [98] 早見あかり第1子出産していた エンタメ ['女性', 'アイドルグループ', 'ももいろクローバー', '現', 'ももいろクローバーZ', 'の', '元メンバー', 'で']
# [99] 修学旅行生 GoToで大人買い 国内 ['10月', 'から', '配布', 'が', '始まっ', 'た', 'Go', 'To']
# [100] コネリーさん死去 悲しい損失 国際 ['映画', 'で', '初めて', '007', 'こと', 'ジェイムズボンド', '役', 'を']
# [101] トランプ氏 接戦州で差縮める 国際 ['ワシントン', '横堀裕也', '米大統領選', 'は', '10月30日', '11月3日', 'の', '投開票']
# [102] 上野動物園 初めてのゾウ誕生 国内 ['東京都台東区', 'の', '上野動物園', 'は', '31日', '飼育', 'する', 'アジアゾウ']
# [103] 都構想 焦点は住民サービス 国内 ['大阪', 'の', '将来', 'を', '占う', '一', '票', 'を']
# [104] 行政事業レビュー 誤記2600件 国内 ['政府', '予算', 'の', '執行', '状況', 'を', '記載', 'する']
# [105] ショーン・コネリーさん死去 国内 ['英', 'BBC', '放送', 'は', '10月31日', '人気', 'スパイ映画', '007']
# [106] 柔道「不可解裁定」で大混乱 スポーツ ['柔道', '講道館杯', '31日', '千葉ポートアリーナ', '日本一', 'を', '争う', '大会']
# [107] 鬼滅 観客動員数1000万人突破 エンタメ ['アニメ映画', '劇場版', '鬼滅の刃', '無限', '列車', '編', '公開', '御礼']
# [108] 渋谷の街 仮装の人出は8割減? 国内 ['新型コロナウイルス', '禍', 'の', '中', 'ハロウィーン', '当日', 'と', 'なっ']
# [109] 歯ぎしり 放置して大丈夫? 科学 ['教え', 'て', 'ヨミ', 'ドック', 'トラさん', 'が', '浮か', 'ない']
# [110] 「偽陽性」で混乱 五輪へ課題 スポーツ ['国際体操連盟', 'FIG', 'は', '31日', '29日', 'に', '新型コロナウイルス', '感染']
# [111] 答弁パターン化 首相の真価は 国内 ['菅義偉', '首相', 'が', '就任後', '初めて', '臨ん', 'だ', '衆参']
# [112] 中国・千人計画 参加者の本音 国際 ['働ける', 'なら', '日本', 'で', '中国政府', 'が', '推進', 'する']
# [113] 都構想 期日前投票は前回超え 地域 ['関西テレビ', '11月1日', 'いわゆる', '大阪都構想', 'の', '投開票', 'が', '行わ']
# [114] 頭に謎の物体 古代文明と市民 国際 ['徐々', 'に', '明かさ', 'れる', '一般市民', 'の', '暮らし', '古代エジプト']
# [115] 渋谷ハロウィン 仮装まばら 国内 ['恒例行事', 'として', '定着', 'し', 'た', 'ハロウィーン', 'が', '31日']
# [116] 珍事 日差しキツくて野球中断 スポーツ ['6回', 'の', 'ロッテ', 'の', '攻撃', '中', 'に', '試合']
# [117] 英 再び全土ロックダウンか 国際 ['AFP', '時事', '英紙', 'タイムズ', 'Times', 'は', '30日', '新型コロナウイルス']
# [118] 内村航平「偽陽性」だった スポーツ ['国際体操連盟', 'FIG', 'は', '31日', '体操', '男子', 'で', '新型コロナウイルス']
# [119] 宇垣美里 報道記者目指してた エンタメ ['昨春', 'TBS', 'を', '退社', 'し', 'フリーアナウンサー', 'に', '転身']
# [120] ハロウィン夜空 46年ぶり満月 国内 ['きょう', '31日', 'ハロウィン', 'の', '夜', 'は', 'グッ', 'と']
# [121] 笑って 崖っぷち遊園地の思い 地域 ['新型コロナウイルス', 'の', '影響', 'で', '崖っぷち', 'に', '立たさ', 'れ']
# [122] 地震怖い トルコ在住の邦人 国際 ['All', 'Nippon', 'NewsNetworkANN', '強い', '揺れ', 'を', '観測', 'し']
# [123] 宇垣美里TBS時代の自分は商品 エンタメ ['昨春', 'TBS', 'を', '退社', 'し', 'フリーアナウンサー', 'に', '転身']
# [124] 女性→親子 鬼滅ファンの代謝 エンタメ ['劇場版アニメ', 'が', '史上', '最速', 'で', '100億円', 'を', '突破']
# [125] 渋野 国内2戦連続の予選落ち スポーツ ['樋口久子', '三菱電機', 'レディース', '渋野', 'は', 'ホールインワン', 'の', 'ジンクス']
# [126] 北海道で81人が感染 過去最多 地域 ['北海道', 'は', '10月31日', '石狩', 'や', '空知', '地方', 'など']
# [127] 改善しない巻き爪 医師が解説 科学 ['インターネット', 'で', '巻き爪', 'を', '検索', 'する', 'と', 'びっくり']
# [128] 日立「巨艦解体」も多難な道 経済 ['営業利益率', '10', '超', 'の', '目標', 'の', '足', 'を']
# [129] 巨人独走V 許した5球団の敗因 スポーツ ['巨人', 'が', '2年連続', '38度目', '1', 'リーグ', '時代', 'を']
# [130] 賞味期限 月単位に変更続々 経済 ['まだ', '食べ', 'られる', 'の', 'に', '廃棄', '処分', 'さ']
# [131] BTSファン 上場巡る激動1週間 国際 ['ジェットコースター', 'の', 'よう', 'に', '市場', 'の', '期待', 'と']
# [132] 都215人感染 3日連続200人超 国内 ['東京都', 'で', 'きょう', '新た', 'に', '215人', 'が', '新型コロナウイルス']
# [133] ハロウィン象徴 なぜカボチャ ライフ ['なぜ', 'ジャック', 'な', 'の', 'か', 'いつ', 'から', 'カボチャ']
# [134] トルコ地震で津波 溺死者も 国際 ['All', 'Nippon', 'NewsNetworkANN', 'トルコ西部', '沖の', 'エーゲ海', 'で', '30日']
# [135] 伊藤さん主演映画 公開へ エンタメ ['乗用車', 'を', '運転', '中', 'に', 'バイク', 'に', '衝突']
# [136] 戦力外通告の瞬間 経験者語る スポーツ ['ロッカー', 'に', '来', 'た', 'マネジャー', 'の', '姿', 'で']
# [137] 鬼滅人気「全集中」経済に光 地域 ['アニメ映画', '劇場版', '鬼滅の刃', '無限', '列車', '編', 'は', '公開']
# [138] 西武山川が抹消 本塁打王消滅 スポーツ ['西武', 'の', '山川穂高', '内野手', '28', 'が', '31日', '出場選手登録']
# [139] 厳しさ増す終盤 激戦州で訴え 国際 ['Nippon', 'News', 'Network', 'NNN', 'アメリカ大統領選挙', 'まで', 'あと', '4日']
# [140] 久保田磨希 認知症の母亡くし エンタメ ['ウェルネス', 'とーく', '少女時代', 'の', 'コンプレックス', 'を', '力', 'に']
# [141] アイマス声優 大坪由佳が結婚 エンタメ ['アニメ', 'アイドルマスター', 'シンデレラガールズ', '三村かな子', '役', 'など', 'で', '知ら']
# [142] トルコ地震 800人以上が死傷 国際 ['トルコ西部', 'で', '30日', '午後', 'に', '起き', 'た', 'マグニチュード']
# [143] 返礼品の和牛産地を偽装 大分 国内 ['大分県', '外', '産', 'の', '和牛', 'を', 'ブランド', '牛']
# [144] 捜査は尽くした 首里城火災 地域 ['首里城', '火災', 'の', '出火', '調査', 'に', '当たっ', 'た']
# [145] がん 死亡直前まで4割が痛み 国内 ['All', 'Nippon', 'NewsNetworkANN', 'がん', 'など', 'で', '亡くなっ', 'た']
# [146] 藤川 引退後は阪神に残らず スポーツ ['今季限り', 'で', 'の', '現役引退', 'を', '表明', 'し', 'て']
# [147] 未婚のパパ 結婚と法的違いは 国内 ['三代目', 'J', 'SOUL', 'BROTHERS', 'の', 'ELLY', 'さん', 'が']
# [148] 相当数に深刻な後遺症 WHO 国際 ['ベルリン', '時事', '世界保健機関', 'WHO', 'の', 'テドロス事務局長', 'は', '30日']
# [149] 速度違反捏造 警官ら書類送検 国内 ['北海道警', '交通機動隊', 'の', '警部補', 'が', '交通違反', 'の', '取り締まり']
# [150] 首里城 二度と燃えない城に 国内 ['沖縄', 'を', '象徴', 'し', 'て', 'き', 'た', '首里城']
# [151] 下平アナ 週半分は広島で主婦 エンタメ ['心', 'が', '動い', 'たら', '思い切っ', 'て', '踏み出す', 'タイプ']
# [152] G岡本 自分の成績にムカつく スポーツ ['JERA', 'セリーグ', '巨人', '3', '―', '3', 'ヤクルト', '延長']
# [153] 首里城 1年前の涙語る高校生 地域 ['沖縄タイムス', 'が', '首里城', '火災', 'を', '報じ', 'た', '昨年11月']
# [154] トルコ沖地震 死者20人超に 国際 ['イズミルローマ', '共同', '米', '地質調査所', 'USGS', 'に', 'よる', 'と']
# [155] 尚弥&モロニー距離10cmで火花 スポーツ ['プロボクシング', 'WBA', 'IBF', '世界', 'バンタム級', 'タイトルマッチ', '12回', '戦']
# [156] iPhone 知らない予定追加被害 国内 ['iPhone', 'アイフォーン', 'の', 'カレンダー', 'に', '勝手', 'に', '予定']
# [157] 信長の野望 37年売れ続ける訳 エンタメ ['文春', 'オンライン', 'で', '中間', '発表', 'さ', 'れ', 'た']
# [158] 逗子の崖崩れ 前日に亀裂発見 国内 ['神奈川県逗子市', 'で', '2月', '分譲マンション', '敷地内', 'の', '斜面', 'が']
# [159] 危険なバス停調査 6県780カ所 国内 ['12', '横断', '歩道', 'や', '交差点', 'の', 'そば', 'に']
# [160] G原監督 丸は骨折していた スポーツ ['JERA', 'セリーグ', '巨人', '3', '―', '3', 'ヤクルト', '30日']
# [161] Gドラ1平内に背番号11用意 スポーツ ['巨人', 'から', 'ドラフト1位指名', 'を', '受け', 'た', '亜大', '平内']
# [162] トルコ沖で地震 複数の死者 国際 ['エルサレム', '時事', 'トルコ西部', '沖の', 'エーゲ海', 'で', '30日', '午後2時']
# [163] ユーロ圏GDP12%増 上げ最大 国際 ['ブリュッセル', '時事', '欧州連合', 'EU', '統計局', 'が', '30日', '発表']
# [164] 嵐 被災地に寄り添った歴史 エンタメ ['大', 'ブレイク', 'を', '果たし', '国民', '的', 'アイドル', 'に']
# [165] 伊藤さん釈放 30秒超頭下げる エンタメ ['29日', 'に', '自動車運転処罰法', '違反', '過失', '傷害', 'と', '道路交通法違反']
# [166] 地中海 ギリシャでM7.0の地震 国内 ['日本時間', 'の', '10月30日', '金', '20時', '51分', '頃', '海外']
# [167] 北海道 強毒性鳥インフル確認 国内 ['北海道', 'は', '30日', '紋別', 'もん', 'べつ', '市内', 'で']
# [168] ハマスタ実証実験 目安届かず スポーツ ['セリーグ', 'DeNA', '―', '阪神', '2020年', '10月30日', '横浜', '横浜']
# [169] 巨人がリーグ2連覇 スポーツ ['JERA', 'セリーグ', '巨人', '3', '―', '3', 'ヤクルト', '延長']
# [170] 第一生命元職員 5200万円詐取 経済 ['FNN', 'プライム', 'オンライン', '第一生命', 'の', '生保', 'レディー', 'が']
# [171] KDDI 格安スマホで新会社 経済 ['FNN', 'プライム', 'オンライン', 'KDDI', 'が', '格安スマホ', 'ブランド', 'として']
# [172] 伊藤容疑者が釈放 涙ぐみ謝罪 エンタメ ['道交法違反', 'ひき逃げ', 'など', 'の', '疑い', 'で', '逮捕', '送検']
# [173] GoToトラベルに制限 7泊まで 国内 ['CopyrightC', 'Japan', 'News', 'Network', 'All', 'rights', 'reserved', 'GoTo']
# [174] 給付金 返還の申し出6千件 経済 ['新型コロナウイルス', 'の', '経済', '対策', 'の', '持続化給付金', 'を', '不適切']
# [175] 短期出張 帰国後待機を免除へ 国内 ['政府', 'は', '30日', '海外', 'へ', 'の', '短期', '出張']
# [176] 台湾で鬼滅公開 熱狂ファンも 国際 ['Nippon', 'News', 'Network', 'NNN', '驚異', '的', 'な', 'ヒット']
# [177] 首相 学術会議は旧帝大が45% 国内 ['菅義偉', '首相', 'は', '30日', 'の', '参院本会議', 'で', '日本学術会議']
# [178] 有休取得率56.3% 過去最高 経済 ['厚生労働省', 'が', '30日', '発表', 'し', 'た', '就労', '条件']
# [179] 自殺誘う情報で通報 上期最多 国内 ['警察庁', 'の', '委託', 'を', '受け', 'て', 'インターネット上', 'の']
# [180] 皿洗いで無料の店 最後の思い ライフ ['食後', '30分間', 'の', '皿洗い', 'で', '1', '食', '無料']
# [181] 内閣の資産公開 首相6277万円 国内 ['菅義偉', '首相', 'と', '閣僚', 'の', '計', '21人', 'は']
# [182] 切り捨て生む 地震が変えた町 地域 ['北海道', 'ニュース', 'UHB', '死者', '44人', '建物', '被害', 'が']
# [183] リニア工事差し止め求め 提訴 地域 ['リニア中央新幹線', 'の', '建設工事', 'を', '巡り', '大井川', '流域', 'の']
# [184] 北村匠海 映画公開も「不安」 エンタメ ['俳優', 'の', '北村匠海', '22', '女優', 'の', '山本舞香', '23']
# [185] 朗希 今季は公式戦で登板なし スポーツ ['ロッテ', '佐々木朗希', '投手', '18', 'が', '今季', 'の', '12']
# [186] DCM 島忠TOBの条件変更考えず 経済 ['東京', '30日', 'ロイター', '島忠', '8184', 'T', 'に対する', '株式公開']
# [187] 高齢者を捨て 若者優先した町 地域 ['北海道', 'ニュース', 'UHB', '死者', '44人', '建物', '被害', 'が']
# [188] 都の感染者204人 20代が最多 国内 ['東京都', 'に', 'よる', 'と', '30日', 'に', '都', 'が']
# [189] 石崎議員に罰金20万円 おわび 地域 ['NST', '新潟総合テレビ', '去年', '車内', 'で', '元', '秘書', 'の']
# [190] ハロウィン 自治体で判断に差 国内 ['31日', 'に', '迫っ', 'た', 'ハロウィーン', '例年', '繁華街', 'に']
# [191] G大阪の不祥事 監督は衝撃大 スポーツ ['ガンバ大阪', 'の', '宮本恒靖', '監督', '43', 'が', '30日', 'オンライン']
# [192] NTC 体操練習場の利用中止 スポーツ ['体操', 'の', '内村航平', '選手', 'リンガーハット', 'の', '新型コロナウイルス', '感染']
# [193] JR西日本 中間決算初の赤字 経済 ['JR西日本', 'が', '30日', '発表', 'し', 'た', '2020年', '9月']
# [194] 北 韓国人射殺は「自衛措置」 国際 ['ソウル', '30日', 'ロイター', '北朝鮮', '国営', 'の', '朝鮮中央通信社', 'KCNA']
# [195] 検査1日6万件に引き上げへ 都 国内 ['12', '東京都', 'の', '小池百合子知事', 'は', '30日', 'の', '定例記者会見']
# [196] 国産ジェット開発費20分の1に 経済 ['三菱重工業', 'は', '2020年', '10月30日', '金', '2021年度', 'から', '2023年度']
# [197] JAL 赤字最大2700億円予想 経済 ['日本航空', 'は', '30日', '2021年', '3月', '期', 'の', '純']
# [198] 伊藤容疑者 近く釈放へ 国内 ['ひき逃げ', 'など', 'の', '疑い', 'で', '逮捕', 'さ', 'れ']
# [199] 9カ国・地域の感染危険度緩和 国内 ['茂木敏充', '外相', 'は', '30日', 'の', '記者会見', 'で', '新型コロナウイルス']
# [200] 説明十分?都構想あさって投票 国内 ['11月1日', 'の', '投開票', 'で', '賛否', 'が', '明らか', 'に']
# [201] スカヨハ 俳優と3度目の結婚 エンタメ ['映画', 'アベンジャーズ', 'シリーズ', 'の', 'ブラックウィドウ', '役', 'など', 'で']
# [202] 救急車 全国無料で高速OKに 国内 ['河野太郎', '行政改革', '相', 'は', '30日', 'の', '閣議後', '会見']
# [203] 五輪チケ払い戻し 11/10から スポーツ ['東京五輪', 'パラリンピック', '組織委員会', 'は', '30日', '新型コロナウイルス', 'の', '影響']
# [204] GoToクーポン不正 国が対策 国内 ['国', 'の', '観光', '支援', '事業', 'Go', 'To', 'トラベル']
# [205] 米選挙 運命握るカトリック票 国際 ['ピューリサーチセンター', 'が', '今月', '行っ', 'た', '調査', 'に', 'よる']
# [206] 休暇分散 西村氏経済界に要請 国内 ['西村康稔', '経済', '再生', '担当相', 'は', '30日', '午前', '経済3団体']
# [207] UPLINKのパワハラ訴訟 和解 エンタメ ['今年6月', 'パワハラ', 'で', '元従業員', 'ら', 'に', '提訴', 'さ']
# [208] インフル接種 予約終了病院も 科学 ['冬', 'を', '控え', 'インフルエンザ予防接種', 'の', '予約', 'が', '医療機関']
# [209] LIXIL 希望退職1200人募集 経済 ['住宅', '設備', '大手', 'の', 'LIXIL', 'リクシルグループ', 'は', '30日']
# [210] 精神疾患で自殺 29日以下51% 国内 ['政府', 'は', '30日', '労働', '現場', 'の', '過労', 'の']
# [211] 渋野 2度目のホールインワン スポーツ ['樋口久子', '三菱電機', 'レディース', '初日', '女子ゴルフ', 'の', '樋口久子', '三菱電機']
# [212] 引き揚げ者住宅巡り退去命令 国内 ['太平洋戦争', '後', '旧', '満州', 'など', 'から', 'の', '引き揚げ']
# [213] 日本食?英料理番組に批判殺到 国際 ['ロンドン', '時事', '英', '放送局', 'チャンネル', '4', 'の', '人気']
# [214] 伊藤容疑者 事故分かっていた 国内 ['Nippon', 'News', 'Network', 'NNN', '東京渋谷区', 'で', '車', 'を']
# [215] GoTo観光以外は除外へ 国交相 国内 ['赤羽一嘉', '国土交通相', 'は', '30日', 'の', '閣議後', '記者会見', 'で']
# [216] GAFA3社最高益 際立つ好業績 経済 ['ニューヨーク', '共同', 'GAFA', 'と', '呼ば', 'れる', '米', '巨大']
# [217] NZの国民投票 安楽死賛成65% 国際 ['シドニー', '時事', '今月17日', 'の', 'ニュージーランド', 'NZ', '総選挙', 'に']
# [218] JAL ヤマトなどに500人出向 経済 ['日本航空', 'から', '外部', '企業', 'に', '一時', '的', 'に']
# [219] 元非行少年 厳罰化は解決策か 国内 ['1819', '歳', 'を', '現行', 'より', 'も', '厳罰', '化']
# [220] 転落巻き添え 遺族への補償は 国内 ['阪急', '大阪梅田駅', '近く', 'の', '繁華街', 'で', '10月23日', 'に']
# [221] 米ウォルマート 店から銃撤去 国際 ['ニューヨーク', '共同', '米', '小売り', '大手', 'ウォルマート', 'は', '29日']
# [222] 「今日俺」ポスター撤去 県警 地域 ['人気', '俳優', 'の', '伊藤健太郎', 'いとう', 'けんたろう', '容疑者', '23']
# [223] 企業の内部留保 8年連続で増 経済 ['12', '財務省', 'が', '30日', '発表', 'し', 'た', '2019年度']
# [224] 伊藤健太郎容疑者を送検 国内 ['All', 'Nippon', 'NewsNetworkANN', '東京渋谷区', 'で', 'ひき逃げ', '事件', 'を']
# [225] 川重 バイク生産を分社化へ 経済 ['大手', '重工', 'メーカー', 'の', '川崎重工業', '神戸市中央区', 'が', '新型コロナウイルス']
# [226] 0円で町が温泉売却 応募ゼロ? 国内 ['湯', 'どころ', 'として', '知ら', 'れる', '岩手県西和賀町', 'が', '町営']
# [227] 平野ノラ42歳 第1子を妊娠 エンタメ ['2017年', 'に', '一般男性', 'と', '結婚', 'し', 'た', '平野ノラ']
# [228] 巨額詐欺 倉庫の6千万円押収 国内 ['家庭', '用', '磁気', '商品', 'の', 'オーナー', '販売', '預託商法']
# [229] 米 UAEにF35を売却する方針 国際 ['ワシントン', '時事', 'トランプ', '米', '政権', 'は', '29日', 'アラブ首長国連邦']
# [230] SB周東 普通はできない走塁術 スポーツ ['1992年', 'に', '盗塁王', 'の', 'タイトル', 'を', '獲得', 'し']
# [231] 虎・福留が退団明言 現役続行 スポーツ ['阪神', 'の', '福留孝介', '外野手', '43', 'が', '29日', '鳴尾浜球場']
# [232] クラスター 全国で1761カ所に 国内 ['新型コロナウイルス', 'の', '感染拡大', 'に', '伴い', '全国各地', 'で', '発生']
# [233] 大阪市 4分割コスト試算撤回 国内 ['大阪市', 'を', '四つ', 'の', '自治体', 'に', '分割', 'し']
# [234] 石破派混乱「空中分解」の声 国内 ['自民党', '石破派', '水月会', 'で', '石破茂', '前', '会長', 'の']
# [235] 鬼滅 既刊22巻ランキング独占 エンタメ ['吾峠呼世晴', '鬼滅の刃', 'の', '最新', '22巻', 'が', '週間', '326']
# [236] 大竹しのぶ 芸歴47年初の月9 エンタメ ['女優', 'の', '大竹しのぶ', 'が', '11月30日', 'に', '放送', 'さ']
# [237] 芸能界と事故 運転禁止の傾向 エンタメ ['伊藤健太郎', '容疑者', 'ひき逃げ', 'の', '疑い', 'で', '逮捕', '2020年']
# [238] 斎藤佑 初の1軍登板なしに スポーツ ['日本ハム', 'の', '吉村', '浩', 'GM', 'が', '29日', 'オリックス']
# [239] ゴーン被告支援 2人引き渡しへ 国際 ['ボストン', '29日', 'ロイター', '米', '国務省', 'は', '日産自動車', '7201']
# [240] 伊藤容疑者 数億円の違約金か エンタメ ['俳優', '伊藤健太郎', '容疑者', '23', 'が', '自動車運転処罰法', '違反', '過失']
# [241] 仏 テロ警戒水準を最高に 国際 ['パリ', '共同', 'フランス南部', 'ニース', '中心部', 'の', 'ノートルダム教会', 'で']
# [242] 内村の感染 五輪関係者に衝撃 スポーツ ['国際体操連盟', 'の', '渡辺', '守成', '会長', 'が', '29日', '緊急会見']
# [243] 表紙に伊藤容疑者 小説誌変更 国内 ['俳優', 'の', '伊藤健太郎', '容疑者', '23', 'が', '道路交通法違反', 'ひき逃げ']
# [244] 雇用助成の特例 来年も継続へ 経済 ['企業', 'が', '従業員', 'に', '支払う', '休業手当', 'の', '一部']
# [245] ELLYもう親バカ?本当かわいい エンタメ ['人気グループ', '三', '代目', 'J', 'SOUL', 'BROTHERS', 'の', 'ELLY']
# [246] 習近平氏の長期政権化へ攻防 国際 ['北京', '西見由章', '29日', '閉幕', 'し', 'た', '中国共産党', 'の']
# [247] 学術会議会長 首相に反論 国内 ['日本学術会議', 'の', '梶田隆章', '会長', 'ら', '幹部', '4人', 'は']
# [248] 伊藤容疑者「気が動転した」 国内 ['車', 'を', '運転', '中', 'に', 'バイク', 'と', '衝突']
# [249] 米GDP、過去最大の33.1%増 経済 ['米', '商務省', 'が', '29日', '発表', 'し', 'た', '2020年']
# [250] アンゴラ村長 縄跳びでギネス エンタメ ['お笑いコンビ', 'にゃんこスター', 'の', 'アンゴラ村長', 'が', '“', 'プロ', 'な']
# [251] 巨人 今季最悪5連敗でもM1に スポーツ ['セリーグ', '巨人', '2', '―', '5', 'DeNA', '2020年', '10月29日']
# [252] 石破派 竹下派と合流構想浮上 国内 ['自民党', 'の', '石破茂', '元', '幹事長', 'が', '会長', '辞任']
# [253] 在サウジ仏領事館で刃物襲撃 国際 ['AFP', '時事', '更新', '写真', '追加', 'サウジアラビア', 'ジッダ', 'Jeddah']
# [254] 福島県 人件費求め東電を提訴 地域 ['県', 'は', '2013年度', 'に', '原発事故', 'の', '対応', 'で']
# [255] ワクチン供給3社目 政府契約 国内 ['厚生労働省', 'は', '29日', '米', 'バイオテクノロジー', '企業', 'モデルナ', 'が']
# [256] 仏で刃物襲撃3人死亡 テロか 国際 ['AFP', '時事', '更新', '写真', '追加', 'フランス南部', 'ニース', 'Nice']
# [257] ドンキ前社長 株取引で不正か 国内 ['Nippon', 'News', 'Network', 'NNN', 'ディスカウントストア', 'の', 'ドンキホーテ', 'など']
# [258] 伊藤容疑者 NHKドラマを降板 エンタメ ['NHK', 'は', '29日', '伊藤健太郎', '容疑者', 'が', '出演予定', 'だっ']
# [259] 内村航平が新型コロナ陽性 スポーツ ['国際体操連盟', 'FIG', 'の', '渡辺', '守成', '会長', 'ら', 'が']
# [260] 香港 国安法違反で活動家起訴 国際 ['AFP', '時事', '香港当局', 'は', '29日', '6月', 'に', '解散']
# [261] くそたれ地震 不満のみ込む今 地域 ['北海道', 'ニュース', 'UHB', '死者', '44人', '建物', '被害', 'が']
# [262] GoToイート紙切れ 担当者憤り 地域 ['新型コロナウイルス', 'の', '影響', 'で', '打撃', 'を', '受け', 'た']
# [263] 週末 東日本で冷え込み強まる 国内 ['明日', '30日', '金', 'は', '上空', 'の', '寒気', 'が']
# [264] SB周東が12戦連続盗塁 プロ新 スポーツ ['ソフトバンクロッテ', '29日', 'ペイペイドーム', 'ソフトバンク', '周東', 'が', '12試合', '連続']
# [265] TDR運営 511億円赤字の見通し 経済 ['オリエンタルランド', 'は', '29日', '2021年', '3月', '期', 'の', '連結']
# [266] 伊藤容疑者 事故直後の映像 国内 ['FNN', 'プライム', 'オンライン', '29日', 'ひき逃げ', 'など', 'の', '疑い']
# [267] 日本初 糖質0ビールどう実現 ライフ ['糖質ゼロ', 'と', 'いえ', 'ば', '発泡酒', 'や', '第三のビール', 'で']
# [268] 給食で100人超食中毒 鶏に菌 国内 ['東京都', 'は', '29日', '中野', '区立', '中野', '第一小学校', 'で']
# [269] ビシエド抹消 打点王は絶望的 スポーツ ['中日', 'の', 'ダヤンビシエド', '内野手', '31', 'が', '29日', '出場選手登録']
# [270] 案里被告 参院本会議を欠席 国内 ['昨年7月', 'の', '参院選', '広島選挙区', 'を', '巡る', '大規模', '買収']
# [271] 「THE W」決勝進出10組が決定 エンタメ ['女性芸人', 'の', '中', 'から', '一番', '面白い', '“', '笑い']
# [272] 巨人 きょう優勝の条件は スポーツ ['巨人', 'は', 'リーグ2', '連覇', 'へ', '優勝', 'マジック', 'を']
# [273] ニトリ 島忠にTOB実施を発表 経済 ['家具', '製造', '販売', '大手', 'の', 'ニトリホールディングス', 'は', '29日']
# [274] ウイカ 尊敬するのはリンゴ エンタメ ['オーディション', 'で', 'ひな壇', 'の', '座', 'を', '勝ち取る', 'アイドル']
# [275] 鈴木氏の出馬断念 知事は驚き 地域 ['来年', '春', 'の', '千葉県知事選', 'を', '巡り', '森田健作知事', '70']
# [276] 東京都 新たに221人感染確認 国内 ['東京都', 'に', 'よる', 'と', '29日', 'に', '都', 'が']
# [277] 伊藤容疑者 とんかつDJは公開 エンタメ ['道交法違反', 'ひき逃げ', 'など', 'の', '疑い', 'で', '俳優', 'の']
# [278] トヨタ、9月生産が過去最高 経済 ['トヨタ自動車', 'が', '29日', '発表', 'し', 'た', '9月', 'の']
# [279] GoToイベント 第1弾にUSJ 経済 ['経済産業省', 'は', '29日', '新型コロナウイルス', '対策', 'の', '需要', '喚起']
# [280] 歓楽街に検査拠点を 分科会 国内 ['政府', 'の', '新型コロナウイルス感染症', '対策', '分科会', 'が', '29日', '開か']
# [281] AIでいじめ対策 7市導入検討 国内 ['いじめ', '被害', 'を', '減らす', 'ため', '大津市', 'など', 'が']
# [282] 国内感染者 客船含め10万人超 国内 ['東京都', 'で', '29日', 'に', '新型コロナウイルス', 'の', '感染者', 'が']
# [283] デンソー中間決算赤字711億円 経済 ['トヨタ自動車', '系', 'の', '部品', 'メーカー', 'デンソー', 'が', '29日']
# [284] 伊藤容疑者 目撃者が追い説得 国内 ['28日', '午後5時', '45分', '頃', '東京都渋谷区千駄ヶ谷', 'の', '都道', '交差点']
# [285] 日銀 大規模緩和の維持決定 経済 ['日銀', 'は', '29日', '前日', 'に', '続い', 'て', '金融政策決定会合']
# [286] 伊藤容疑者逮捕 事務所が謝罪 エンタメ ['道交法違反', 'ひき逃げ', 'など', 'の', '疑い', 'で', '警視庁', 'に']
# [287] フジ 伊藤容疑者番組差し替え エンタメ ['フジテレビ', 'は', '29日', '道路交通法違反', '容疑', 'ひき逃げ', 'で', '逮捕']
# [288] 行き過ぎ指導 元生徒が提訴 地域 ['HOME', '広島ホームテレビ', '行き過ぎ', 'た', '指導', 'により', '退学', 'を']
# [289] 再審無罪 宮田浩喜さんが死去 地域 ['1985年', 'に', '熊本県宇城市', '松橋町', 'で', '男性', '当時', '59']
# [290] 李元大統領に懲役17年確定 国際 ['ソウル', '共同', '韓国', '最高裁', 'は', '29日', '大統領', '在職']
# [291] 第一生命 企業年金利率下げる 経済 ['第一生命保険', 'は', '29日', '企業年金', '保険', 'を', '運用', 'する']
# [292] 伊藤容疑者 事故現場離れた 国内 ['俳優', 'の', '伊藤健太郎', '容疑者', '23', 'が', '10月28日', '夜']
# [293] エビ中・安本彩花 治療で休養 エンタメ ['私立恵比寿中学', 'の', '安本彩花', 'が', '悪性リンパ腫', 'の', '診断', 'を']
# [294] 男性不妊 語る治療の難しさ 国内 ['27日', 'の', '記者会見', 'で', '女性', 'だけ', 'で', 'なく']
# [295] スノボ五輪銅 平岡被告に有罪 国内 ['追突事故', 'を', '起こし', '飲酒運転', 'の', '発覚', 'を', '免れる']
# [296] 伊藤健太郎容疑者を逮捕 国内 ['乗用車', 'を', '運転', '中', 'に', 'バイク', 'と', '衝突事故']
# [297] 政府 多機能イージス艦新造へ 国内 ['政府', 'が', '地上', '配備', '型', '迎撃', 'システム', 'イージスアショア']
# [298] 家に犬164匹 多頭飼育崩壊か 国内 ['島根県出雲市', 'の', '民家', 'で', '今月', '160', '匹', '以上']
# [299] 伊藤健太郎さん事故 女性重傷 国内 ['俳優', 'の', '伊藤健太郎', 'さん', 'が', 'きのう', '東京渋谷区', 'で']
# [300] 競技場の盗撮 対策の難しさ 国内 ['女子', 'アスリート', 'の', '胸', 'や', 'お', '尻', 'を']
# [301] 首里城火災1年あの日の悔しさ 地域 ['首里城', '火災', 'あれから', '1年', '上', '1031', '当日', '昨年']
# [302] 米 WTO事務局長の選出を阻止 国際 ['ロンドン', '時事', '世界貿易機関', 'WTO', 'の', '空席', 'と', 'なっ']
# [303] 行き過ぎ指導 元生徒が提訴へ 国内 ['行き過ぎ', 'た', '生徒指導', 'により', '退学', 'を', '余儀なく', 'さ']
# [304] ニトリ、島忠の全株取得へ 経済 ['家具', '日用品', '大手', 'の', 'ニトリホールディングス', 'が', 'ホームセンター', '中堅']
# [305] 仏 ロックダウン再導入へ 国際 ['AFP', '時事', '更新', 'フランス', 'の', 'エマニュエルマクロン', 'Emmanuel', 'Macron']
# [306] 鬼滅 ファンが生んだ「聖地」 エンタメ ['今や', '社会現象', 'と', 'なっ', 'て', 'いる', 'アニメ', '鬼滅の刃']
# [307] 鈴木大地氏 知事選出馬を断念 地域 ['来年4月', 'の', '任期満了', 'に', '伴う', '千葉県知事選', 'で', '自民党']
# [308] 深田恭子 新婚生活を「妄想」 エンタメ ['年々', '美し', 'さ', 'と', '輝き', 'を', '増す', '女優']
# [309] GoTo 電子クーポン不正取得か 国内 ['All', 'Nippon', 'NewsNetworkANNGoTo', 'トラベル', 'キャンペーン', 'の', '期間', '延長']
# [310] YouTuber事務所VAZ 社長退任 エンタメ ['大手', 'ユーチューバー', '事務所', 'VAZ', 'の', '森', '泰輝', '氏']
# [311] NY株943ドル安 3カ月ぶり安値 経済 ['ニューヨーク', '共同', '28日', 'の', 'ニューヨーク株式市場', 'の', 'ダウ工業株30種平均', 'は']
# [312] 阪神一筋の上本博紀 退団へ スポーツ ['阪神', 'の', '上本博紀', '内野手', '34', 'が', '球団', 'から']
# [313] 白石 卒コンで何度も「幸せ」 エンタメ ['人気', 'アイドルグループ', '乃木坂46', 'の', '白石麻衣', '28', 'が', '28日']
# [314] 錦織圭 右肩負傷で今季終了 スポーツ ['錦織圭', '男子テニス', 'で', '世界ランク', '37位', 'の', '錦織圭', 'は']
# [315] 白石 卒コン序盤から涙腺崩壊 エンタメ ['乃木坂46', '白石麻衣', '28', 'の', '卒業コンサート', 'NOGIZAKA', '46', 'Mai']
# [316] かんぽ不正 新たに490人処分 経済 ['日本郵政グループ', 'は', '28日', '傘下', 'の', 'かんぽ生命保険', 'の', '不適切']
# [317] 関テレ デヴィ夫人発言で謝罪 ライフ ['関西テレビ', '大阪市', 'は', '28日', '関西地区', 'など', 'で', '24日']
# [318] 4連敗 G監督そうですね10連発 スポーツ ['DeNA', '106', '巨人', '28日', '横浜', '巨人', 'は', '今季']
# [319] 森元首相 鈴木大地氏出馬に反対 国内 ['東京五輪', 'パラリンピック', '組織委員会', '会長', 'の', '森喜朗', '元首相', 'は']
# [320] シリアの停戦 崩壊の危機に 国際 ['カイロ', '共同', 'トルコ', 'の', 'エルドアン', '大統領', 'は', '28日']
# [321] 今年台風上陸なし?幸運重なる 国内 ['昨年', '日本列島', 'に', '再三', '上陸', 'し', 'て', '甚大']
# [322] SB周東11試合連続盗塁に成功 スポーツ ['ソフトバンクロッテ', '28日', 'ペイペイドーム', 'ソフトバンク', '周東', 'が', '3回', '二死']
# [323] 時速380km「圧力感じない」 地域 ['仙台放送', '時速', '380キロ', 'の', '世界', 'を', '体験', 'です']
# [324] 大麻所持 東海大生ら2人逮捕 国内 ['FNN', 'プライム', 'オンライン', '東海大学', 'の', '学生', 'ら', 'が']
# [325] JTB 転勤でも引っ越しせずOK 経済 ['旅行', '大手', 'の', 'JTB', 'は', '28日', '従来', 'なら']
# [326] 嵐が謝罪 中日「恐縮です」 エンタメ ['プロ野球', 'の', '〝', '試合', '中断', '騒動', '〟', 'を']
# [327] コロナ感染「微増傾向続く」 国内 ['新型コロナウイルス', '対策', 'を', '助言', 'する', '厚生労働省', 'の', '専門家']
# [328] 集配所殺傷 遺族「許さない」 地域 ['神戸市北区', 'の', 'ヤマト運輸', '配送センター', 'で', '従業', '員', 'の']
# [329] 日立製作所 営業利益39%減 経済 ['日立製作所', 'が', '28日', '発表', 'し', 'た', '20年', '9月']
# [330] 紙不足 京都がGoTo食事券停止 国内 ['新型コロナウイルス', 'の', '影響', 'で', '打撃', 'を', '受け', 'た']
# [331] 三代目ELLYがパパに 結婚せず エンタメ ['三代目', 'J', 'SOUL', 'BROTHERS', 'の', 'パフォーマー', 'ELLY', '33']
# [332] 菅首相 任命拒否の判断変えず 国内 ['菅首相', 'は', '28日', '午後', '衆院本会議', 'の', '代表質問', 'で']
# [333] JR東海 純損益1135億円の赤字 経済 ['JR東海', 'が', '28日', '発表', 'し', 'た', '2020年', '9月']
# [334] 調布の陥没 東日本高速が陳謝 国内 ['東京都調布市', 'の', '東京外郭環状道路', 'トンネル', '工事', '現場近く', 'で', '起き']
# [335] 貯水槽に男性遺体 殺人で捜査 地域 ['28日', '午前11時', '5分', 'ごろ', '千葉県印西市小林', 'の', '防火', '貯水槽']
# [336] 若年女性の失業4.7% 最も悪化 経済 ['新型コロナウイルス', '感染拡大', 'の', '影響', 'で', '雇用', '環境', 'が']
# [337] 土砂崩れ作業員1人死亡 大阪 国内 ['28日', '正午', '頃', '大阪府茨木市千提寺', 'の', '資材', '置き場', 'で']
# [338] 試合中断 嵐がおわびの色紙 エンタメ ['24日', 'に', 'アイドルグループ嵐', 'が', '国立競技場', 'で', '行っ', 'た']
# [339] アパート内で豚解体 4人逮捕 国内 ['許可', 'を', '得', 'て', 'い', 'ない', '場所', 'で']
# [340] 漁業被害 アザラシがゴロゴロ 国内 ['冬', 'が', '近づく', '中', '北海道北', 'の', '宗谷', '地域']
# [341] デヴィ夫人 不妊巡る発言謝罪 エンタメ ['デヴィ夫人', 'こと', 'タレント', 'の', 'デヴィスカルノ', '氏', 'が', '28日']
# [342] 土砂崩れ1人心肺停止 大阪 地域 ['大阪府茨木市', 'の', '土木工事', '会社', 'の', '資材', '置き場', 'で']
# [343] 正月休み分散 自民幹部が苦言 国内 ['自民党', 'の', '下村博文', '政調会長', 'は', '28日', '新型コロナウイルス', '感染拡大']
# [344] 首相 任命拒否の違法性否定 国内 ['菅首相', 'は', '28日', '午後', '衆院本会議', 'の', '代表質問', 'で']
# [345] 東京都 新たに171人感染確認 国内 ['東京都', 'に', 'よる', 'と', '28日', 'に', '都', 'が']
# [346] 大好きだった祖母殺害 介護限界 国内 ['黒髪', 'を', 'キュッと', '結ん', 'だ', 'ポニーテール', '白い', 'ブラウス']
# [347] 6人死傷火災 元店長に有罪 地域 ['2015年', 'に', '3人', 'が', '死亡', 'し', '3人', 'が']
# [348] 国税庁「路線価」引き下げず 経済 ['国税庁', 'は', '28日', '相続税', 'や', '贈与税', 'の', '算定']
# [349] MLBド軍優勝 監督は沖縄出身 スポーツ ['6回', 'に', 'ベッツ', 'の', '好', '走塁', 'で', '逆転']
# [350] ノブコブ徳井、離婚していた エンタメ ['お笑いコンビ', '平成ノブシコブシ', 'の', '徳井健太', '40', 'が', '27日', 'に']
# [351] 加藤氏 原発の新増設想定せず 国内 ['加藤勝信', '官房長官', 'は', '28日', '午前', 'の', '記者会見', 'で']
# [352] 三男死なせた長女 家族に何が 国内 ['知的障害', 'が', 'ある', '長女', 'が', '自宅', 'で', '三男']
# [353] MLBドジャース32年ぶり世界一 スポーツ ['レイズ', '13', 'ドジャース', 'グローブライフフィールド', 'ドジャース', 'は', 'レイズ', 'と']
# [354] 感染対策が不足 受刑者が提訴 地域 ['読売テレビ', '刑務所', '内', 'の', '新型コロナウイルス', 'へ', 'の', '対策']
# [355] 大塚家具 久美子社長が辞任へ 経済 ['大塚家具', 'の', '社名', 'は', 'そのまま', '変え', 'ない', '方針']
# [356] ハワイ 日本の観光客受け入れ 国際 ['FNN', 'プライム', 'オンライン', '新型コロナウイルス', 'の', '影響', 'で', '訪問']
# [357] メッシと対立 バルサ会長辞任 スポーツ ['前日', 'に', 'は', '辞任', 'が', '頭', 'を', 'よぎっ']
# [358] 北海道 警戒ステージ引き上げ 地域 ['北海道', 'は', '28日', '午前', 'の', '新型コロナウイルス感染症対策本部', '会議', 'で']
# [359] 戦略違う?みちょぱ&ゆきぽよ エンタメ ['昨今', 'の', 'ギャル', 'タレント', 'を', 'けん引', 'する', '二大巨頭']
# [360] 間宮祥太朗 成田凌から相談も エンタメ ['15歳', 'の', '役者', 'デビュー', '以降', 'コメディ', 'から', 'シリアス']
# [361] 間宮祥太朗 ブレイクなかった エンタメ ['15歳', 'の', '役者', 'デビュー', '以降', 'コメディ', 'から', 'シリアス']
# [362] 携帯値下げ SBとKDDIが新料金 経済 ['All', 'Nippon', 'NewsNetworkANN', '政府', 'の', '携帯', '料金', '引き下げ']
# [363] 静岡銀と山梨中銀が提携へ 経済 ['静岡銀行', 'と', '山梨中央銀行', 'が', '業務', '提携', 'する', 'こと']
# [364] 国家公務員の月給 据え置きへ 国内 ['人事院', 'は', '28日', '2020年度', 'の', '国家公務員', '月給', 'について']
# [365] ALFA-X初試乗会 時速382km 国内 ['JR東日本', 'は', '27日', '深夜', 'から', '翌日', '未明', 'にかけ']
# [366] 鬼滅特需も 続くシネコン苦境 エンタメ ['鬼滅の刃', '異例', 'の', '大', 'ヒット', '今年', '最大', 'の']
# [367] 米で警官撃ち黒人死亡 波紋 国際 ['Nippon', 'News', 'Network', 'NNN', '1週間', '後', 'に', '迫っ']
# [368] 首里城再建の寄付 50億円突破 地域 ['首里城', '火災', 'から', '31日', 'で', '1年', 'が', 'たつ']
# [369] 卒後3年は新卒扱い 政府要請  経済 ['田村憲久', '厚生労働相', 'は', '27日', '萩生田光一', '文部科学相', '坂本哲志', '1億総活躍']
# [370] トヨタ系に出向 三菱重が打診 経済 ['東京', '28日', 'ロイター', '新型コロナウイルス', 'の', '影響', 'で', '業績']
# [371] ツキヨタケ中毒相次ぐ 県注意 地域 ['毒キノコ', 'ツキヨタケ', 'の', '食中毒', '発生', 'が', '県内', 'で']
# [372] 学術会議 官邸14年選考も関心 国内 ['日本学術会議', 'が', '推薦', 'し', 'た', '会員', '候補', '6人']
# [373] 陸上コールマン 五輪は絶望的 スポーツ ['陸上', '男子', '100メートル', 'で', '19年', '世界選手権', '金', 'メダリスト']
# [374] 「女性活躍」重い?現場の疲弊 地域 ['輝け', '輝け', 'って', 'ホタル', 'じゃ', 'ない', 'ん', 'だ']
# [375] 米、香港活動家の亡命拒絶か 国際 ['香港', '共同', '香港', '英字紙', 'サウスチャイナモーニングポスト', '電子版', 'は', '27日']
# [376] 米大統領選まで1週間 接戦へ 国際 ['ワシントンロサンゼルスウォームスプリングス', '米', 'ジョージア州', '27日', 'ロイター', '米大統領選', 'が', '1週間']
# [377] 伊の新規感染2.2万人過去最多 国内 ['ローマ', '共同', 'イタリア政府', 'は', '27日', '新型コロナウイルス', 'の', '感染者']
# [378] ANA 「再浮揚」なお視界不良 経済 ['ANAホールディングス', 'HD', 'が', '27日', '発表', 'し', 'た', '事業']
# [379] 消費税不正 40億円を追徴課税 国内 ['国税', '当局', 'が', '全国', 'の', '免税店', 'など', 'を']
# [380] 病で収監延期 田代まさしの今 エンタメ ['2019年', '11月', 'に', '覚醒剤取締法', '違反', 'の', '罪', 'など']
# [381] GoToトラベル延長へ 政府調整 国内 ['政府', '与党', 'は', '27日', '来年1月', '末', 'に', '期限']
# [382] FIFA会長がコロナ陽性 隔離 スポーツ ['国際サッカー連盟', 'FIFA', 'は', '27日', 'ジャンニインファンティーノ', '会長', '50', 'が']
# [383] ミラクル9 入社1年目アナ起用 エンタメ ['テレビ朝日', '系', 'で', '放送', '中', 'の', 'クイズ番組', 'ミラクル9']
# [384] LVMH ティファニー買収再交渉 経済 ['ニューヨーク', '27日', 'ロイター', '仏', '高級', 'ブランド', 'LVMH', 'モエヘネシールイヴィトン']
# [385] 斎藤佑樹 右肘手術を検討  スポーツ ['日本ハム', 'の', '斎藤佑樹', '投手', '32', 'が', '右肘', 'の']
# [386] SB内川退団へ 現役続行は模索 スポーツ ['2軍', 'で', '結果', 'も', '今季', '1軍', '昇格', 'なし']
# [387] 個人番号夜間も対応を 総務相 国内 ['武田良太', '総務相', 'は', '27日', 'の', '閣議後', '記者会見', 'で']
# [388] SB優勝 ロボット踊る祝勝会 スポーツ ['ソフトバンク', '51', 'ロッテ', '27日', 'ペイペイドーム', 'ソフトバンク', 'は', '優勝']
# [389] ANA コロナ後にらみ雇用維持 経済 ['ANAホールディングス', 'HD', 'が', '27日', 'に', '事業', '構造改革', 'で']
# [390] トランプ氏 本当に負けるのか 国際 ['1週間', '後', 'に', '控える', '米大統領選', 'で', '再選', 'を']
# [391] コロチキ西野 第1子男児誕生 エンタメ ['お笑いコンビ', 'コロコロチキチキペッパーズ', 'の', '西野創人', '29', 'が', '27日', '自身']
# [392] 中国 35年にガソリン車全廃へ 国際 ['中国工業', '情報化', '省', 'など', 'は', '27日', '2035年', 'に']
# [393] SBがV奪回 裏に「老将の知」 スポーツ ['ソフトバンク', '51', 'ロッテ', '27日', 'ペイペイドーム', 'ソフトバンク', 'が', '27日']
# [394] 「17連休」要請 西村氏が否定 国内 ['西村康稔', '経済', '再生', '担当相', 'は', '27日', 'の', '記者会見']
# [395] 河井案里被告を保釈 国内 ['昨年7月', 'の', '参院選', '広島選挙区', 'を', '巡る', '大規模', '買収']
# [396] ソフトバンク3年ぶり優勝 スポーツ ['ソフトバンク', '51', 'ロッテ', '27日', 'ペイペイドーム', 'パリーグ', '優勝', 'へ']
# [397] 座間事件 2つのアカ使い接触 国内 ['All', 'Nippon', 'NewsNetworkANN', 'ツイッター', 'で', '異なる', 'キャラクター', 'を']
# [398] ロイヤルHD早期退職200人募集 経済 ['ロイヤルホールディングス', 'HD', '福岡市', 'は', '27日', '12月', '末', '時点']
# [399] 大阪 新たに142人の感染確認 地域 ['大阪府', 'は', '27日', '新た', 'に', '142人', 'の', '新型コロナウイルス']
# [400] 原子力規制委に不正アクセス 国内 ['原子力規制委員会', 'は', '27日', '全', '職員', 'が', '利用', 'する']
# [401] 発言物議 デヴィ夫人は反論 国内 ['デヴィ夫人', 'こと', 'タレント', 'の', 'デヴィスカルノ', 'さん', 'が', '不妊']
# [402] KDDI 20ギガ4千円弱で調整 経済 ['KDDI', 'が', '携帯電話', 'の', '料金', '体系', 'を', '見直し']
# [403] 日立金属 3200人リストラへ 経済 ['日立製作所', 'の', '上場', '子会社', 'の', '日立金属', 'は', '27日']
# [404] 西武1位 爆笑会見の裏明かす スポーツ ['西武', 'から', 'ドラフト1位指名', 'さ', 'れ', 'た', '桐蔭横浜大', '渡部']
# [405] 作家・大城立裕さん死去 95歳 地域 ['沖縄出身', '者', 'で', '初', 'の', '芥川賞', 'を', '受賞']
# [406] エコリカがキヤノンを提訴 国内 ['キヤノン', '東京', 'が', 'インクカートリッジ', 'の', '仕様', 'を', '変更']
# [407] GWまでGoToの継続を 公明提言 国内 ['Nippon', 'News', 'Network', 'NNN', '公明党', 'は', '菅総理', '大臣']
# [408] 克行被告の公判 11月4日再開 国内 ['昨年7月', 'の', '参院選', 'で', '公職選挙法違反', '加重', '買収', 'など']
# [409] 脱臼 首位打者DeNA佐野を抹消 スポーツ ['セリーグ', '首位打者', 'の', 'DeNA', '佐野恵太', '内野手', '25', 'が']
# [410] 米 対中関税巡りWTOに上訴 経済 ['ブルームバーグ', 'トランプ', '米', '政権', 'は', '26日', '中国', 'から']
# [411] 西武1位 会見で頭が真っ白 スポーツ ['西武', 'から', 'ドラフト1位指名', 'さ', 'れ', 'た', '桐蔭横浜大', '渡部']
# [412] LCC新ブランド立ち上げへ ANA 経済 ['エアージャパン', '活用', 'ANA', 'の', 'ボーイング787', '型', '機', 'を']
# [413] 手越祐也 独立で「やりがい」 エンタメ ['手越', 'さん', 'の', '新居', 'は', '築', '年数', 'こそ']
# [414] 親子2人切られ父死亡 男逮捕 国内 ['27日', '午前8時', '前', '茨城県常陸太田市町屋町', 'の', '根本', '昇', 'さん']
# [415] 露の下院議員91人感染1人死亡 国際 ['モスクワ', '田村', '雄', 'ロシア', '議会', '下院', 'の', 'ビャチェスラフウォロジン']
# [416] 古坂大魔王 第2子女児誕生 エンタメ ['ピコ太郎', 'の', '“', 'プロデューサー', '”', 'こと', 'お笑いタレント', '古坂大魔王']
# [417] ギャグ打撃 ダチョウ久々キス エンタメ ['お笑いトリオ', 'ダチョウ倶楽部', 'が', '27日', '都内', 'で', '行わ', 'れ']
# [418] ANA 5100億円の赤字見通し 経済 ['ANAホールディングス', 'HD', 'は', '27日', '未定', 'と', 'し', 'て']
# [419] 東京都 新たに158人感染確認 国内 ['東京都', 'に', 'よる', 'と', '27日', 'に', '都', 'が']
# [420] ダチョウ倶楽部 久々のキス芸 エンタメ ['お笑いトリオ', 'ダチョウ倶楽部', 'が', '27日', '都内', 'で', '行わ', 'れ']
# [421] 血の入れ替え G最多19人指名 スポーツ ['プロ野球ドラフト会議', 'supported', 'by', 'リポビタンD', 'が', '26日', '都内', 'の']
# [422] 巨人メルセデス手術 今季絶望 スポーツ ['巨人', 'の', 'クリストファークリソストモメルセデス', '投手', '26', 'が', '左肘', 'の']
# [423] JAL 再上場後初の赤字見通し 経済 ['日本航空', 'JAL', 'の', '2021年', '3月', '期', '連結決算', 'の']
# [424] 携帯値下げへ3つの柱 総務省 経済 ['CopyrightC', 'Japan', 'News', 'Network', 'All', 'rights', 'reserved', '菅政権']
# [425] 漫才初 西川きよし文化功労者 エンタメ ['お笑いタレント', 'の', '西川きよし', '74', 'が', '27日', 'に', '政府']
# [426] 出産一時金 引き上げ含め検討 国内 ['田村憲久', '厚生労働相', 'は', '27日', 'の', '記者会見', 'で', '出産']
# [427] 野口さん搭乗 11月15日宇宙へ 科学 ['NASA', 'アメリカ航空宇宙局', 'は', '日本人宇宙飛行士', '野口聡一', 'さん', 'が', '搭乗']
# [428] 盗撮被害 女子選手が語る苦悩 国内 ['競技会', 'で', '女子', 'アスリート', 'の', 'パフォーマンス', 'を', '撮影']
# [429] 煉獄ファン「300億円の男に」 エンタメ ['興行収入', '107', '億', '円', 'を', '突破', 'し', 'た']
# [430] 再審無罪 女性に補償5997万円 国内 ['12', '滋賀県東近江市', 'の', '湖東', '記念病院', 'で', '2003年', 'に']
# [431] 判事承認 トランプ氏は自賛 国際 ['Nippon', 'News', 'Network', 'NNN', 'アメリカ大統領選挙', 'が', '1週間', '後']
# [432] 米大統領選 期日前6000万人に 経済 ['ワシントン', '26日', 'ロイター', '米', 'フロリダ大学', 'の', '米', '選挙']
# [433] 橋田寿賀子氏ら5人に文化勲章 ライフ ['12', '政府', 'は', '27日', '2020年度', 'の', '文化勲章', 'を']
# [434] 都構想 隣接2市も特別区移行? 国内 ['12', '大阪都構想', 'の', '住民投票', '11月1日', '投開票', 'の', '手続き']
# [435] 冬休み一律延長求めず 文科相 国内 ['萩生田光一', '文部科学相', 'は', '27日', 'の', '閣議後', '記者会見', 'で']
# [436] かつや好調 裏に高いシェア? 経済 ['飲食店', 'コンサルタント', 'の', '三ツ井', '創太郎', 'です', 'Go', 'To']
# [437] R・ナダル プロゴルフ大会6位 スポーツ ['AFP', '時事', '男子テニス', '世界ランク', '2位', 'の', 'ラファエルナダル', 'Rafael']
# [438] 逃げた警察犬を無事保護 兵庫 国内 ['兵庫県福崎町田口', 'の', '山中', 'で', '行方不明者', 'の', '捜索', '中']
# [439] 任命拒否想定せず 04年資料に 国内 ['日本学術会議', 'の', '任命', '拒否', '問題', 'を', '巡り', '推薦']
# [440] ネット中傷 裁判手続き創設へ 国内 ['総務省', 'は', '26日', 'インターネット上', 'で', '誹謗中傷', 'を', '受け']
# [441] 潜水漁業中2人溺れ死亡 沖縄 国内 ['26日', '午後10時', '40分', 'ごろ', '沖縄県糸満市', 'の', '喜屋武岬', 'の']
# [442] 河井案里被告の保釈認める 国内 ['昨年7月', 'の', '参院選', 'を', 'めぐり', '公職選挙法違反', '買収', 'の']
# [443] 所信表明「処理水」は触れず 国内 ['菅義偉', '首相', 'は', '26日', 'の', '所信表明演説', 'で', '福島']
# [444] 首相のガスゼロ宣言 国連評価 国際 ['ニューヨーク', 'ブリュッセル', '共同', 'グテレス', '国連事務総長', 'は', '26日', '菅義偉']
# [445] 保守派の米最高裁判事を承認 国際 ['米上院', '定数', '100', 'は', '26日', 'の', '本会議', 'で']
# [446] 目黒 強盗疑いで少年3人逮捕 国内 ['Nippon', 'News', 'Network', 'NNN', '26日', '東京目黒区', 'の', 'タワーマンション']
# [447] 沢村にMLB複数球団が興味か スポーツ ['ロッテ', '沢村拓一', '投手', '32', 'に', '複数', 'の', 'メジャー']
# [448] フィギュア今季GP 得点非公認 スポーツ ['ジュネーブ', '共同', '国際スケート連盟', 'ISU', 'の', '広報担当者', 'は', '26日']
# [449] 消える日立マーク 市民寂しさ 地域 ['日立製作所', '創業', 'の', '地', '日立市内', 'から', '日立', 'を']
# [450] 京都高島屋「くぼ地」店に幕 地域 ['12', '京都市', '下京区', '四条通', '河原町', 'に', 'ある', '京都']
# [451] 栃木知事選「魅力度」争点に 国内 ['今年', 'の', '都道府県', '魅力', '度', 'ランキング', 'で', '初めて']
# [452] EU ナイジェリアWTO候補支持 国際 ['ブリュッセル', '26日', 'ロイター', '欧州連合', 'EU', 'の', '当局者', 'は']
# [453] 政府 デジタル庁恒久化の方針 国内 ['政府', 'は', '来年', '中', 'の', '創設', 'を', 'めざす']
# [454] 製油所12カ所 耐震不足の恐れ 国内 ['南海トラフ地震', 'や', '首都直下地震', 'が', '起き', 'て', 'も', '石油']
# [455] 月の水 想定より大量に存在か 科学 ['AFP', '時事', '月面', 'に', 'は', 'これ', 'まで', '考え']
# [456] トランプ氏 南部州死守の重圧 国際 ['ワシントン', '時事', '来月3日', 'の', '米大統領選', 'まで', '27日', 'で']
# [457] 日産、中国の生産能力3割増へ 経済 ['日産自動車', 'が', '2021年', '中', 'に', '中国', 'で', 'の']
# [458] 乃木坂樋口 役作り30cm髪切る エンタメ ['人気', 'アイドルグループ', '乃木坂46', 'の', '樋口日奈', 'が', '2021年', '新春']
# [459] 広瀬すず「戦後初のCA」役に エンタメ ['広瀬すず', 'が', '2021年', '春', '放送', 'の', 'スペシャルドラマ', 'エア']
# [460] 指名漏れ妥当? 田沢に残る3択 スポーツ ['2020', 'ドラフト会議', '元', 'メジャー', '世界一', '右腕', 'を', '待ち受け']
# [461] Zeebra、家族と別居報道 エンタメ ['自分', 'の', '不甲斐ない', '行い', 'により', '大切', 'な', '家族']
# [462] NYダウ大幅続落 650ドル安 経済 ['ニューヨーク', '共同', '週明け', '26日', 'の', 'ニューヨーク株式市場', 'の', 'ダウ工業株30種平均']
# [463] ももクロ高城 阪神D1にエール エンタメ ['阪神', 'が', 'ドラフト1位', 'で', '交渉', '権', 'を', '獲得']
# [464] アント 史上最高額で上場へ 経済 ['上海', '共同', '中国', 'の', '電子商取引', '最大手', 'アリババグループ', '傘下']
# [465] 所信表明 言い間違い6カ所 国内 ['菅義偉', '首相', 'が', '26日', 'の', '所信表明演説', 'で', '新型コロナウイルス']

# %%
# 6は太宰治の「人間失格」です。
# 自分の人生に迷いながら苦悩するみたいな話だったはず。
# 最後は精神病院送りにされて、、重苦しいまま終わる感じだった。
ranking1 = model1.docvecs.most_similar(15, topn=50)

# %%
ranking1[:5] # コサイン類似度が大きい作品トップ5
# Out:
# [(104, 0.9998716115951538),
#  (421, 0.9998632669448853),
#  (65, 0.999862551689148),
#  (169, 0.9998478889465332),
#  (225, 0.9998416900634766)]

# %%
ranking1[-5:] # コサイン類似度が小さい作品トップ5
# Out:
# [(303, 0.999794602394104),
#  (16, 0.999794602394104),
#  (235, 0.9997944831848145),
#  (64, 0.999794065952301),
#  (460, 0.9997934699058533)]

# %%
le1 = preprocessing.LabelEncoder()

vecs1 = []
for i in range(len(model1.docvecs)):
    vecs1.append(model1.docvecs[i])
category1 = list(df['category'])
df1 = pd.DataFrame(vecs1)
df1.insert(0, 'category', category1)
df1.category = le1.fit_transform(df1.category)
dfs1 = df1.iloc[:, 1:].apply(lambda x: (x - x.mean()) / x.std(), axis=0)

# %%
pca1 = PCA()
pca1.fit(dfs1)
feature1 = pca1.transform(dfs1)

# %%
# 第一主成分と第二主成分でプロットする
plt.figure(figsize=(6, 6))
plt.scatter(feature1[:, 0], feature1[:, 1], alpha=0.8, c=list(df1.iloc[:, 0]))
plt.grid()
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()

# %%
# sentencesの中身を確認
for i, sentence in enumerate(sentences):
    if i < 5:
        print(sentence[:10])
# Out:
# ['10月16日', 'に', '公開', 'さ', 'れ', 'た', 'アニメ映画', '劇場版', '鬼滅の刃', '無限']
# ['お笑いコンビ', 'ニッチェ', 'の', '近藤くみこ', '37', 'が', '2日', '所属事務所', 'マセキ芸能社', 'の']
# ['衆院', '予算委員会', 'は', '2日', '午前', '菅義偉', '首相', 'と', '全閣僚', 'が']
# ['NHK', 'は', '2日', '今年', 'の', '大晦日', 'に', '放送', 'さ', 'れる']
# ['お世話', 'に', 'なっ', 'て', 'ばかり', 'で', '寂しい', 'です', '巨人', 'や']

# %%
# 自作のsortedTFIDF関数を用いてTF-IDF順にソートされたリストを得る。
sorted_texts_tfidf = sortedTFIDF(sentences)

# %%
# 作品ごとにTF-IDFの高い単語を確認
for i, tfidf in enumerate(sorted_texts_tfidf):
    if i < 5:
        print('%s.' % i, '〜%s〜' % df['title'][i]) # 一応タイトルも表示
        pprint(tfidf[:10])
        print('')
# Out:
# 0. 〜鬼滅の刃 歴代興収が10位に〜
# [[0.34561730502482435, '興行収入'],
#  [0.3346700856098662, '億'],
#  [0.24505678502326675, '円'],
#  [0.2167399272892577, '公開'],
#  [0.20737038301489458, '鬼'],
#  [0.17915377477976968, '動員'],
#  [0.17280865251241218, '無限'],
#  [0.17280865251241218, '列車'],
#  [0.14932676925199329, '炭'],
#  [0.12675718898578303, '万']]
#
# 1. 〜ニッチェ近藤が結婚を報告〜
# [[0.3488586476327346, 'ニッチェ'],
#  [0.26164398572455094, '近藤くみこ'],
#  [0.2574769142322737, '致し'],
#  [0.23212700791578275, '近藤'],
#  [0.21486068276303485, '入籍'],
#  [0.1744293238163673, '江上'],
#  [0.1744293238163673, '宜しく'],
#  [0.16359070786543706, 'お願い'],
#  [0.15475133861052182, '似顔絵'],
#  [0.15388144422744035, '報告']]
#
# 2. 〜首相 学術会議は既得権益化〜
# [[0.4654665878293501, '会員'],
#  [0.23292522083969588, '首相'],
#  [0.22446367256303948, '任命'],
#  [0.16964739242846888, '踏襲'],
#  [0.16964739242846888, '正当'],
#  [0.16964739242846888, '既得権益'],
#  [0.16964739242846888, '大塚拓'],
#  [0.16964739242846888, '90万人'],
#  [0.15050887371281918, '質疑'],
#  [0.15050887371281918, '問題視']]
#
# 3. 〜紅白司会 紅組は二階堂ふみ〜
# [[0.35138240981150987, 'エール'],
#  [0.22777181857996737, '責任者'],
#  [0.22777181857996737, '大泉'],
#  [0.1711566640006937, '音楽番組'],
#  [0.1711566640006937, '総合司会'],
#  [0.1711566640006937, '大河ドラマ'],
#  [0.1711566640006937, '二階堂'],
#  [0.1518478790533116, '紅白'],
#  [0.1518478790533116, '白組'],
#  [0.1518478790533116, '内村光良']]
#
# 4. 〜松井秀喜氏が愛した店閉店〜
# [[0.4046097015055036, '君'],
#  [0.387889142200944, '松井'],
#  [0.2792204145424851, '松井氏'],
#  [0.13298992273587845, 'です'],
#  [0.13138894605670356, '安倍氏'],
#  [0.13138894605670356, '吉'],
#  [0.13138894605670356, 'もー'],
#  [0.12075198336455346, 'ん'],
#  [0.11599707973129857, '店'],
#  [0.09854170954252767, '清原']]

# %%
all_title = []
for tfidf in sorted_texts_tfidf:
    title = []
    for word in tfidf[:100]: # 100語に絞る
        title.append(word[1])
    all_title.append(title)

# %%
# all_titleリストの中身を確認
for i, text in enumerate(all_title):
    if i < 5:
        print(text[:10])
# Out:
# ['興行収入', '億', '円', '公開', '鬼', '動員', '無限', '列車', '炭', '万']
# ['ニッチェ', '近藤くみこ', '致し', '近藤', '入籍', '江上', '宜しく', 'お願い', '似顔絵', '報告']
# ['会員', '首相', '任命', '踏襲', '正当', '既得権益', '大塚拓', '90万人', '質疑', '問題視']
# ['エール', '責任者', '大泉', '音楽番組', '総合司会', '大河ドラマ', '二階堂', '紅白', '白組', '内村光良']
# ['君', '松井', '松井氏', 'です', '安倍氏', '吉', 'もー', 'ん', '店', '清原']

# %%
# Doc2Vecモデルに重要単語リストall_titleを渡します。
documents2 = [TaggedDocument(doc, [i]) for i, doc in enumerate(all_title)]
model2 = Doc2Vec(documents2, vector_size=100, window=5, min_count=1)

# %%
# 結果と照らし合わせやすいように、番号と作品の一覧を表示
for i, doc in enumerate(documents2):
    print(doc[1], df['title'][i], df['category'][i], doc[0][:8])
# Out:
# [0] 鬼滅の刃 歴代興収が10位に エンタメ ['興行収入', '億', '円', '公開', '鬼', '動員', '無限', '列車']
# [1] ニッチェ近藤が結婚を報告 エンタメ ['ニッチェ', '近藤くみこ', '致し', '近藤', '入籍', '江上', '宜しく', 'お願い']
# [2] 首相 学術会議は既得権益化 国内 ['会員', '首相', '任命', '踏襲', '正当', '既得権益', '大塚拓', '90万人']
# [3] 紅白司会 紅組は二階堂ふみ エンタメ ['エール', '責任者', '大泉', '音楽番組', '総合司会', '大河ドラマ', '二階堂', '紅白']
# [4] 松井秀喜氏が愛した店閉店 スポーツ ['君', '松井', '松井氏', 'です', '安倍氏', '吉', 'もー', 'ん']
# [5] ハンド宮崎大輔容疑者を逮捕 国内 ['宮崎', '宮崎大輔', 'ハンドボール', '容疑者', '引っ張る', '名古屋市内', '暴行', '元日本代表']
# [6] 尚弥の超速パンチ 実は新兵器 スポーツ ['パンチ', 'モロニー', '井上', '発', '黒田', '速', '的中', 'モンスター']
# [7] やっぱり青学が本命?箱根駅伝 スポーツ ['青学大', '2年', '駒大', '東海大', '4年', '箱根駅伝', '登録', 'エース']
# [8] WHO事務局長が自主隔離 国際 ['自主', 'WHO', '隔離', '陽性', '人物', '接触', '症状', '断ち切り']
# [9] 西武 内海哲也と契約更新へ スポーツ ['内海哲也', '人的補償', '登板', '来季', '西武', '年', '巨人', '昨季']
# [10] 尖閣周辺に中国船 年最多更新 国内 ['隻', '船', '航行', '尖閣', '周辺', '確認', '領有権', '重ねる']
# [11] 千葉市長 知事選出馬を表明 地域 ['知事選', '県政', '▽', '熊谷氏', '市長選', '政党', '千葉', '出馬']
# [12] 高橋留美子さんに紫綬褒章 エンタメ ['受章', '紫綬褒章', '少年漫画', 'ラブコメ', '褒章', '中学', '誌', '連載']
# [13] 札幌2歳衰弱死 母は無罪主張 地域 ['池田', '梨', '被告', '詩', '衰弱', '娘', '藤原', '保護責任者遺棄致死の罪']
# [14] ハロウィンに偽パトカー疾走? 国内 ['パトカー', '車', '警察官', '動画', '投稿', '届け出', '映っ', '違反']
# [15] 都構想関連に公金100億円超 国内 ['局', '大都市', '法定', '市長', '13年', '設置', '出直し市長選', '公約']
# [16] 2700ツネ キッチンカーで働く エンタメ ['ツネ', 'キッチンカー', '営業', '2700', 'です', '謹慎', 'さすが', '苦']
# [17] 本田望結 サッカー応援マネに エンタメ ['応援', '二兎', '女優', 'マネジャー', '選手', '大会', '高校サッカー', '静岡学園']
# [18] コネリーさん 認知症だった エンタメ ['コネリー', 'さん', 'ルクブルン', '彼', '死去', '英', '近親者', '見守ら']
# [19] レナウン 再建断念し破産へ 経済 ['レナウン', 'TSR', '企業コード', '株', '譲渡', '破産', '民事再生法', '小泉グループ']
# [20] 米大統領選 期日前が過去最高 国際 ['州', '郵送', '選挙', '集会', '投票', 'ペンシルベニア', 'トランプ氏', 'レディング']
# [21] 中韓などから入国 検査不要に 国内 ['滞在', '不要', '成田空港', '入国者', '韓国', '入国', '検査', '待機']
# [22] 首相 都構想は「一石投じた」 国内 ['差し控える', '大都市制度', '一石', '記者団', '官邸', '投じ', '否決', '質問']
# [23] 居酒屋大手5社 全体の1割閉店 経済 ['居酒屋', '店', '持ち帰り', 'ファミリーレストラン', 'ファストフード', '業態', '閉店', '売上高']
# [24] マー君 全球団との交渉可能に スポーツ ['ヤンキース', '田中', 'FA', '交渉', '契約交渉', '取り合い', '代理人', 'ケーシー']
# [25] 遠隔は悪?大学名公表で波紋 ライフ ['授業', '対面', '学生', '遠隔', '大学', 'オンライン', '文科省', '学習']
# [26] 都幹部「首都2つに見える」 国内 ['権限', '都', '首都', '幹部', '大阪都', '並み', '分散', '二つ']
# [27] 否決で打撃 維新立て直し急務 国内 ['松井氏', '馬場伸幸', '衆院選', '次期', '控室', '急務', '区切り', '党規']
# [28] 秋の褒章 尾畠春夫さんに緑綬 国内 ['受章', '由布岳', 'スーパーボランティア', 'もらっ', 'ボランティア', '男児', '鮮魚店', '閉め']
# [29] 公園の乳児遺体 母親を逮捕 国内 ['遺棄', '遺体', '北井', '乳児', '警視庁', '産婦人科', '生後', '愛宕']
# [30] ヤクルト井野卓 現役引退へ スポーツ ['近日中', '球団', '捕手', '出場', '投手', '鎌ケ谷', '自由契約', '捕手陣']
# [31] ヤクルトがSB内川の獲得調査 スポーツ ['村上', '球団幹部', '獲得調査', '坂口', '固定', '厚く', '一塁手', 'ユーティリティー']
# [32] 紅白 白組司会は大泉洋で調整 エンタメ ['司会', '大泉', '紅組司会', 'ブルーリボン賞', '紅白', '白組', 'トーク', 'さん']
# [33] トルコ地震 迫る「72時間」 国際 ['地震', '隊', 'がれき', '救助', 'トルコ', 'バイラクル', '地区', '救出']
# [34] 大阪都構想を阻止 自民は安堵 国内 ['大阪府連', '力不足', '市議', '代表', '会見', '市内', 'でき', '様子']
# [35] 西武・松坂 来季も現役続行へ スポーツ ['来季', '開幕', '松坂', '契約', '球団', '投げ', '西武', '続け']
# [36] ATSUSHI EXILE卒業しソロ専念 エンタメ ['EXILE', 'ATSUSHI', '歌手', 'と共に', '卒業', '活動', '決意', '40歳']
# [37] 板で窓覆う 米大統領選を警戒 国際 ['ミリシア', 'トランプ氏', '投票所', '起きる', '敗北', '衝突', '混乱', '訴追']
# [38] 知事 僕は都構想再挑戦ない 国内 ['吉村', '両氏', '維新', '告示', 'ましょ', '街頭演説', '訴え', 'かど']
# [39] 接戦の都構想 悩んだ有権者 国内 ['投じ', '大阪', '票', '反対', '会社員', '男性', '無職男性', '港区']
# [40] 天心42連勝 惜別の跳び膝蹴り スポーツ ['裕樹', 'RISE', '拳', '那須川天心', 'ボク', '良かっ', '飾っ', '強く']
# [41] 大阪市長 任期満了で政界引退 地域 ['速報', '政界引退', '2023年', '松井', '任期満了', '受けて', 'もっ', '市長']
# [42] 否決 大阪市長「私の力不足」 国内 ['政治家', '力不足', '松井', '手段', '構想', '都', '代表', '大阪市']
# [43] 元withB アメフト会心プレー スポーツ ['QB', 'サック', 'コージ', '相手', '第4Q', '吉野', 'らいふ', 'プレー']
# [44] 反対多数 大阪市は存続へ 国内 ['特別区', '否決', '大阪市', '維新', '構想', '票', '政界', '前回']
# [45] ハナコ岡部 絶妙なかわいさ エンタメ ['岡部', '系', '癒', '朝ドラ', 'ドラマ', 'シリアス', '出演', '日本テレビ']
# [46] 大阪投票率62.35% 前回下回る 国内 ['住民投票', '期日前投票', '投票率', '関心', '有権者', '選管', '篠山市', '由紀']
# [47] 8冠 騎手ルメールも目真っ赤 スポーツ ['アーモンドアイ', '芝', '直線', 'G1', '天皇賞秋', '天皇賞', 'プレッシャー', '最強']
# [48] 大阪都構想 賛否は拮抗 国内 ['有権者', '投票', '産経新聞社', '毎日新聞社', '日経新聞', '共同通信社', '2816人', '行わ']
# [49] 都構想 18時投票率37.60% 国内 ['住民投票', '9445', '82', '452', '3760', '選挙管理委員会', '5730', '365']
# [50] ネコの絵も 謎は深まるナスカ 国際 ['地上絵', 'ナスカの地上絵', '描か', 'ペルー', 'ナスカ', '巨大', '考古学', '謎']
# [51] 台風横断 フィリピン各地洪水 国際 ['台風19号', '上陸', '弱め', '勢力', 'フィリピン', '各地', '現地メディア', '洪水']
# [52] 西武平尾コーチ解雇 私物窃取 スポーツ ['コーチ', '球団', '窃取', '私物', '契約', '解除', '自宅待機', '平尾']
# [53] 安倍氏 父墓前に首相辞任報告 国内 ['首相', '尽くし', '議員', '長門市', '辞し', '論', '細田', '潰瘍性大腸炎']
# [54] 大下容子アナ 30歳定年説語る エンタメ ['アナウンサー', '大下', '女性アナウンサー', '入社', 'ます', '30歳', '年齢', 'テレビ朝日']
# [55] 米大統領選 かたずのむイラン 国際 ['イラン', '選挙', '超大国', '敵対', '女性医師', '外交政策', '公立病院', 'メヘヌスババイ']
# [56] VTuber人気けん引 upd8終了へ エンタメ ['upd', '8', 'VTuber', 'キズナアイ', '脱退', '所属', '株式会社', 'バーチャルYouTuber']
# [57] 憲剛引退 冷静で「口達者」 スポーツ ['川崎F', '憲剛', '記者', '担当', '良い意味', '驚かさ', 'レジェンド', 'ほど']
# [58] SB内川 涙こらえファンに別れ スポーツ ['ウエスタンリーグ', '声援', '福岡ソフトバンクホークス', 'スタンド', '1軍', '内川', '優勝', 'いただき']
# [59] 軒並み赤字 外食チェーン岐路 経済 ['居酒屋', '業態', 'ワタミ', '和民', '焼肉店', '焼肉', '転換', '売上高']
# [60] 都構想 130年の歴史変わるか 国内 ['特別区', '大阪市', '票', '賛成', '否決', '維新', '再編', '住民']
# [61] アーモンドアイ GI初の8冠馬 スポーツ ['GI', '天皇賞秋', 'アーモンドアイ', '次い', '目', '制し', '騎乗', '秋華賞']
# [62] 都新たに116人 感染数横ばい 国内 ['116人', '34人', '陽性', '重症', '感染者', '増', '横ばい', '検体']
# [63] 毒ガスのよう 香害に苦しむ声 国内 ['におい', '柔軟剤', '合成洗剤', '化学物質過敏症', '気分', '香害', '香り', '洗剤']
# [64] 板東英二 今は仕事セーブ中 エンタメ ['板東', '在阪', 'ラジオ局', '関係者', '引退', 'ラジオ', '水曜日のダウンタウン', '一般人']
# [65] MF中村憲剛 今季限りで引退 スポーツ ['川崎', 'J1', 'W杯', '国際Aマッチ', 'Jリーグ', '得点', '中村', '40歳']
# [66] 福岡のハロウィン 2人を逮捕 地域 ['全裸', '注目', '自称', '福岡市天神', 'テレビ西日本', '警固公園', '現行犯', '男']
# [67] 北陸新幹線 延伸遅れで懸念も 地域 ['開業', '並行在来線', '会社', '県', '運賃', '新幹線', '準備', '拠出']
# [68] トルコ 救出は時間との闘い 国際 ['生存者', '救出', '救出活動', '地震', '生存', '余震', 'がれき', '発生']
# [69] 元ジャニ7人組 来年デビュー エンタメ ['ORDER', '7', '7人', '日本武道館', 'メジャーデビュー', 'リリース', '音楽', '彼ら']
# [70] 駅伝 駒大が「3強」激戦制す スポーツ ['青学大', '駒大', '東海大', '名取', '吉田', '田沢', '4年', '伊勢路']
# [71] 尚弥KO勝ち 試合中に戦略変更 スポーツ ['ラスベガス', 'モロニー', 'WBA', 'IBF', 'ダウン', '試合', '王座', 'フィニッシュ']
# [72] はんこ店 鬼滅キャラ名あるよ ライフ ['秀島', 'はん', '名字', '鬼', '名前', '殺', 'こ', '▽']
# [73] 山口組総本部 菓子配らず 国内 ['菓子', '暴力団排除条例', '暴力団員', '山口組', '県', '禁じ', '改正', '事務所']
# [74] 都構想 正午時点の投票率16% 国内 ['住民投票', '399', '2136人', '1642', '選挙管理委員会', '正午', '5730', '365']
# [75] イージス代替艦 大型化を検討 国内 ['艦船', '迎撃', '代替', 'トン', '方向', '策', '最大', '負担軽減']
# [76] 仏で教会司祭撃たれ重傷 逮捕 国際 ['司祭', 'リヨン', '教会', '負っ', '重傷', '銃身', '至近', '肝臓']
# [77] ものすごい量 服在庫処分の今 経済 ['在庫', 'アパレル', '商品', '業界', '服', 'メーカー', '焼却', '売れ残り']
# [78] 豚解体 ベトナム人を再逮捕 国内 ['豚', '解体', '再逮捕', '自宅', '容疑', '疑い', '購入', '持ち掛ける']
# [79] 尚弥 ラスベガスで7回KO勝ち スポーツ ['リング', 'WBA', 'IBF', 'バブル', '王者', 'ラスベガス', 'バンタム級', '7回']
# [80] 火災で救助中 消防署員が死亡 国内 ['盛岡', '住人', '体調不良', '東', 'マンション', '火災', '救助', '署']
# [81] 1万人超に抗体検査へ 厚労省 ライフ ['抗体', '抗体検査', '感染歴', '調査', '血液', '宮城県', '実施', '初回']
# [82] 「誰も頼れず」産後うつ倍増 国内 ['夫', '子ども', '不安', '産後うつ', '産後', '母乳', '孤立', '育休']
# [83] トルコ なお多数閉じ込めか 国際 ['がれき', 'ギリシャ', 'トルコ', '地震', '倒壊', 'ERT', '島', 'サモス']
# [84] あと3日 米大統領選追い込み 国際 ['バイデン', 'オバマ', '暴動', 'トランプ大統領', '3日', '火曜日', '氏', 'ホワイトハウス']
# [85] 元祖JJガール「本当に休刊?」 エンタメ ['創刊', 'JJ', '山田', '――', 'です', '赤文字系雑誌', '光文社', '元祖']
# [86] 都構想 議論かみ合わぬまま 国内 ['特別区', '年度', '市', '財政', '反対派', '自民', 'サービス', '深まら']
# [87] ジャポニカ表紙 写真家探検記 国内 ['昆虫', '表紙', 'ジャポニカ学習帳', '写真', '山口氏', '植物', '叔父', '写真家']
# [88] 北海道 4日は平地でも雪か 国内 ['でしょ', '雪', '雨', '寒気', '下さい', '平地', '北海道', 'う']
# [89] 吉見引退へ 中日の黄金期支え スポーツ ['先発', '最多勝', '11年', '中日', '投手', '2敗', '年', '故障']
# [90] 「大江戸線延伸を」どんな街? 経済 ['大江戸線', '地下鉄', '駅', '土支田', '練馬区', '沿線', 'バス', '開通']
# [91] 危険な状況 北海道で感染急増 地域 ['札幌', 'クラスター', '道内', '感染者', '10月', '感染者数', '道', '地方']
# [92] 現金化商法に注意 手口巧妙化 国内 ['業者', '現金化', '商法', '取り立て', 'ヤミ金', 'ファクタリング', '給与', '借金']
# [93] 秋元氏「金で転ぶ」買収指示か 国内 ['秋元', '被告', '顧問', '淡路', '議員', '千', 'うそ', '円']
# [94] 迷える渋野日向子 解けぬ呪縛 スポーツ ['予選落ち', 'バーディー', '去年', '今季初戦', 'パッティング', 'ボギー', 'パット', 'ダブルボギー']
# [95] 大阪都構想 住民投票始まる 国内 ['投票', '記入', '住民投票', '防止', '投票所', '特別区', '廃止', '24']
# [96] 花澤香菜 棒読みだった過去 エンタメ ['シャオヘイ', '妖精', '黒猫', '花澤', '字幕版', '原音', 'もち', '演じる']
# [97] 感染拡大 英で再び外出自粛へ 国際 ['外出', '生活必需品', 'ジョンソン首相', '導入', '営業', '英国', 'ロンドン', '再び']
# [98] 早見あかり第1子出産していた エンタメ ['早見', 'あかり', 'ももクロ', '初主演', '―', 'A', '15年', 'と共に']
# [99] 修学旅行生 GoToで大人買い 国内 ['千円', 'クーポン', '修学旅行', '分', '土産物', 'もみじまんじゅう', 'セット', '生']
# [100] コネリーさん死去 悲しい損失 国際 ['ボンド', 'スコットランド', 'コネリー', '映画', 'さん', 'サーショーンコネリー', '英', '演じ']
# [101] トランプ氏 接戦州で差縮める 国際 ['州', 'トランプ氏', 'バイデン', '接戦', '遊説', 'ウィスコンシン', 'リード', '過密']
# [102] 上野動物園 初めてのゾウ誕生 国内 ['飼育', '繁殖', 'ゾウ', 'ウタイ', '赤ちゃん', '園', '雄', '誕生']
# [103] 都構想 焦点は住民サービス 国内 ['特別区', 'サービス', '区長', '特別', '二重行政', '派', '解消', 'コスト']
# [104] 行政事業レビュー 誤記2600件 国内 ['シート', '予算', '行政事業レビュー', '支出', '官僚', '有識者', 'レビュー', '法人番号']
# [105] ショーン・コネリーさん死去 国内 ['007', 'スコットランド', '英', 'スコットランド独立', 'アンタッチャブル', 'ショーンコネリー', '彼', '痛む']
# [106] 柔道「不可解裁定」で大混乱 スポーツ ['小西', '押さえ込み', '解け', '村', '裁定', '押さえ込ん', '技あり', '宣告']
# [107] 鬼滅 観客動員数1000万人突破 エンタメ ['鬼', '炭', '治郎', '煉獄', '無限', '列車', '公開', '花江']
# [108] 渋谷の街 仮装の人出は8割減? 国内 ['仮装', '若者', '渋谷', 'ハロウィーン', '例年', '騒ぐ', '自粛', '良い']
# [109] 歯ぎしり 放置して大丈夫? 科学 ['歯', '睡眠', 'Q', '顎', 'ヨ', '歯ぎしり', 'ヨミ', 'ブラキシズム']
# [110] 「偽陽性」で混乱 五輪へ課題 スポーツ ['PCR検査', '大会', '偽陽性', '内村', '陰性', '五輪', '増やせ', '国際交流']
# [111] 答弁パターン化 首相の真価は 国内 ['答弁', '首相', '衆参', '参院', '施策', '代表質問', '野党', '任命']
# [112] 中国・千人計画 参加者の本音 国際 ['中国', '研究', '論文', '基礎科学', '研究者', '日本', 'ノーベル賞', '予算']
# [113] 都構想 期日前投票は前回超え 地域 ['大阪市', '6万人', 'いわゆる', '関西テレビ', '期日前投票', '特別区', 'ます', '11月1日']
# [114] 頭に謎の物体 古代文明と市民 国際 ['円すい', '墓地', '一般市民', '美術', '埋葬', '古代エジプト', 'スティーブンス', '発見']
# [115] 渋谷ハロウィン 仮装まばら 国内 ['ハロウィーン', '渋谷', 'バーチャル', 'スクランブル交差点', '渋谷区', '自粛', '参加', '若者']
# [116] 珍事 日差しキツくて野球中断 スポーツ ['ロッテ', '中断', '楽天', '西日', '清田', '右翼', 'スタンド', '試合']
# [117] 英 再び全土ロックダウンか 国際 ['英国', '5000人', '陽性', '上っ', '報告書', 'イングランド', '死亡', '万']
# [118] 内村航平「偽陽性」だった スポーツ ['内村', '国際大会', 'PCR検査', '偽陽性', 'FIG', 'NTC', '陰性', '合宿']
# [119] 宇垣美里 報道記者目指してた エンタメ ['宇垣', '林', 'アナウンサー', 'TBS', 'です', 'ん', '局アナ', '報道記者']
# [120] ハロウィン夜空 46年ぶり満月 国内 ['満月', 'ハロウィン', '気温', '°', 'C', 'きょう', '空', '日中']
# [121] 笑って 崖っぷち遊園地の思い 地域 ['園', '企画', 'アトラクション', 'ぎりぎり', '同', '爆速', '扇風機', '新型コロナ']
# [122] 地震怖い トルコ在住の邦人 国際 ['地震', 'イズミル', '出口', '揺れ', '隼人', '朱理', '怖い', '在住']
# [123] 宇垣美里TBS時代の自分は商品 エンタメ ['宇垣', '林', 'アナウンサー', 'TBS', 'です', 'ん', '局アナ', '報道記者']
# [124] 女性→親子 鬼滅ファンの代謝 エンタメ ['ブーム', '本作', '鬼滅の刃', '層', 'アニメ', '劇場版', 'き', '突破']
# [125] 渋野 国内2戦連続の予選落ち スポーツ ['予選落ち', 'ボギー', 'ホールインワン', '破れ', 'に関して', 'パット', 'ジンクス', 'ショット']
# [126] 北海道で81人が感染 過去最多 地域 ['地方', '小樽市', '感染', '空知', '石狩', '北海道', '12人', 'まし']
# [127] 改善しない巻き爪 医師が解説 科学 ['巻き爪', '爪', '巻い', '陥入爪', '痛い', '矯正', '痛み', '食い込ん']
# [128] 日立「巨艦解体」も多難な道 経済 ['日立製作所', '子会社', '事業', '上場', '選択と集中', 'ルマーダ', '日立建機', '統合']
# [129] 巨人独走V 許した5球団の敗因 スポーツ ['関本', '不調', 'チーム', '故障', '開幕', '防御率', '欠い', '守護神']
# [130] 賞味期限 月単位に変更続々 経済 ['食品ロス', '賞味期限', '表示', '削減', 'SDGs', '消費者', '廃棄', '年月']
# [131] BTSファン 上場巡る激動1週間 国際 ['アーミー', 'BTS', '上場', 'メンバー', '兵役', 'ビッグヒット', '株', 'ゲーム']
# [132] 都215人感染 3日連続200人超 国内 ['215人', 'きのう', 'きょう', 'おととい', '42人', '51人', '36人', '204人']
# [133] ハロウィン象徴 なぜカボチャ ライフ ['ジャック', 'ジャックオランタン', '民話', 'ランタン', '魂', '火の玉', 'マニオン', 'サウィン']
# [134] トルコ地震で津波 溺死者も 国際 ['棟', 'ビル', '倒壊', 'できし', '800人', '4000人', '340回', '被害']
# [135] 伊藤さん主演映画 公開へ エンタメ ['公開', '釈放', '賜り', '存じ', 'そのうえで', '十二単衣', 'ご', '作品']
# [136] 戦力外通告の瞬間 経験者語る スポーツ ['選手', '時期', '戦力外通告', 'ロッカー', 'クビ', '2軍', 'どうしても', '入団']
# [137] 鬼滅人気「全集中」経済に光 地域 ['高崎', 'SL', 'イベント', '滅', '上映', '鬼', '伊勢崎', 'MOVIX']
# [138] 西武山川が抹消 本塁打王消滅 スポーツ ['登録', '内野手', '浅村', '水口大地', '山川穂高', '山川', '右足首', '出場選手']
# [139] 厳しさ増す終盤 激戦州で訴え 国際 ['演説', 'トランプ大統領', '候補', 'ミネソタ州', 'バイデン', '民主党', '中西部', '支持者']
# [140] 久保田磨希 認知症の母亡くし エンタメ ['笑', '6時', '――', '時間', 'です', '玄米', '早起き', '早寝']
# [141] アイマス声優 大坪由佳が結婚 エンタメ ['役', '三村かな子', 'シンデレラガールズ', 'アイドルマスター', '大坪', 'お仕事', '一般男性', 'アニメ']
# [142] トルコ地震 800人以上が死傷 国際 ['倒壊', '建物', '救出活動', '隊員', '地元メディア', '沿い', 'がれき', '家族']
# [143] 返礼品の和牛産地を偽装 大分 国内 ['和牛', '偽装', 'ふるさと納税', '返礼', 'おおいた', '納税額', '産', '佐伯市']
# [144] 捜査は尽くした 首里城火災 地域 ['特定', '捜査', '原因', '尽くさ', '燃え', '出火', '首里城', '火災']
# [145] がん 死亡直前まで4割が痛み 国内 ['患者', 'がん', '亡くなる', '緩和ケア', '療養', '国立がん研究センター', '5万人', '遺族']
# [146] 藤川 引退後は阪神に残らず スポーツ ['チーム内', '阪神', 'レジェンド', '球団', '存在', '技術', '谷本', '虎']
# [147] 未婚のパパ 結婚と法的違いは 国内 ['父親', '子ども', '親子', '認知', '法的', '母親', 'ELLY', '生まれ']
# [148] 相当数に深刻な後遺症 WHO 国際 ['後遺症', '症状', '入院患者', '例', '臓器', '神経系', '疲労感', '数カ月']
# [149] 速度違反捏造 警官ら書類送検 国内 ['警部補', '偽造', '取り締まり', '同隊', '速度', '書類', '証拠', '疑い']
# [150] 首里城 二度と燃えない城に 国内 ['正殿', '設計', '焼失', '平良', '屋根', '独特', '30年', '角度']
# [151] 下平アナ 週半分は広島で主婦 エンタメ ['広島', 'アナウンサー', '大人', '週', '特売', '下平さやか', 'ぶどう', 'まし']
# [152] G岡本 自分の成績にムカつく スポーツ ['4番', 'です', 'ホームラン', '僕', 'ます', '思っ', '成績', '気持ち']
# [153] 首里城 1年前の涙語る高校生 地域 ['首里城', '宮城', '下地', '2人', '焼け', '泣い', 'さん', '火災']
# [154] トルコ沖地震 死者20人超に 国際 ['51分', 'トルコ', '都市計画', '日本総領事館', '取り残さ', 'クルム', 'イズミルローマ', '8時']
# [155] 尚弥&モロニー距離10cmで火花 スポーツ ['ポンド', '井上', '計量', 'クリア', '大橋', 'ラスベガス', 'WBA', 'IBF']
# [156] iPhone 知らない予定追加被害 国内 ['IPA', 'カレンダー', 'URL', '見覚え', '独立行政法人', '数件', '情報処理推進機構', '引き出さ']
# [157] 信長の野望 37年売れ続ける訳 エンタメ ['天下統一', '初代', '戦国時代', '大名', '取り入れ', 'PC', 'シリーズ', '作']
# [158] 逗子の崖崩れ 前日に亀裂発見 国内 ['亀裂', '斜面', 'メートル', '管理会社', '市道', '上部', '事故', '県']
# [159] 危険なバス停調査 6県780カ所 国内 ['バス停', 'か所', '横断歩道', '危険', 'B', '公表', 'ランク', 'リスト']
# [160] G原監督 丸は骨折していた スポーツ ['丸', '骨折', 'たく', '巨人', '治り', '振ら', '取り返せ', '丸佳浩']
# [161] Gドラ1平内に背番号11用意 スポーツ ['平内', '龍太', '大塚', '1年目', '亜大', 'トレーニング', '山本', 'ローテ']
# [162] トルコ沖で地震 複数の死者 国際 ['サモス', '震源', 'イズミル', 'トルコ', '島', 'イスタンブール', '10キロ', '地震']
# [163] ユーロ圏GDP12%増 上げ最大 国際 ['期', '月', '各国', '制限', '減', '足元', '脱し', '域内総生産']
# [164] 嵐 被災地に寄り添った歴史 エンタメ ['ライブ', '生徒', 'まし', '5人', '寄贈', '被災地', 'セット', '中学校']
# [165] 伊藤さん釈放 30秒超頭下げる エンタメ ['伊藤', '下げ', 'つぐなっ', '深々', '同署', '頭', '申し訳', 'そして']
# [166] 地中海 ギリシャでM7.0の地震 国内 ['津波', '震源', '近傍', '地震', 'ギリシャ', '震度5弱', '追記', '地中海']
# [167] 北海道 強毒性鳥インフル確認 国内 ['採取', '鳥', '野鳥', '毒性', 'インフルエンザウイルス', 'フン', '周辺', '高病原性鳥インフルエンザ']
# [168] ハマスタ実証実験 目安届かず スポーツ ['感染リスク', 'における', '球場', '検証', '80', '横浜', '観衆', '精細']
# [169] 巨人がリーグ2連覇 スポーツ ['監督', '開幕', '勝', 'シーズン', '原辰徳', '引き分け', 'プロ野球', '巨人']
# [170] 第一生命元職員 5200万円詐取 経済 ['第一生命', '顧客', '員', '不正', '営業', '取得', '貸付', '解雇']
# [171] KDDI 格安スマホで新会社 経済 ['KDDI', '格安スマホ', '設立', 'ブランド', '手続き', 'オンライン', '提供', '高橋誠']
# [172] 伊藤容疑者が釈放 涙ぐみ謝罪 エンタメ ['オートバイ', '伊藤', '償っ', '容疑者', '怪我', '運転', '謝罪', '逮捕']
# [173] GoToトラベルに制限 7泊まで 国内 ['旅行', '観光庁', '日数', '制限', '泊', '対象外', 'キャンペーン', 'GoTo']
# [174] 給付金 返還の申し出6千件 経済 ['返還', '申し出', '申請', '経産省', '件', '▽', '持続化給付金', '不正受給']
# [175] 短期出張 帰国後待機を免除へ 国内 ['帰国', '入国', '免除', '短期', '待機', '14日間', '出張', '措置']
# [176] 台湾で鬼滅公開 熱狂ファンも 国際 ['台湾', '驚異', 'ファン', 'コスプレ', '映画', '鬼滅の刃', '劇場版', 'ヒット']
# [177] 首相 学術会議は旧帝大が45% 国内 ['首相', '会員', '任命', '与野党', '旧', '観光', '予算', '状況']
# [178] 有休取得率56.3% 過去最高 経済 ['取得', '有休', '年次有給休暇', '就労', 'ほど遠い', '563', '急上昇', '1984年']
# [179] 自殺誘う情報で通報 上期最多 国内 ['IHC', '上半期', '件', '警察庁', '誘う', '有害情報', 'プロバイダー', 'インターネットホットラインセンター']
# [180] 皿洗いで無料の店 最後の思い ライフ ['閉店', '店', '出町', '皿洗い', '井上', '記事', '学生', '言う']
# [181] 内閣の資産公開 首相6277万円 国内 ['総資産', '発足', '平均', '1億円', '円', '家族', '分', '万']
# [182] 切り捨て生む 地震が変えた町 地域 ['仮設住宅', '加賀谷', '被災', '仮設', '年金', '入居', '廃業', '生活']
# [183] リニア工事差し止め求め 提訴 地域 ['大井川', '工事', '住民', '流域', '差し止め', '南アルプス', 'JR東海', '沿線']
# [184] 北村匠海 映画公開も「不安」 エンタメ ['アゲ', '映画', '太郎', 'フロア', '渋谷', '駆けつけ', 'オートバイ', 'とんかつDJアゲ太郎']
# [185] 朗希 今季は公式戦で登板なし スポーツ ['井口', '公式戦', '1軍', 'ブルペン', '帯同', '楽天', '調整', '投げ']
# [186] DCM 島忠TOBの条件変更考えず 経済 ['島忠', 'TOB', 'T', '補完', '両社', '買い付け', 'DCM', '価格']
# [187] 高齢者を捨て 若者優先した町 地域 ['仮設住宅', '加賀谷', '被災', '仮設', '年金', '入居', '廃業', '生活']
# [188] 都の感染者204人 20代が最多 国内 ['重症', '感染者', '882人', '27人', '204人年', '都', '39人', '36人']
# [189] 石崎議員に罰金20万円 おわび 地域 ['新潟総合テレビ', 'NST', '石崎', '略式', '新潟', '納付', '議員', '離党届']
# [190] ハロウィン 自治体で判断に差 国内 ['パレード', '仮装', '集まる', '見物客', '密集', 'コンテスト', '街', '最大級']
# [191] G大阪の不祥事 監督は衝撃大 スポーツ ['アデミウソン', '選手', '25日', '練習', '指揮官', '向かっ', '戦', '24日']
# [192] NTC 体操練習場の利用中止 スポーツ ['体操', '日本スポーツ振興センター', '味の素ナショナルトレーニングセンター', '選手', 'NTC', '合宿', '内村航平', 'リンガーハット']
# [193] JR西日本 中間決算初の赤字 経済 ['億', '円', '前年同期', '赤字', '黒字', '804', '488', '3899']
# [194] 北 韓国人射殺は「自衛措置」 国際 ['北朝鮮', 'KCNA', '自衛', '韓国', '韓国側', '事件', '軍', '措置']
# [195] 検査1日6万件に引き上げへ 都 国内 ['件', '千', '検査', '万', '能力', '簡易', '抗原検査', '小池']
# [196] 国産ジェット開発費20分の1に 経済 ['ジェット', '開発', 'スペース', '事業', '旅客機', '実用化', '事業計画', 'MRO']
# [197] JAL 赤字最大2700億円予想 経済 ['億', '赤字', '円', '前年', '国際会計基準', '旅客', '月', '純']
# [198] 伊藤容疑者 近く釈放へ 国内 ['伊藤', '下げ', 'さん', 'ひき逃げ', '黒い', '迷っ', '救護活動', '任意']
# [199] 9カ国・地域の感染危険度緩和 国内 ['レベル', '危険情報', '各国', '危険', '落ち着き', '渡航自粛', '不要不急', '出し']
# [200] 説明十分?都構想あさって投票 国内 ['住民投票', '有権者', '賛否', '住民', '両派', '票', '重い', '条例']
# [201] スカヨハ 俳優と3度目の結婚 エンタメ ['結婚', '慈善団体', '挙式', 'を通じて', '離婚', '高齢者', 'シリーズ', '披露']
# [202] 救急車 全国無料で高速OKに 国内 ['高速', '河野氏', '無料', '救急車', '消防車', '消防署', '戻れる', '国交省']
# [203] 五輪チケ払い戻し 11/10から スポーツ ['払い戻し', 'チケット', '返金', 'パラリンピック', '購入者', '決済', 'Visa', '59分']
# [204] GoToクーポン不正 国が対策 国内 ['電子', 'クーポン', '予約', '宿泊', '旅行', '赤羽一嘉', '緊密', '宿泊施設']
# [205] 米選挙 運命握るカトリック票 国際 ['バイデン', 'カトリック', '教徒', '氏', '支持', 'ムングィアサンチェス', 'トランプ氏', '信仰']
# [206] 休暇分散 西村氏経済界に要請 国内 ['西村', '休暇', '協力', '分散', '会談', '休み', '業種', '氏']
# [207] UPLINKのパワハラ訴訟 和解 エンタメ ['元従業員', 'アップリンク', '浅井氏', '提訴', 'ハラスメント', '謝罪', '合意', '社内']
# [208] インフル接種 予約終了病院も 科学 ['接種', 'ワクチン', 'インフルエンザ', '予約', '確保', '流行', '医療機関', '受け付け']
# [209] LIXIL 希望退職1200人募集 経済 ['LIXIL', '応募', '社員', '物流センター', '正社員', '勤続', '上乗せ', 'リクシルグループ']
# [210] 精神疾患で自殺 29日以下51% 国内 ['自殺', '精神疾患', '白書', '専門', '事案', '職', '発症', '占め']
# [211] 渋野 2度目のホールインワン スポーツ ['パー', '初日', '8番', '渋野', '樋口久子', '三菱電機', 'レディース', 'ホールインワン']
# [212] 引き揚げ者住宅巡り退去命令 国内 ['村崎', '住宅', '引き揚げ', '節子', '東貝塚', '府', 'さん', '戸']
# [213] 日本食?英料理番組に批判殺到 国際 ['出場者', 'ま', '蒸し', 'ケーキ', 'かわいい', 'テーマ', '料理', 'チャンネル']
# [214] 伊藤容疑者 事故分かっていた 国内 ['供述', '逃走', 'ひい', '趣旨', '伊藤', '容疑者', '車', '分かり']
# [215] GoTo観光以外は除外へ 国交相 国内 ['料金', '宿泊', '付い', '支援', '除外', '講習', '旅行商品', '対象外']
# [216] GAFA3社最高益 際立つ好業績 経済 ['ドル', 'アップル', '万', '増', '減益', '持ち株会社', 'フェイスブック', 'コム']
# [217] NZの国民投票 安楽死賛成65% 国際 ['安楽死', 'NZ', '容認', '賛否', '開票結果', '耐え難い', '総選挙', '永住']
# [218] JAL ヤマトなどに500人出向 経済 ['日航', '賃金水準', '教育機関', '宅配便', '一時帰休', 'ヤマトホールディングス', '需要', '企業']
# [219] 元非行少年 厳罰化は解決策か 国内 ['少年院', '要綱', '更生', '送致', '松尾', '厳罰', '教育', '矯正']
# [220] 転落巻き添え 遺族への補償は 国内 ['遺族', '女子大生', '男子生徒', '亡くなっ', '過失犯', '給金', '犯罪被害者', '給付']
# [221] 米ウォルマート 店から銃撤去 国際 ['銃弾', '銃', '暴徒', '店頭', 'ウォルマート', '撤去', '販売', '店舗']
# [222] 「今日俺」ポスター撤去 県警 地域 ['掲示', '県警', 'ポスター', '撤去', '載っ', '伊藤', '容疑', '本部']
# [223] 企業の内部留保 8年連続で増 経済 ['兆', '内部留保', '億', '円', '減', '財務省', '蓄え', '法人企業統計']
# [224] 伊藤健太郎容疑者を送検 国内 ['伊藤', 'バイク', '容疑者', '送検', '衝突', '起こし', '負い', '容疑']
# [225] 川重 バイク生産を分社化へ 経済 ['造船', '川重', '二輪車', '部門', 'プラント', '工場', '造船所', '神戸']
# [226] 0円で町が温泉売却 応募ゼロ? 国内 ['温泉', '温泉施設', '町', '応募', '売却', '利用者', '西和賀町', '老朽化']
# [227] 平野ノラ42歳 第1子を妊娠 エンタメ ['子ども', '夫', 'う', 'まし', '気づい', '婦人公論', 'みよ', 'よ']
# [228] 巨額詐欺 倉庫の6千万円押収 国内 ['山口', '容疑者', '財産', '合同捜査本部', '千', '関係先', '破綻', '円']
# [229] 米 UAEにF35を売却する方針 国際 ['売却', 'UAE', 'F35', '政権', '非公式', '戦闘機', '国交', '下院外交委員会']
# [230] SB周東 普通はできない走塁術 スポーツ ['盗塁', '周東', '飯田', '配球', '盗塁王', 'トップスピード', 'カウント', '速い']
# [231] 虎・福留が退団明言 現役続行 スポーツ ['福留', 'ユニホーム', '鳴尾浜球場', '福留孝介', '内規', '43試合', '22年目', '12打点']
# [232] クラスター 全国で1761カ所に 国内 ['か所', '波', '感染者', '第', '解除', '低下', '多かっ', '広がっ']
# [233] 大阪市 4分割コスト試算撤回 国内 ['財政局', '試算', '人口', '局長', '218', '分割', '毎日新聞', 'コスト']
# [234] 石破派混乱「空中分解」の声 国内 ['石破派', '石破', '派閥', '総裁選', '同派', '党内', '例会', '派']
# [235] 鬼滅 既刊22巻ランキング独占 エンタメ ['独占', '付', '1位', '週間', '今週', '売上', '10位', '記録']
# [236] 大竹しのぶ 芸歴47年初の月9 エンタメ ['美幸', '朝顔', '大竹', '月9', '共演', 'さん', '生き', '里子']
# [237] 芸能界と事故 運転禁止の傾向 エンタメ ['管理', '移動', '事故', '事務所', '運転', 'ひき逃げ', '舞台稽古', '細心']
# [238] 斎藤佑 初の1軍登板なしに スポーツ ['登板', 'GM', 'イースタン', '吉村', '浩', '23試合', 'けど', '絶望']
# [239] ゴーン被告支援 2人引き渡しへ 国際 ['国務省', '引き渡し', 'ボストン', '弁護士', '移送', '容疑者', '申し立て', '裁判所']
# [240] 伊藤容疑者 数億円の違約金か エンタメ ['違約金', '容疑者', 'CM', '伊藤', '映画', '損害賠償', '警視庁', 'ひき逃げ']
# [241] 仏 テロ警戒水準を最高に 国際 ['テロ', 'ニース', '容疑者', '拘束', '駆け付け', '銃撃', '襲撃事件', 'ノートルダム教会']
# [242] 内村の感染 五輪関係者に衝撃 スポーツ ['五輪', 'NTC', '国際大会', '体操', '競技', '渡辺', '選手', '感染者']
# [243] 表紙に伊藤容疑者 小説誌変更 国内 ['表紙', 'KADOKAWA', '号', '伊藤', '野性時代', '発売予定', '忍法帖シリーズ', '差し替える']
# [244] 雇用助成の特例 来年も継続へ 経済 ['財源', '雇', '調', '3次', '補正予算', '特例措置', '予備費', '追加']
# [245] ELLYもう親バカ?本当かわいい エンタメ ['ELLY', 'ゲーム', 'パートナー', '本当に', 'プレイ', '僕', '楽しい', 'アンバサダー']
# [246] 習近平氏の長期政権化へ攻防 国際 ['党', '習', '主席', '総会', '党総書記', '長期政権', '国家主席', '制']
# [247] 学術会議会長 首相に反論 国内 ['梶田', '学術', '会議', '任命', '拒否', '会長', '会員', '井上']
# [248] 伊藤容疑者「気が動転した」 国内 ['バイク', '1丁目', '容疑者', '立ち去っ', '捜査関係者', '衝突', '運転', '伊藤']
# [249] 米GDP、過去最大の33.1%増 経済 ['期', '四半期', 'プラス', 'マイナス', '月', 'GDP', '79', '過去最大']
# [250] アンゴラ村長 縄跳びでギネス エンタメ ['ギネス', '生山', 'アンゴラ村長', 'とび', '伝わり', 'ヒジキ', 'になわ', 'とびで']
# [251] 巨人 今季最悪5連敗でもM1に スポーツ ['安打', '丸', 'マジック', '巨人', '坂本', '3番', '連続', '敗れ']
# [252] 石破派 竹下派と合流構想浮上 国内 ['竹下派', '石破派', '石破', '鴨下', '氏', '幹部', '合流', '党総裁']
# [253] 在サウジ仏領事館で刃物襲撃 国際 ['サウジ', '襲撃', '仏', '大使館', '警備', 'ジッダ', '風刺画', '犯']
# [254] 福島県 人件費求め東電を提訴 地域 ['賠償', '東京電力', '原発事故', '提訴', '県', '福島地方裁判所', '原子力損害賠償紛争解決センター', '9250万円']
# [255] ワクチン供給3社目 政府契約 国内 ['モデルナ', 'ワクチン', '製薬', '治験', '回分', '供給', '大手', '開発中']
# [256] 仏で刃物襲撃3人死亡 テロか 国際 ['大統領', 'イスラム教徒', '襲撃', 'マクロン', '仏', '市長', '筋', '犯']
# [257] ドンキ前社長 株取引で不正か 国内 ['勧め', '社長', '証券取引等監視委員会', '株取引', '強制調査', '関係先', '前', '知人']
# [258] 伊藤容疑者 NHKドラマを降板 エンタメ ['LIFE', 'コント', '伊藤', '連続テレビ小説', '容疑者', 'NHK', 'ドラマ', '組む']
# [259] 内村航平が新型コロナ陽性 スポーツ ['内村', '判定', 'PCR検査', '陽性', '渡辺', '国際大会', '日本代表', '21日']
# [260] 香港 国安法違反で活動家起訴 国際 ['香港', '鍾氏', '生動', '国安', '学', '法', '源', '国家分裂']
# [261] くそたれ地震 不満のみ込む今 地域 ['独り', '高齢者', '空き', '安平町', '佐藤', '介護施設', '安平', '仮設住宅']
# [262] GoToイート紙切れ 担当者憤り 地域 ['券', '冊', '発券', '食事', 'イート', 'ロール', '不足', '事務局']
# [263] 週末 東日本で冷え込み強まる 国内 ['°', 'C', '冷え込み', '関東', '10', '山沿い', '南下', '寒気']
# [264] SB周東が12戦連続盗塁 プロ新 スポーツ ['盗塁', 'プロ野球', '二塁', '周東', '記録', '福本豊', '月間', '成功']
# [265] TDR運営 511億円赤字の見通し 経済 ['来園', '休園', '億', '客', '売上高', '円', '赤字', '通期']
# [266] 伊藤容疑者 事故直後の映像 国内 ['伊藤', '容疑者', '容疑', '事故', '伊藤健太郎', '映画', 'ショック', '車']
# [267] 日本初 糖質0ビールどう実現 ライフ ['ビール', '糖質ゼロ', '糖質', '一番搾り', '酒好き', 'ハイボール', 'いえ', '気']
# [268] 給食で100人超食中毒 鶏に菌 国内 ['給食', '児童', '鶏肉', '中野', '症状', '発熱', '105人', '保健所']
# [269] ビシエド抹消 打点王は絶望的 スポーツ ['中日', '82打点', '復帰', '痛', '抹消', '甲子園', '捕手', '阪神']
# [270] 案里被告 参院本会議を欠席 国内 ['被告', '里', '保釈', '案', '本会議', '公判', '参院', '罪']
# [271] 「THE W」決勝進出10組が決定 エンタメ ['ブロック', '女王', 'ぼる塾', 'Aマッソ', 'ファイナリスト', 'ネタ', 'ゆりやんレトリィバァ', 'ゆりやん']
# [272] 巨人 きょう優勝の条件は スポーツ ['巨人', '引き分け', '中日', '予告先発', '負け', '横浜スタジアム', '勇', 'リーグ2']
# [273] ニトリ 島忠にTOB実施を発表 経済 ['島忠', 'ニトリ', 'TOB', '株', '取得', 'ホームセンター', '買い付け', '家具']
# [274] ウイカ 尊敬するのはリンゴ エンタメ ['ダウンタウンDX', '出演', 'お話', 'ブレイク', '番組', '――', 'バラエティー番組', 'です']
# [275] 鈴木氏の出馬断念 知事は驚き 地域 ['森田', '知事', '鈴木氏', '擁立', '不出馬', '県連', '進退', '自民']
# [276] 東京都 新たに221人感染確認 国内 ['29人', '重症', '58人', '221人年', '48人', '41人', '10歳', '次いで']
# [277] 伊藤容疑者 とんかつDJは公開 エンタメ ['伊藤', '運転', '伊藤健太郎', '登壇', '明日', '予定通り', '公式', 'オートバイ']
# [278] トヨタ、9月生産が過去最高 経済 ['生産', '増', '台', '過去最高', '前年', '9月', '中国', '旺盛']
# [279] GoToイベント 第1弾にUSJ 経済 ['USJ', 'チケット', 'キャンペーン', 'イベント', '売り出す', '割引', '割り引く', '入場券']
# [280] 歓楽街に検査拠点を 分科会 国内 ['歓楽街', '報告書', '感染拡大', '早期', '予兆', '検知', '保健師', '介入']
# [281] AIでいじめ対策 7市導入検討 国内 ['いじめ', '大津市', 'システム', '分析', 'AI', '深刻', '導入', 'リスク']
# [282] 国内感染者 客船含め10万人超 国内 ['感染者', '超え', '千', '1万人', '8月上旬', '増加', '国内', '感染']
# [283] デンソー中間決算赤字711億円 経済 ['億', '前年同期', '売上高', '兆', '円', '減', '自動車販売', '据え置い']
# [284] 伊藤容疑者 目撃者が追い説得 国内 ['伊藤', 'オートバイ', '俳優', '容疑者', '乗用車', '現場', '警視庁', '連続ドラマ']
# [285] 日銀 大規模緩和の維持決定 経済 ['展望リポート', 'マイナス', '日銀', 'GDP', '見通し', '実質', '金融緩和', '金融政策決定会合']
# [286] 伊藤容疑者逮捕 事務所が謝罪 エンタメ ['皆様', '本件', '怪我', '事故', '俳優', '運転', 'お詫び', '伊藤']
# [287] フジ 伊藤容疑者番組差し替え エンタメ ['特番', '特別編', '恋', 'アウト×デラックス', 'ほんとにあった怖い話', 'でんじろう', 'JD', '2930']
# [288] 行き過ぎ指導 元生徒が提訴 地域 ['体罰', '生徒', '高校', '指導', '学校法人', '大声', '丸刈り', '学校']
# [289] 再審無罪 宮田浩喜さんが死去 地域 ['宮田', '熊本県宇城市', '熊本市', '熊本地裁', '浩喜', '汚名', '殺人犯', '松橋町']
# [290] 李元大統領に懲役17年確定 国際 ['李', '被告', '判決', '大統領', '韓国', '竹島', '独島', '李明博']
# [291] 第一生命 企業年金利率下げる 経済 ['第一生命保険', '企業年金', '予定利率', '025', '125', '引き下げる', '現行', '正式']
# [292] 伊藤容疑者 事故現場離れた 国内 ['バイク', 'ケガ', '容疑者', '伊藤', '交差点', '立ち去っ', '間違い', '乗っ']
# [293] エビ中・安本彩花 治療で休養 エンタメ ['安本', '私立恵比寿中学', '安本彩花', '応援', '頑張り', 'エビ中', 'エビ', '歌っ']
# [294] 男性不妊 語る治療の難しさ 国内 ['不妊', '精子', 'オオタ', '男性', '治療', '検査', '勇気', 'およそ']
# [295] スノボ五輪銅 平岡被告に有罪 国内 ['発覚', '執行猶予', '懲役', '被告', '2年', '銅', '追突事故', '追突']
# [296] 伊藤健太郎容疑者を逮捕 国内 ['バイク', 'けが', '伊藤', '容疑者', '事故', '容疑', '車', '立ち去っ']
# [297] 政府 多機能イージス艦新造へ 国内 ['イージス艦', '地上', '型', 'イージス', '代替', '艦', 'BMD', '隻']
# [298] 家に犬164匹 多頭飼育崩壊か 国内 ['犬', '飼い主', '県', '基金', '排せつ物', '多頭飼育崩壊', '去勢手術', '不妊']
# [299] 伊藤健太郎さん事故 女性重傷 国内 ['聴い', '警視庁', '事情', '伊藤', 'さん', 'バイク', '運転', '伊藤健太郎']
# [300] 競技場の盗撮 対策の難しさ 国内 ['盗撮', '撮影', '尻', '競技', '未成年', 'ビデオ', '防止', '動画']
# [301] 首里城火災1年あの日の悔しさ 地域 ['首里城', '正殿', '火災', '御庭', '燃え', '舞台', '1031', '首里城公園']
# [302] 米 WTO事務局長の選出を阻止 国際 ['WTO', 'オコンジョイウェアラ', 'USTR', '貿易', 'ナイジェリア', '支持', '反対', '米国']
# [303] 行き過ぎ指導 元生徒が提訴へ 国内 ['教諭', '同校', '男子生徒', '体罰', '指導', '学校', '退学', '校長']
# [304] ニトリ、島忠の全株取得へ 経済 ['島忠', 'TOB', '価格', 'ニトリ', 'DCM', '家具', '日用品', '完全子会社']
# [305] 仏 ロックダウン再導入へ 国際 ['マクロン', 'クリスマス', '外出', 'ロックダウン', 'フランス', '措置', '閉鎖', '前回']
# [306] 鬼滅 ファンが生んだ「聖地」 エンタメ ['鬼', '八幡竈門神社', '伝承', '食い', '神社', '竈門', '神楽', '鬼滅の刃']
# [307] 鈴木大地氏 知事選出馬を断念 地域 ['鈴木氏', '県連', '擁立', '出馬', '知事選', '千葉県', '熊谷氏', '断念']
# [308] 深田恭子 新婚生活を「妄想」 エンタメ ['深田', 'シーン', '泥棒', '華', '木曜劇場', '新婚生活', '和馬', 'ルパンの娘']
# [309] GoTo 電子クーポン不正取得か 国内 ['予約', 'クーポン', 'GoTo', 'トラベル', '館山', 'リゾートホテル', 'Q', '電子']
# [310] YouTuber事務所VAZ 社長退任 エンタメ ['VAZ', '代表取締役', 'ユーチューバー', '退任', '森氏', '事務所', 'ヒカル', 'ねお']
# [311] NY株943ドル安 3カ月ぶり安値 経済 ['ドル', '暴徒化', '安値', '営業日', '前日比', '冷え込ま', 'リスク回避', 'マイクロソフト']
# [312] 阪神一筋の上本博紀 退団へ スポーツ ['上本', '球団', 'もよう', '現役続行', '阪神', '戦力', '衰え', 'タテジマ']
# [313] 白石 卒コンで何度も「幸せ」 エンタメ ['白石', '〟', '〝', '幸せ', '9年間', '流し', '乃木坂46', 'ソロ']
# [314] 錦織圭 右肩負傷で今季終了 スポーツ ['室内', 'ハード', 'ATP250', '錦織圭', '錦織', 'ソフィア', 'ひじ', '肩']
# [315] 白石 卒コン序盤から涙腺崩壊 エンタメ ['白石', '涙', 'まいやん', '卒業', '9年間', '乃木坂46', '生田', 'シングル']
# [316] かんぽ不正 新たに490人処分 経済 ['社員', '処分', '日本郵便', '490人', '不適切', '上司', '認定', '大半']
# [317] 関テレ デヴィ夫人発言で謝罪 ライフ ['不妊', 'デヴィ夫人', '中絶', '異なる', '発言', '事実', '謝罪', '関西地区']
# [318] 4連敗 G監督そうですね10連発 スポーツ ['増田', '2点', 'そうですね', '原監督', '巨人', '軽率', '落球', '絡む']
# [319] 森元首相 鈴木大地氏出馬に反対 国内 ['森氏', '鈴木氏', '県連', '擁立', '千葉県知事選', 'スポーツ庁', '自民党', '長官']
# [320] シリアの停戦 崩壊の危機に 国際 ['ロシア', '反体制派', 'トルコ', '空爆', 'シリア', 'イドリブ県', '軍事同盟', '軍事アナリスト']
# [321] 今年台風上陸なし?幸運重なる 国内 ['台風', '上陸', '日本列島', '発生', '個', '高気圧', '気象庁', '上空']
# [322] SB周東11試合連続盗塁に成功 スポーツ ['盗塁', '記録', '福本豊', '月間', '球団', '連続', '陥れ', '遊ゴロ']
# [323] 時速380km「圧力感じない」 地域 ['時速', '乗り心地', 'X', 'JR東日本', '380キロ', '体験', 'ー', '走行試験']
# [324] 大麻所持 東海大生ら2人逮捕 国内 ['東海大学', '大麻', '駐車場', '現行犯', '所持', '学生', '謝罪会見', '硬式野球']
# [325] JTB 転勤でも引っ越しせずOK 経済 ['単身赴任', '社員', '働き', '制度', '配偶者', '転勤', '異動', '新型コロナウイルス感染症の流行']
# [326] 嵐が謝罪 中日「恐縮です」 エンタメ ['嵐', '神宮球場', '直筆', 'サイン色紙', '中日', 'ジャニーズ事務所', '謝罪', 'メッセージ']
# [327] コロナ感染「微増傾向続く」 国内 ['実効', '再生産', '集団', '類型', '愛知', '在留外国人', 'アドバイザリーボード', 'うつす']
# [328] 集配所殺傷 遺族「許さない」 地域 ['遺族', '逆恨み', '犯人', '一同', 'ヤマト運輸', '彼女', 'たかっ', '怒り']
# [329] 日立製作所 営業利益39%減 経済 ['日立金属', '売却', '計上', '億', '上場', '子会社', '円', '減']
# [330] 紙不足 京都がGoTo食事券停止 国内 ['券', '発券', '食事', '冊', 'ファミリーマート', '手続き', '事務局', '用紙']
# [331] 三代目ELLYがパパに 結婚せず エンタメ ['MEGBABY', 'ELLY', '三代目', 'パートナー', 'パパ', 'SOUL', 'J', 'BROTHERS']
# [332] 菅首相 任命拒否の判断変えず 国内 ['拒否', '多様性', '任命', '判断', '会員', '菅内閣', '避ける', '論戦']
# [333] JR東海 純損益1135億円の赤字 経済 ['2575', '1135', 'JR東海', '億', '円', '鉄道', '連結決算', '落ち込ん']
# [334] 調布の陥没 東日本高速が陳謝 国内 ['工事', '陥没', '道路陥没', '東日本高速道路', '東京都調布市', '東京外郭環状道路', '小畠', '現場近く']
# [335] 貯水槽に男性遺体 殺人で捜査 地域 ['傷', '足首', '県警', '脚', '遺体', '男性', '見つかっ', '事件']
# [336] 若年女性の失業4.7% 最も悪化 経済 ['男女別', '悪化', '年代', '上昇', '高水準', '顕著', '就業者', '失業率']
# [337] 土砂崩れ作業員1人死亡 大阪 国内 ['資材', '置き場', '土砂', '巻き込ま', '大阪府茨木市千提寺', '外側', '土木', '作業員']
# [338] 試合中断 嵐がおわびの色紙 エンタメ ['神宮球場', '風船', '花火', '国立競技場', '嵐', 'ジャニーズ事務所', '収録', '両']
# [339] アパート内で豚解体 4人逮捕 国内 ['解体', '県警', '4人', '豚', '家畜', 'アパート', '袋', 'ベトナム人']
# [340] 漁業被害 アザラシがゴロゴロ 国内 ['アザラシ', '前年度', '網', '宗谷', '個体', 'サケ', 'ゴマフアザラシ', '減っ']
# [341] デヴィ夫人 不妊巡る発言謝罪 エンタメ ['方々', '発言', 'デヴィスカルノ', 'ご', '申し上げ', 'デヴィ夫人', '謝罪', '深く']
# [342] 土砂崩れ1人心肺停止 大阪 地域 ['土砂', '生き埋め', '崩れ', '積み上げ', '土木工事', '資材', '置き場', '消防']
# [343] 正月休み分散 自民幹部が苦言 国内 ['休暇', '分散', '発信', '党', '衆院解散総選挙', '苦言', '縛る', '政調会長']
# [344] 首相 任命拒否の違法性否定 国内 ['拒否', '多様性', '任命', '判断', '会員', '菅内閣', '避ける', '論戦']
# [345] 東京都 新たに171人感染確認 国内 ['28人', '重症', '感染者', '9日', '457人', '23人', '171人年', '171人']
# [346] 大好きだった祖母殺害 介護限界 国内 ['祖母', '介護', '女性', '叔母', '親族', '介護者', 'おばあちゃん', 'タオル']
# [347] 6人死傷火災 元店長に有罪 地域 ['火災', '火', '高沢', '容易', '予見', '因果関係', '死傷', '被告']
# [348] 国税庁「路線価」引き下げず 経済 ['下落', '路線価', '地価', '国税庁', '補正', '土地', '調査', '19']
# [349] MLBド軍優勝 監督は沖縄出身 スポーツ ['ワールドシリーズ', 'レイズ', 'ベッツ', '制覇', 'ドジャース', '三塁', 'ロバーツ', 'アーリントン']
# [350] ノブコブ徳井、離婚していた エンタメ ['離婚', '40', '電話', '番組', '離婚届', '生出演', '東野幸治', '東野']
# [351] 加藤氏 原発の新増設想定せず 国内 ['原発', '承知', '温室効果ガス', 'エネルギー', '新設', '原子力', '重要', '点']
# [352] 三男死なせた長女 家族に何が 国内 ['ゆり', '被告', '父親', '育児', '雷斗', '知的障害', '産む', 'おかん']
# [353] MLBドジャース32年ぶり世界一 スポーツ ['レイズ', 'ドジャース', '裏', 'スネル', '打線', '一死', 'ポストシーズン', '2番手']
# [354] 感染対策が不足 受刑者が提訴 地域 ['受刑者', '大阪刑務所', '人身保護法', '感染対策', '不十分', '施設', '訴え', '男性']
# [355] 大塚家具 久美子社長が辞任へ 経済 ['大塚家具', '大塚久美子', '社長', '社名', 'TSR', '取締役', '企業コード', '辞任']
# [356] ハワイ 日本の観光客受け入れ 国際 ['ハワイ州', '免除', 'アメリカ', '隔離', '観光客', '陰性', '検査', 'イゲ']
# [357] メッシと対立 バルサ会長辞任 スポーツ ['辞任', 'よぎっ', 'クラブ', '前日', '手', '生まれ変わる', '無責任', '断固']
# [358] 北海道 警戒ステージ引き上げ 地域 ['警戒', '段階', '北海道', 'ステージ', '独自', '会議', '新型コロナウイルス感染症対策本部', '抑え込ん']
# [359] 戦略違う?みちょぱ&ゆきぽよ エンタメ ['ギャル', '”', '“', 'タレント', '90年代', '知らず', 'ニュー', 'ギャル雑誌']
# [360] 間宮祥太朗 成田凌から相談も エンタメ ['間宮祥太朗', '役者', '僕', '着実', '世代', '俳優', 'って', '凌']
# [361] 間宮祥太朗 ブレイクなかった エンタメ ['間宮祥太朗', '役者', '僕', '着実', '世代', '俳優', 'って', '凌']
# [362] 携帯値下げ SBとKDDIが新料金 経済 ['料金', 'プラン', 'ギガバイト', 'KDDI', '引き下げ', '始める', '受けて', 'ソフトバンク']
# [363] 静岡銀と山梨中銀が提携へ 経済 ['提携', '銀', '狙い', '兆', '強化', '頭取', '静岡銀行', '静岡']
# [364] 国家公務員の月給 据え置きへ 国内 ['月給', '人事院', '改定', '勧告', '民間', '公務員', 'ボーナス', '給与']
# [365] ALFA-X初試乗会 時速382km 国内 ['時速', 'X', 'ALFA', '360キロ', '新幹線', '―', '試験走行', '試乗会']
# [366] 鬼滅特需も 続くシネコン苦境 エンタメ ['興収', '週', '興行', '2週目', '本作', 'ヒット', '突破', '動員']
# [367] 米で警官撃ち黒人死亡 波紋 国際 ['ペンシルベニア州', '近づい', '波紋', '撃た', '男性', '黒人', '迫っ', '抗議デモ']
# [368] 首里城再建の寄付 50億円突破 地域 ['首里城', '寄付', '県', '美', '財団', '沖縄', '時点', '火災']
# [369] 卒後3年は新卒扱い 政府要請  経済 ['厚労相', '会頭', '会談', '要請', '維持', '首脳', '経済団体', '既卒']
# [370] トヨタ系に出向 三菱重が打診 経済 ['三菱', 'T', '出向', '重', '小型', 'ジェット旅客機', '受け入れ', '部品']
# [371] ツキヨタケ中毒相次ぐ 県注意 地域 ['ツキヨタケ', 'キノコ', '食中毒', '県', '食用', '食べ', '採取', '染み']
# [372] 学術会議 官邸14年選考も関心 国内 ['推薦', '会議', '候補', '105人', '元幹部', '官邸', '名簿', '会員']
# [373] 陸上コールマン 五輪は絶望的 スポーツ ['ドーピング', '出場停止処分', 'コールマン', '世界選手権', '100メートル', '東京五輪', '男子', '不正']
# [374] 「女性活躍」重い?現場の疲弊 地域 ['夫', '保育園', '家事', '仕事', '育児', '輝け', '時短', '女']
# [375] 米、香港活動家の亡命拒絶か 国際 ['香港', '拒絶', '総領事館', '米', '要求', '対立', '避け', '報道']
# [376] 米大統領選まで1週間 接戦へ 国際 ['バイデン', 'トランプ大統領', '郵便', '氏', '投票', '集計', '検事', 'ジョージア州']
# [377] 伊の新規感染2.2万人過去最多 国内 ['過去最多', '死者', '感染', '累計', '新た', '超え', '北部', '北欧']
# [378] ANA 「再浮揚」なお視界不良 経済 ['路線', '資金', '拡大', '航空', '国際線', '収束', '銀行団', '片野坂']
# [379] 消費税不正 40億円を追徴課税 国内 ['消費税', '仕入れ', '金地金', '追徴', '課税', '申告', '帳簿', '中国人']
# [380] 病で収監延期 田代まさしの今 エンタメ ['田代', '薬物依存症', '裏切っ', '薬物', 'ん', '逮捕', '収監', 'め']
# [381] GoToトラベル延長へ 政府調整 国内 ['延長', '観光', '詰める', '観光産業', '斉藤鉄夫', '大型連休', '下支え', '事業']
# [382] FIFA会長がコロナ陽性 隔離 スポーツ ['インファンティーノ', 'FIFA', '会長', '陽性反応', '隔離', '措置', '軽度', '国際サッカー連盟']
# [383] ミラクル9 入社1年目アナ起用 エンタメ ['アナ', '久冨', '渡辺', '進行', 'ミラクル9', '収録', '大切', '率いる']
# [384] LVMH ティファニー買収再交渉 経済 ['LVMH', '買収', 'ティファニー', '合意', '履行', '提訴', '価格', '宝飾']
# [385] 斎藤佑樹 右肘手術を検討  スポーツ ['右肘', '痛', '投球', 'じん帯', '登板', '断裂', '実戦復帰', '1215']
# [386] SB内川退団へ 現役続行は模索 スポーツ ['内川', '2軍', '1軍', '退団', 'プロ', '昇格', 'FA', '戦力']
# [387] 個人番号夜間も対応を 総務相 国内 ['交付', '申請', '送付', '取り組み', '要請', '都道府県知事', '枚数', '普及促進']
# [388] SB優勝 ロボット踊る祝勝会 スポーツ ['ロボット', 'ペッパー', '型', 'ソフトバンク', '合わせ', '鎮座', '祝辞', '祝勝']
# [389] ANA コロナ後にらみ雇用維持 経済 ['出向', '航空', '社員', '業種', '雇用', 'HD', 'ノジマ', '先']
# [390] トランプ氏 本当に負けるのか 国際 ['トランプ氏', '有権者', '陣営', '支持者', '支持', '登録', 'バイデン', '再選']
# [391] コロチキ西野 第1子男児誕生 エンタメ ['西野', 'コロコロチキチキペッパーズ', '第1子', 'ありがとう', '誕生', '西野創人', '立ち会い', '凄']
# [392] 中国 35年にガソリン車全廃へ 国際 ['ガソリンエンジン', '新車', '環境対応車', '優遇', 'NEV', 'HV', '市場', '販売']
# [393] SBがV奪回 裏に「老将の知」 スポーツ ['工藤監督', '金氏', '王', '監督', 'ソフトバンク', '会長', 'V', '韓国プロ野球']
# [394] 「17連休」要請 西村氏が否定 国内 ['休暇', '分散', '分科会', '1月11日', '取得', '西村', '年末年始', '提言']
# [395] 河井案里被告を保釈 国内 ['被告', '里', '保釈', '案', '克行', '参院選', '論告', '被告人']
# [396] ソフトバンク3年ぶり優勝 スポーツ ['優勝', '点灯', 'ロッテ', '甲斐', 'マジック', 'ペイペイドーム', '6回', 'ソフトバンク']
# [397] 座間事件 2つのアカ使い接触 国内 ['アカウント', '白石', '殺害', '被告', '女性', 'まし', 'ツイッター', '隆浩']
# [398] ロイヤルHD早期退職200人募集 経済 ['運営会社', '社', 'ロイヤルホスト', '退職', '12月', '計上', '募集', '連結決算']
# [399] 大阪 新たに142人の感染確認 地域 ['滋賀県', '8月21日', '67日', '165人', '142人', '140人', '11人', '近畿']
# [400] 原子力規制委に不正アクセス 国内 ['情報システム', '送受信', '不正アクセス', '委', '外部', '規制', '職員', '電子メール']
# [401] 発言物議 デヴィ夫人は反論 国内 ['堕胎', 'デヴィ夫人', '不妊', '発言', '掻爬', '番組', 'アナ', '中絶']
# [402] KDDI 20ギガ4千円弱で調整 経済 ['プラン', 'ギガバイト', '料金', '月額', 'UQモバイル', 'KDDI', '追加', '電話料金']
# [403] 日立金属 3200人リストラへ 経済 ['自然減', '従業員', '早期退職', '削減', '伴う', '海外', '定年退職', 'リストラ']
# [404] 西武1位 爆笑会見の裏明かす スポーツ ['渡部', 'ありがとう', '会見', '巨漢', '監督', 'メッセージ', 'です', '赤らめ']
# [405] 作家・大城立裕さん死去 95歳 地域 ['沖縄', '芥川賞', '文学', '小説', '受賞', '達矢', '老衰', '琉球政府']
# [406] エコリカがキヤノンを提訴 国内 ['キヤノン', '品', '再生', 'エコリカ', '純正', '独禁法', '仕様', 'インクカートリッジ']
# [407] GWまでGoToの継続を 公明提言 国内 ['菅総理', '公明党', '提言', 'GoTo', 'ゴールデンウイーク', '継続', 'トラベル', '斉藤']
# [408] 克行被告の公判 11月4日再開 国内 ['議員', '里', '検察', '審理', '案', '弁護側', '東京地裁', '保釈']
# [409] 脱臼 首位打者DeNA佐野を抹消 スポーツ ['スタメン', '連戦', '森', '昇格', '4番', '1軍', '復帰', '首位打者']
# [410] 米 対中関税巡りWTOに上訴 経済 ['WTO', 'ブルームバーグ', '上訴', '関税', '米国', 'パネル', '中国', '判断']
# [411] 西武1位 会見で頭が真っ白 スポーツ ['渡部', 'ありがとう', '会見', '巨漢', '監督', 'メッセージ', 'です', '赤らめ']
# [412] LCC新ブランド立ち上げへ ANA 経済 ['機', 'ANA', '型', '退役', 'ます', 'ボーイング787', 'ボーイング777', '立ち']
# [413] 手越祐也 独立で「やりがい」 エンタメ ['手越', '千', '動画', 'フォロワー', '4億円', '円', '万', '月収']
# [414] 親子2人切られ父死亡 男逮捕 国内 ['邦雄', '昇', '切りつけ', 'さん', '根本', '関根', '背中', '従業員']
# [415] 露の下院議員91人感染1人死亡 国際 ['下院', 'ウォロジン', '集団感染', 'ロシア', '田村', '下院議員', 'モスクワ', 'プーチン大統領']
# [416] 古坂大魔王 第2子女児誕生 エンタメ ['可愛い', '第2子', '古坂', '55分', '2696', 'ママ', 'グラム', '頑張る']
# [417] ギャグ打撃 ダチョウ久々キス エンタメ ['キス', '上島', 'リップクリーム', 'フェイスシールド', 'ダチョウ', '芸', '久々', 'コロナ禍']
# [418] ANA 5100億円の赤字見通し 経済 ['億', '前年', '円', 'ピーチ', '赤字', '黒字', 'LCC', '飛行機']
# [419] 東京都 新たに158人感染確認 国内 ['重症', '感染者', '先月25日', '286人', '158人年', '158人', '都', '17人']
# [420] ダチョウ倶楽部 久々のキス芸 エンタメ ['キス', '上島', 'リップクリーム', 'フェイスシールド', 'ダチョウ', '芸', '久々', 'コロナ禍']
# [421] 血の入れ替え G最多19人指名 スポーツ ['指名', '育成', 'ドラフト', '佐藤', '投手', '球団', '将来性', '★']
# [422] 巨人メルセデス手術 今季絶望 スポーツ ['左肘', '先発', 'ファーム', 'クリーニング', '来季', '違和感', 'リハビリ', '開幕']
# [423] JAL 再上場後初の赤字見通し 経済 ['JAL', '旅客', '赤字', '国際線', '連結決算', '534', '2000億円', '見通し']
# [424] 携帯値下げへ3つの柱 総務省 経済 ['料金', '乗り換え', 'アクションプラン', '携帯', '競争', '総務省', '柱', '携帯電話']
# [425] 漫才初 西川きよし文化功労者 エンタメ ['やすし', '選出', '漫才', '文化功労者', '吉本興業', '功績', 'いただい', '74']
# [426] 出産一時金 引き上げ含め検討 国内 ['所得制限', 'に関し', '保険', '適用', '出産育児一時金', '保険料', '42万円', '早急']
# [427] 野口さん搭乗 11月15日宇宙へ 科学 ['打ち上げ', '宇宙船', 'ドラゴン', 'クルー', 'ISS', '野口聡一', '搭乗', '宇宙飛行士']
# [428] 盗撮被害 女子選手が語る苦悩 国内 ['アカウント', '性的', 'DM', '画像', '尊厳', '―', 'アスリート', '普通']
# [429] 煉獄ファン「300億円の男に」 エンタメ ['煉獄', '300', '男', '億', '興収', 'さん', 'ファン', '100億の男']
# [430] 再審無罪 女性に補償5997万円 国内 ['西山', '額', '上限', '拘束', '補償', '請求', '自白', '無罪判決']
# [431] 判事承認 トランプ氏は自賛 国際 ['バレット', '承認', 'トランプ大統領', '式典', '最高裁判事', '保守', '氏', '正式']
# [432] 米大統領選 期日前6000万人に 経済 ['大統領選', 'プロジェクト', '有権者', '達する', '政治学', 'マイケルマクドナルド', '5000万人', '1908年']
# [433] 橋田寿賀子氏ら5人に文化勲章 ライフ ['文化功労者', '文化勲章', '漫才', '90', '74', '顕彰', '近藤淳', '親授式']
# [434] 都構想 隣接2市も特別区移行? 国内 ['特別区', '市長', '市', '移行', '区', '豊中', '守口', '堺']
# [435] 冬休み一律延長求めず 文科相 国内 ['学校', '分散', '経済', '補習', '教育委員会', '冬休み', '萩生田', '文部科学相']
# [436] かつや好調 裏に高いシェア? 経済 ['かつや', '専門店', '店舗', 'ます', '売り上げ', '展開', '業態', 'とんかつ']
# [437] R・ナダル プロゴルフ大会6位 スポーツ ['ナダル', 'スペイン', '2020', '大会', '選手権', '腕前', '混合', '母国']
# [438] 逃げた警察犬を無事保護 兵庫 国内 ['クレバ', '失踪', '号', '鑑識課', '警察犬', '県警', '行方不明者', '山中']
# [439] 任命拒否想定せず 04年資料に 国内 ['推薦', '任命', '拒否', '方式', '現行', '83年', '日本学術会議', '制']
# [440] ネット中傷 裁判手続き創設へ 国内 ['加害者', '悪質', '被害者', '裁判', '手続き', '骨子', '通信記録', '誹謗中傷']
# [441] 潜水漁業中2人溺れ死亡 沖縄 国内 ['潜水', '兄', '船長', '漁船', '漁業', '息子', 'いずれ', '陸さん']
# [442] 河井案里被告の保釈認める 国内 ['保釈', '議員', '里', '公判', '案', '地裁', '克行', '請求']
# [443] 所信表明「処理水」は触れず 国内 ['復興', '東北', '避難指示', '震災', '原発事故', '処理', '解除', '水']
# [444] 首相のガスゼロ宣言 国連評価 国際 ['目標達成', 'フォンデアライエン', 'グテレス', '歓迎', '気候変動', '国連事務総長', '排出', '技術的']
# [445] 保守派の米最高裁判事を承認 国際 ['最高裁判事', '保守派', 'バレット', '承認', '大統領選', '最高裁', '法科大学院', 'リベラル']
# [446] 目黒 強盗疑いで少年3人逮捕 国内 ['少年', '装っ', '押し入り', '宅配', '19歳', '600万円', '業者', '部屋']
# [447] 沢村にMLB複数球団が興味か スポーツ ['メジャー', 'サイト', 'オフ', '球団', '沢村', 'ポスティングシステム', '投げ', 'ドル']
# [448] フィギュア今季GP 得点非公認 スポーツ ['自己ベスト', 'ISU', '得点', '記録', '開催概要', '開催国', '置く', '国際スケート連盟']
# [449] 消える日立マーク 市民寂しさ 地域 ['日立', 'マーク', '工場', '文字', 'パワー', 'MHPS', '群', '三菱']
# [450] 京都高島屋「くぼ地」店に幕 地域 ['京都', 'ビル', '高島屋', '善', '池', '閉店', '店', '社長']
# [451] 栃木知事選「魅力度」争点に 国内 ['最下位', '栃木', '知事', '魅力', 'イチゴ', '福田', 'ギョーザ', '県民']
# [452] EU ナイジェリアWTO候補支持 国際 ['EU', 'オコンジョイウェアラ', 'WTO', '選', '事務局長', '氏', '支持', '通商交渉']
# [453] 政府 デジタル庁恒久化の方針 国内 ['デジタル', '庁', '時限', '組織', '内閣', '復興庁', '直轄', 'めざす']
# [454] 製油所12カ所 耐震不足の恐れ 国内 ['石油', '製油', '所', 'カ所', '耐震', '出荷', '会社', '院']
# [455] 月の水 想定より大量に存在か 科学 ['水', '月面', '論文', '太陽光', '存在', '2本', 'はるか', '観測']
# [456] トランプ氏 南部州死守の重圧 国際 ['下処理', 'トランプ氏', '投票', 'フロリダ', 'バイデン', '州', '郵便', '判明']
# [457] 日産、中国の生産能力3割増へ 経済 ['日産', '台', '生産能力', '車種', '中国', 'か所', '糸口', '生産ライン']
# [458] 乃木坂樋口 役作り30cm髪切る エンタメ ['風間', '教場', '教官', '”', '“', '樋口', '木村', '坂根']
# [459] 広瀬すず「戦後初のCA」役に エンタメ ['小鞠', 'エア', 'ガール', '航空', '日本', '松木', '空', '飛行機']
# [460] 指名漏れ妥当? 田沢に残る3択 スポーツ ['田沢', '独立リーグ', 'ドラフト会議', 'NPB', '指名', 'プレー', '場', 'スカウト']
# [461] Zeebra、家族と別居報道 エンタメ ['Zeebra', '本誌', '不倫', '別居', 'NiziU', '家族', '離婚', 'マンション']
# [462] NYダウ大幅続落 650ドル安 経済 ['安', 'ドル', '続落', '反落', '下落幅', 'ハイテク', 'ナスダック総合指数', 'ダウ平均']
# [463] ももクロ高城 阪神D1にエール エンタメ ['佐藤', '高城', '推し', 'ます', '選手', '阪神', '高城れに', '過言']
# [464] アント 史上最高額で上場へ 経済 ['上海', '香港', '兆', '額', '両', '電子商取引', '証取', '証券取引']
# [465] 所信表明 言い間違い6カ所 国内 ['薬価', '重症', '化', 'ところ', '間違える', '間違え', '重点', '貧困対策']

# %%
ranking2 = model2.docvecs.most_similar(101, topn=50) # 今回も太宰治の「人間失格」で検証

# %%
ranking2[:5]
# Out:
# [(112, 0.40038585662841797),
#  (293, 0.400232195854187),
#  (310, 0.3920342028141022),
#  (123, 0.38493385910987854),
#  (338, 0.383727103471756)]

# %%
df['title'][101]
# Out:
# 'トランプ氏 接戦州で差縮める'

# %%
df['text'][101]
# Out:
# ' ワシントン横堀裕也米大統領選は10月30日11月3日の投開票まであと4日に迫り共和党のドナルドトランプ大統領と民主党のジョーバイデン前副大統領の陣営がラストスパートをかけている勝敗の鍵を握る接戦州ではバイデン氏のリードが縮まっておりトランプ氏が懸命の巻き返しを見せている 米政治情報サイトリアルクリアポリティクスはペンシルベニアミシガンウィスコンシンノースカロライナフロリダアリゾナの6州を接戦州として挙げる6州に限った支持率は10月に入りバイデン氏のリードが最大5ポイントあったが30日時点では31ポイント差となっている トランプ氏は30日ウィスコンシンなど3州を回り経済政策をアピールした31日以降残り3日間で14回の支持者集会を開く計画だバイデン氏もウィスコンシンなど3州で遊説しトランプ氏の新型コロナウイルス対策を批判した感染拡大を踏まえて過密な遊説日程は避けてきたが最終盤でピッチを上げている'

# %%
le2 = preprocessing.LabelEncoder()

vecs2 = []
for i in range(len(model2.docvecs)):
    vecs2.append(model2.docvecs[i])
category2 = list(df['category'])
df2 = pd.DataFrame(vecs2)
df2.insert(0, 'category', category2)
df2.category = le2.fit_transform(df2.category)

# %%
df2
# Out:
#      category         0         1         2         3         4         5  \
# 0           0  0.000095 -0.001083 -0.001368  0.002356 -0.002926 -0.003537
# 1           0  0.001314  0.001587 -0.005135 -0.003239 -0.004831  0.003999
# 2           3 -0.004564 -0.004734  0.004541  0.002877  0.004813 -0.000409
# 3           0 -0.001005  0.004638  0.003528 -0.002963  0.001605 -0.003065
# 4           1  0.003498  0.003317 -0.003191  0.004279 -0.008310 -0.001408
# ..        ...       ...       ...       ...       ...       ...       ...
# 461         0  0.004315 -0.001168 -0.006553  0.000808 -0.004571  0.000815
# 462         7  0.002363 -0.005700  0.005673  0.000037  0.004478  0.001016
# 463         0 -0.001177 -0.003356 -0.005123 -0.002213  0.001289  0.003350
# 464         7  0.004274 -0.003323  0.002485  0.001572  0.008385  0.002250
# 465         3 -0.002571  0.002985  0.000573 -0.000535 -0.000781  0.003774
#
#             6         7         8  ...        90        91        92  \
# 0    0.001955  0.005850  0.000840  ...  0.000927  0.002458  0.002507
# 1   -0.002909  0.008253 -0.007952  ...  0.005673  0.004437  0.003279
# 2   -0.000462  0.000717 -0.001143  ... -0.006821 -0.000679 -0.005411
# 3   -0.000298 -0.002616  0.000464  ... -0.000902  0.005198  0.001158
# 4   -0.005105  0.005199  0.001797  ...  0.001453  0.005321  0.002851
# ..        ...       ...       ...  ...       ...       ...       ...
# 461 -0.004403  0.007349 -0.004945  ...  0.005334  0.004496  0.004437
# 462  0.001239  0.000234  0.001017  ... -0.005108  0.000237  0.000280
# 463 -0.003976  0.005075  0.002284  ...  0.002534 -0.000506  0.004687
# 464  0.003753  0.001801 -0.002465  ...  0.001968 -0.003857 -0.006825
# 465  0.002997  0.004649  0.000231  ...  0.001560 -0.001509 -0.003704
#
#            93        94        95        96        97        98        99
# 0   -0.000967  0.004886  0.001878 -0.000447 -0.003232 -0.000388  0.002429
# 1   -0.001737  0.004826  0.001510 -0.001676 -0.004736 -0.002369  0.001417
# 2   -0.002095 -0.000219  0.000851 -0.004714 -0.003809  0.004626 -0.002468
# 3   -0.001881  0.002252 -0.002918  0.000163 -0.004927  0.001834 -0.001120
# 4   -0.002443  0.000244 -0.000442 -0.001569  0.000735 -0.003838 -0.005828
# ..        ...       ...       ...       ...       ...       ...       ...
# 461 -0.001712 -0.001014  0.003673 -0.002231 -0.002675 -0.003579 -0.003382
# 462 -0.004343  0.001077 -0.002477 -0.003200  0.001348 -0.001135 -0.002996
# 463 -0.000802  0.000021 -0.001859 -0.000063  0.002474  0.002657 -0.002879
# 464  0.002625 -0.002647  0.003535  0.001874 -0.002147  0.007186  0.004241
# 465  0.001978  0.003582  0.002954 -0.000875 -0.005012  0.004545 -0.002659
#
# [466 rows x 101 columns]

# %%
dfs2 = df2.iloc[:, 1:].apply(lambda x: (x - x.mean()) / x.std(), axis=0)
# dfs.head()

# %%
pca2 = PCA()
pca2.fit(dfs2)
feature2 = pca2.transform(dfs2)

# %%
# 主成分得点
# pd.DataFrame(feature, columns=["PC{}".format(x + 1) for x in range(len(dfs.columns))]).head()

# %%
# 第一主成分と第二主成分でプロットする
plt.figure(figsize=(6, 6))
plt.scatter(feature2[:, 0], feature2[:, 1], alpha=0.8, c=list(df2.iloc[:, 0]))
plt.grid()
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()
