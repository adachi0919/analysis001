# %%
import requests
from bs4 import BeautifulSoup
import re
import itertools
import pandas as pd, numpy as np
import os
import glob
import pathlib
import re
import janome
import jaconv
from janome.tokenizer import Tokenizer
from janome.analyzer import Analyzer
from janome.charfilter import *
import string

# %%
def symbol_removal(soup):
    soup = unicodedata.normalize("NFKC", soup)
    exclusion = "「」『』【】、。・◇◆" + "\n" + "\r" + "\u3000"
    soup = soup.translate(str.maketrans("", "", string.punctuation  + exclusion))
    return soup

# %%
url = "https://news.yahoo.co.jp/topics/top-picks"
URL = "https://news.yahoo.co.jp/"
res = requests.get(url)
soup = BeautifulSoup(res.text, "html.parser")

# %%
all_page_links = []
all_page_links.append(url)
while True:
    try:
        next = soup.find("li", class_="pagination_item-next").find("a")["href"]
        next_link = URL + next
        all_page_links.append(next_link)
        next_res = requests.get(next_link)
        soup = BeautifulSoup(next_res.text, "html.parser")
    except:
        break

# %%
all_page_links[5]
# Out:
# 'https://news.yahoo.co.jp//topics/top-picks?page=6'

# %%
# title_list = []
# category_list = []
# text_list = []
# for i, url in enumerate(all_page_links): # all_page_links: 全てのニュースのリスト
#     if i == 5:
#         res = requests.get(url) # url: 25個分のニュースのリスト
#         soup = BeautifulSoup(res.text, "html.parser")
#         page_soup = soup.find_all("a", class_="newsFeed_item_link")
#         for href in page_soup:
#             link = href["href"] # link: 一つのニュースのリンク(本文は一部のみ)
# #             print(link)
#             link_res = requests.get(link)
#             href_soup = BeautifulSoup(link_res.text, "html.parser")
#             title = href_soup.find("h1", class_=re.compile("^sc")).string
#             title_link = href_soup.find("a", class_="sc-eAyhxF")["href"] # title_link: 本文
# #             print(title_link)
#             res = requests.get(title_link)
#             soup = BeautifulSoup(res.text, "html.parser")
# #             print(soup.find("p", class_=re.compile("^sc")))
            
#             category = soup.find_all("li", class_="current")
# #             print(category)
# #             category = category[1].string
#             if category == []:
# #                 print(category)
#                 continue
#             else:
#                 for tag in soup.find_all(["a"]):
#                     tag.decompose()
# #                 print(soup.find_all("p", class_="yjDirectSLinkTarget")[0].get_text())
#                 try:
#                     text_list.append(soup.find_all("p", class_="yjDirectSLinkTarget")[0].get_text())
#                     title_list.append(title)
# #                     print(category)
#                     print(category[1].string)
# #                     category_list.append(category)
# #                     print("<", title, ">")
#                 except:
#                     continue

# %%
title_list = []
category_list = []
text_list = []
for i, url in enumerate(all_page_links): # all_page_links: 全てのニュースのリスト
#     if i == 16:
        res = requests.get(url) # url: 25個分のニュースのリスト
        soup = BeautifulSoup(res.text, "html.parser")
        page_soup = soup.find_all("a", class_="newsFeed_item_link")
        for href in page_soup:
            link = href["href"] # link: 一つのニュースのリンク(本文は一部のみ)
#             print(link)
            link_res = requests.get(link)
            href_soup = BeautifulSoup(link_res.text, "html.parser")
            title = href_soup.find("h1", class_=re.compile("^sc")).string
            title_link = href_soup.find("a", class_="sc-eAyhxF")["href"] # title_link: 本文
#             print(title_link)
            res = requests.get(title_link)
            soup = BeautifulSoup(res.text, "html.parser")
#             print(soup.find("p", class_=re.compile("^sc")))
            
            category = soup.find_all("li", class_="current")
#             print(category)
            try:
                category = category[1].string
            except:
                continue
#             if category == []:
#                 print(category)
                continue
            else:
                for tag in soup.find_all(["a"]):
                    tag.decompose()
#                 print(soup.find_all("p", class_="yjDirectSLinkTarget")[0].get_text())
                try:
                    print(i, title)
                    soup = soup.find_all("p", class_="yjDirectSLinkTarget")[0].get_text()
                    soup = symbol_removal(soup)
#                     print(soup)
                    text_list.append(soup)
#                     text_list.append(soup.find_all("p", class_="yjDirectSLinkTarget")[0].get_text())
                    title_list.append(title)
#                     print(category)
#                     print(category)
                    category_list.append(category)
#                     print("<", title, ">")
                except:
                    continue
# Out:
# 0 内村航平が新型コロナ陽性
# 0 くそたれ地震 不満のみ込む今
# 0 GoToイート紙切れ 担当者憤り
# 0 週末 東日本で冷え込み強まる
# 0 上原氏 田沢の結果あまりに酷
# 0 SB周東が12戦連続盗塁 プロ新
# 0 TDR運営 511億円赤字の見通し
# 0 伊藤容疑者 事故直後の映像
# 0 日本初 糖質0ビールどう実現
# 0 給食で100人超食中毒 鶏に菌
# 0 ビシエド抹消 打点王は絶望的
# 0 案里被告 参院本会議を欠席
# 0 「THE W」決勝進出10組が決定
# 0 巨人 きょう優勝の条件は
# 0 ニトリ 島忠にTOB実施を発表
# 0 鈴木氏の出馬断念 知事は驚き
# 0 東京都 新たに221人感染確認
# 0 伊藤容疑者 とんかつDJは公開
# 0 トヨタ、9月生産が過去最高
# 0 GoToイベント 第1弾にUSJ
# 0 歓楽街に検査拠点を 分科会
# 0 AIでいじめ対策 7市導入検討
# 0 国内感染者 客船含め10万人超
# 0 デンソー中間決算赤字711億円
# 0 伊藤容疑者 目撃者が追い説得
# 1 日銀 大規模緩和の維持決定
# 1 伊藤容疑者逮捕 事務所が謝罪
# 1 フジ 伊藤容疑者番組差し替え
# 1 行き過ぎ指導 元生徒が提訴
# 1 再審無罪 宮田浩喜さんが死去
# 1 李元大統領に懲役17年確定
# 1 第一生命 企業年金利率下げる
# 1 伊藤容疑者 事故現場離れた
# 1 エビ中・安本彩花 治療で休養
# 1 男性不妊 語る治療の難しさ
# 1 スノボ五輪銅 平岡被告に有罪
# 1 伊藤健太郎容疑者を逮捕
# 1 政府 多機能イージス艦新造へ
# 1 家に犬164匹 多頭飼育崩壊か
# 1 伊藤健太郎さん事故 女性重傷
# 1 競技場の盗撮 対策の難しさ
# 1 首里城火災1年あの日の悔しさ
# 1 米 WTO事務局長の選出を阻止
# 1 行き過ぎ指導 元生徒が提訴へ
# 1 ニトリ、島忠の全株取得へ
# 1 仏 ロックダウン再導入へ
# 1 鬼滅 ファンが生んだ「聖地」
# 1 鈴木大地氏 知事選出馬を断念
# 1 深田恭子 新婚生活を「妄想」
# 1 GoTo 電子クーポン不正取得か
# 2 YouTuber事務所VAZ 社長退任
# 2 NY株943ドル安 3カ月ぶり安値
# 2 阪神一筋の上本博紀 退団へ
# 2 白石 卒コンで何度も「幸せ」
# 2 錦織圭 右肩負傷で今季終了
# 2 白石 卒コン序盤から涙腺崩壊
# 2 かんぽ不正 新たに490人処分
# 2 関テレ デヴィ夫人発言で謝罪
# 2 4連敗 G監督そうですね10連発
# 2 森元首相 鈴木大地氏出馬に反対
# 2 シリアの停戦 崩壊の危機に
# 2 今年台風上陸なし?幸運重なる
# 2 SB周東11試合連続盗塁に成功
# 2 時速380km「圧力感じない」
# 2 大麻所持 東海大生ら2人逮捕
# 2 JTB 転勤でも引っ越しせずOK
# 2 嵐が謝罪 中日「恐縮です」
# 2 コロナ感染「微増傾向続く」
# 2 集配所殺傷 遺族「許さない」
# 2 日立製作所 営業利益39%減
# 2 紙不足 京都がGoTo食事券停止
# 2 三代目ELLYがパパに 結婚せず
# 2 菅首相 任命拒否の判断変えず
# 2 JR東海 純損益1135億円の赤字
# 2 調布の陥没 東日本高速が陳謝
# 3 貯水槽に男性遺体 殺人で捜査
# 3 トヨタ 39車種21万台リコール
# 3 若年女性の失業4.7% 最も悪化
# 3 土砂崩れ作業員1人死亡 大阪
# 3 試合中断 嵐がおわびの色紙
# 3 アパート内で豚解体 4人逮捕
# 3 漁業被害 アザラシがゴロゴロ
# 3 デヴィ夫人 不妊巡る発言謝罪
# 3 土砂崩れ1人心肺停止 大阪
# 3 正月休み分散 自民幹部が苦言
# 3 首相 任命拒否の違法性否定
# 3 東京都 新たに171人感染確認
# 3 大好きだった祖母殺害 介護限界
# 3 6人死傷火災 元店長に有罪
# 3 国税庁「路線価」引き下げず
# 3 MLBド軍優勝 監督は沖縄出身
# 3 ノブコブ徳井、離婚していた
# 3 加藤氏 原発の新増設想定せず
# 3 三男死なせた長女 家族に何が
# 3 MLBドジャース32年ぶり世界一
# 3 感染対策が不足 受刑者が提訴
# 3 大塚家具 久美子社長が辞任へ
# 3 ハワイ 日本の観光客受け入れ
# 3 メッシと対立 バルサ会長辞任
# 3 北海道 警戒ステージ引き上げ
# 4 戦略違う?みちょぱ&ゆきぽよ
# 4 間宮祥太朗 成田凌から相談も
# 4 間宮祥太朗 ブレイクなかった
# 4 携帯値下げ SBとKDDIが新料金
# 4 静岡銀と山梨中銀が提携へ
# 4 国家公務員の月給 据え置きへ
# 4 ALFA-X初試乗会 時速382km
# 4 鬼滅特需も 続くシネコン苦境
# 4 米で警官撃ち黒人死亡 波紋
# 4 首里城再建の寄付 50億円突破
# 4 卒後3年は新卒扱い 政府要請
# 4 トヨタ系に出向 三菱重が打診
# 4 ツキヨタケ中毒相次ぐ 県注意
# 4 学術会議 官邸14年選考も関心
# 4 陸上コールマン 五輪は絶望的
# 4 「女性活躍」重い?現場の疲弊
# 4 米、香港活動家の亡命拒絶か
# 4 米大統領選まで1週間 接戦へ
# 4 伊の新規感染2.2万人過去最多
# 4 ANA 「再浮揚」なお視界不良
# 4 消費税不正 40億円を追徴課税
# 4 病で収監延期 田代まさしの今
# 4 GoToトラベル延長へ 政府調整
# 4 FIFA会長がコロナ陽性 隔離
# 4 ミラクル9 入社1年目アナ起用
# 5 LVMH ティファニー買収再交渉
# 5 斎藤佑樹 右肘手術を検討
# 5 SB内川退団へ 現役続行は模索
# 5 個人番号夜間も対応を 総務相
# 5 SB優勝 ロボット踊る祝勝会
# 5 ANA コロナ後にらみ雇用維持
# 5 トランプ氏 本当に負けるのか
# 5 コロチキ西野 第1子男児誕生
# 5 中国 35年にガソリン車全廃へ
# 5 SBがV奪回 裏に「老将の知」
# 5 「17連休」要請 西村氏が否定
# 5 河井案里被告を保釈
# 5 ソフトバンク3年ぶり優勝
# 5 座間事件 2つのアカ使い接触
# 5 ロイヤルHD早期退職200人募集
# 5 大阪 新たに142人の感染確認
# 5 原子力規制委に不正アクセス
# 5 発言物議 デヴィ夫人は反論
# 5 「無限くら寿司」やってみた
# 5 注意点ない?「無限くら寿司」
# 5 KDDI 20ギガ4千円弱で調整
# 5 日立金属 3200人リストラへ
# 5 西武1位 爆笑会見の裏明かす
# 5 作家・大城立裕さん死去 95歳
# 6 エコリカがキヤノンを提訴
# 6 GWまでGoToの継続を 公明提言
# 6 克行被告の公判 11月4日再開
# 6 脱臼 首位打者DeNA佐野を抹消
# 6 米 対中関税巡りWTOに上訴
# 6 西武1位 会見で頭が真っ白
# 6 LCC新ブランド立ち上げへ ANA
# 6 手越祐也 独立で「やりがい」
# 6 親子2人切られ父死亡 男逮捕
# 6 露の下院議員91人感染1人死亡
# 6 古坂大魔王 第2子女児誕生
# 6 ギャグ打撃 ダチョウ久々キス
# 6 ANA 5100億円の赤字見通し
# 6 東京都 新たに158人感染確認
# 6 ダチョウ倶楽部 久々のキス芸
# 6 血の入れ替え G最多19人指名
# 6 巨人メルセデス手術 今季絶望
# 6 再び非常宣言 深刻なスペイン
# 6 JAL 再上場後初の赤字見通し
# 6 携帯値下げへ3つの柱 総務省
# 6 漫才初 西川きよし文化功労者
# 6 出産一時金 引き上げ含め検討
# 6 野口さん搭乗 11月15日宇宙へ
# 7 盗撮被害 女子選手が語る苦悩
# 7 煉獄ファン「300億円の男に」
# 7 再審無罪 女性に補償5997万円
# 7 判事承認 トランプ氏は自賛
# 7 米大統領選 期日前6000万人に
# 7 橋田寿賀子氏ら5人に文化勲章
# 7 都構想 隣接2市も特別区移行?
# 7 冬休み一律延長求めず 文科相
# 7 かつや好調 裏に高いシェア?
# 7 R・ナダル プロゴルフ大会6位
# 7 逃げた警察犬を無事保護 兵庫
# 7 任命拒否想定せず 04年資料に
# 7 ネット中傷 裁判手続き創設へ
# 7 潜水漁業中2人溺れ死亡 沖縄
# 7 河井案里被告の保釈認める
# 7 所信表明「処理水」は触れず
# 7 首相のガスゼロ宣言 国連評価
# 7 保守派の米最高裁判事を承認
# 7 目黒 強盗疑いで少年3人逮捕
# 7 沢村にMLB複数球団が興味か
# 7 フィギュア今季GP 得点非公認
# 7 消える日立マーク 市民寂しさ
# 7 京都高島屋「くぼ地」店に幕
# 7 栃木知事選「魅力度」争点に
# 7 EU ナイジェリアWTO候補支持
# 8 政府 デジタル庁恒久化の方針
# 8 製油所12カ所 耐震不足の恐れ
# 8 月の水 想定より大量に存在か
# 8 トランプ氏 南部州死守の重圧
# 8 日産、中国の生産能力3割増へ
# 8 乃木坂樋口 役作り30cm髪切る
# 8 広瀬すず「戦後初のCA」役に
# 8 指名漏れ妥当? 田沢に残る3択
# 8 Zeebra、家族と別居報道
# 8 NYダウ大幅続落 650ドル安
# 8 ももクロ高城 阪神D1にエール
# 8 アント 史上最高額で上場へ
# 8 所信表明 言い間違い6カ所
# 8 中国 尖閣で「領空侵犯」主張
# 8 不妊治療 男女とも保険適用拡大
# 8 任命拒否 首相「大学に偏り」
# 8 育成勇人 比較され苦しかった
# 8 習長期政権へ布石か 5中全会
# 8 公明 受験生への2万円案撤回
# 8 首相「温室ガス2050年ゼロ」
# 8 不妊治療の保険適用 男性にも
# 8 年始休暇の延長 二階氏不快感
# 8 続く芸能人独立 音事協に聞く
# 8 川上未映子さん 中傷受け提訴
# 8 藤井2冠が3連敗 王将挑戦逃す
# 9 田沢 育成でも指名されず終了
# 9 ナゴルノ3度目停戦 すぐ崩壊
# 9 巨人 育成で「坂本勇人」指名
# 9 「ガス臭い」神奈川また異臭
# 9 TikTok中国事業 香港上場検討
# 9 安住氏 もう一つ党が消えれば
# 9 田沢 まさかの支配下指名漏れ
# 9 オリンパス損失隠し 賠償確定
# 9 日銀、大規模緩和策を維持へ
# 9 日本航空 3000億円調達を検討
# 9 全在校生が転校へ 兵庫私立高
# 9 ドラフト 巨人くじ引き10連敗
# 9 日テレ 徳井復帰は視聴者賛否
# 9 4球団競合 早川交渉権は楽天
# 9 近大・佐藤は阪神が交渉権
# 9 Jまた不祥事 村井満氏悲痛
# 9 首相の所信表明 異例の遅さ
# 9 年始の休暇延長 企業の対応は
# 9 4-9月クマ出没 過去5年で最多
# 9 アラブ諸国で仏製品不買運動
# 9 初鹿衆院議員の辞職を許可
# 9 目黒 宅配装い500万円奪う
# 9 東京都 新たに102人感染確認
# 9 持続化給付金 終了を提言
# 10 自転車であおり運転 初の逮捕
# 10 ゼネスト?ベラルーシ反政権派
# 10 首相 就任後初めて所信表明
# 10 FWアデミ選手 酒気帯び容疑
# 10 反省の日々 渡部建が心境語る
# 10 18年前の殺人 DNA採取に成功
# 10 SNSの相手信用できる?誘拐も
# 10 往来再開 海外旅行解禁いつ?
# 10 加藤氏 核禁条約に署名しない
# 10 史上最速 鬼滅が興収100億円
# 10 乳がん0.5mm未満も識別 阪大
# 10 どっちがホンマ? 都構想議論
# 10 死亡ひき逃げ 女性に無罪判決
# 10 官僚サービス残業 背景に予算
# 10 田沢純一 ドラフト指名あるか
# 10 実習生の転職解禁 矛盾あらわ
# 10 家畜盗難 ベトナム人ら関与か
# 10 オウムへの観察処分 更新請求
# 10 車のライト まぶしさの正体は
# 10 山手線西側の私鉄 終電混乱?
# 10 コロナ 変わる化粧品のあり方
# 10 引退車両撮影しようと 駅侵入
# 10 監禁事件の容疑者 2人逃走か
# 11 鬼滅 実写化の可能性と問題点
# 11 新型出生前診断 本格議論へ
# 11 海鳥エトピリカ 減少止まらず
# 11 コロナ「謎対策」生まれる謎
# 11 ナゴルノ紛争 米仲介で停戦へ
# 11 不明者捜索中の警察犬 逃走中
# 11 都民割 「対象外」ホテル悲鳴
# 11 最大4球団の競合?ドラ注目2人
# 11 万博 外国企業への課税軽減へ
# 11 唯一の被爆国 条約に背を向け
# 11 自転車初あおり運転 男逮捕へ
# 11 東京BABYLON 30年経てアニメ
# 11 スペインで再び非常事態宣言
# 11 仏の新規感染者数 過去最多に
# 11 鈴木大地氏 知事選に立候補へ
# 11 臨時国会が召集 与野党攻防へ
# 11 石橋貴明&新しい地図 共演へ
# 11 レガネス柴崎 移籍後初ゴール
# 11 ハミルトン F1歴代最多92勝目
# 11 引退五十嵐 フェンスよじ登る
# 11 核禁条約が迫る価値観の転換
# 11 東京Dに球児登場曲 粋な敵将
# 11 ジュゴンいる?辺野古やきもき
# 11 警察署10人感染 家で待機7割
# 11 土地購入 国籍届け出義務化へ
# 12 市川実日子 毎回感じる「恥」
# 12 日本 韓国WTO候補を不支持へ
# 12 「じゃない方」選ぶ中井貴一
# 12 市川実日子 演じる恥ずかしさ
# 12 首相が初論戦 臨時国会の焦点
# 12 岡山知事選 伊原木氏の3選確実
# 12 スバル 一斉に受注終了の怪
# 12 サンタ「Xmasは中止しない」
# 12 美容室の雑談苦手 どう対処?
# 12 クルーズ船 再開第1号が出港
# 12 コロナ禍 減った他の感染症は
# 12 ビビる大木 合コン中にも仕事
# 12 都構想反対が賛成上回る 調査
# 12 核禁条約 政府は有効性疑問視
# 12 ド軍「不運」ドタバタ幕切れ
# 12 JALの赤字850億円 7ｰ9月期
# 12 公園で7mの木倒れる 頭直撃
# 12 なぜ相次ぐ?荒唐無稽な陰謀論
# 12 ビビる大木 台本見るなの意味
# 12 おにぎり小型化?コンビニ見解
# 12 声優の福原綾香、結婚を発表
# 12 コントレイルV 父子無敗3冠
# 12 就活生の裏アカ特定 成果は
# 12 沖縄平和ガイド コロナで危機
# 12 アイドル死去 中傷に法的措置も
# 13 都124人感染 累計3万人超える
# 13 トルコ 仏大統領は精神検査を
# 13 菊花賞 親子で牡馬三冠なるか
# 13 ふるさと納税 「抜け道」も
# 13 看護介護もらえぬ慰労金 憤り
# 13 赤ちゃんポストの開設者 死去
# 13 おひとりさま 危機どう備える
# 13 国勢調査 町内会と縁切る人も
# 13 ベトナム人を誤認逮捕 警視庁
# 13 23年飼育のエイ新種 なぜ判明
# 13 異例の個室 ドラフトどうなる
# 13 ローソン看板にツバメ 今年は
# 13 核兵器廃絶へ 広島喜び広がる
# 13 上原氏 田沢「新人」ではない
# 13 トランプ氏 資金集めでも劣勢
# 13 アフガンで自爆 ISが犯行声明
# 13 娘を丸刈りに どこから虐待か
# 13 天王洲アイルって何 由来は?
# 13 サムスン会長 李健熙氏が死去
# 13 伊藤健太郎 原作あえて読まず
# 13 製品出火 アマゾンを提訴へ
# 13 瀬戸内海「きれい過ぎ」是正へ
# 13 ANAだけじゃない 非航空活路
# 13 温暖化の影響ある 自治体8割
# 14 蘭で歴史的大差 19歳FW5得点
# 14 12年ぶり 台風「上陸なし」か
# 14 伊感染者50万超す 最悪ペース
# 14 菊花賞「100円元返し」も?
# 14 トヨタに社員出向 ANA要請へ
# 14 森山直太朗の演技力 業界注目
# 14 神木隆之介 坊の声母と練習
# 14 核兵器禁止条約、発効へ
# 14 核兵器禁止条約が発効へ
# 14 米大統領選 トランプ氏が投票
# 14 プロ野球中断 ジャニーズ謝罪
# 14 「気の毒」 転落巻き添え死亡
# 14 偽動画 一般人も素材のリスク
# 14 次のファーウェイ 中国で台頭
# 14 神宮で珍事 試合が2度中断
# 14 スターフライヤー 増資を検討
# 14 NMB吉田朱里卒コン 何度も涙
# 14 親子で空き巣 父と中3を逮捕
# 14 「複雑」な携帯料金に改革案
# 14 GoTo商店街「予想以上の人」
# 14 法政大サッカー部 20人感染
# 14 10万円 麻生氏が効果疑問視
# 14 インク容器巡りキヤノン提訴へ
# 14 脳性まひ乗り越え 起業に挑戦
# 14 ロシア第2波 新規感染が最悪
# 15 ラミレス監督 今季限りで退任
# 15 「時間ない」拉致家族会訴え
# 15 園児の手に点数記入 教諭採点
# 15 正月の芸能人ハワイ取材消滅?
# 15 深刻に悩む人へ あんぱん送る
# 15 小惑星の岩石60g超 NASA採取
# 15 阪神・サンズ 侮辱行為で退場
# 15 市議会議長逮捕 贈賄申し込み
# 15 感染で中傷の病院に匿名寄付
# 15 北海道の感染者 過去最多60人
# 15 ポーランド大統領 コロナ陽性
# 15 愛子さま 学習院大に初の登校
# 15 メタボ健診補助金 過大に交付
# 15 ビル転落 巻き添えの女性死亡
# 15 dyson偽サイト なぜ商品送付
# 15 年末年始の休暇延長 街の声は
# 15 目チカチカ 網膜剥離の前兆は
# 15 東京の感染 1週間ぶり200人超
# 15 コロナ後遺症 脱毛症状も報告
# 15 DeNAロペス 日米通算2000安打
# 15 相葉の動物番組 なぜ全てロケ
# 15 大下アナ 寝耳に水だった辞令
# 15 首相 滋さんに「心動かした」
# 15 オオスズメバチ巣 米で初発見
# 15 サンマ水揚げ回復 やや手頃に
# 16 元地方アナ 中洲でおかみ修業
# 16 無敗3冠へ コントレイル万全
# 16 池江 五輪会場を泳ぎ「絶賛」
# 16 米 1日で過去最多8.4万人感染
# 16 「都民割」開始 観光客が続々
# 16 お笑いは必要?河本準一の葛藤
# 16 工場で火災 旭化成側が陳謝
# 16 年始の休暇延長 企業は従うか
# 16 業務スーパー 新規出店続く訳
# 16 覚醒剤事件捜索中に逃走 逮捕
# 16 米英2社 ワクチン治験再開へ
# 16 SB 携帯乗り換え手数料撤廃へ
# 16 五輪チケット 11月払い戻しへ
# 16 かに道楽 看板のカニ元気に
# 16 近畿地方、木枯らし1号吹く
# 16 ガンプラブーム 40年前の熱狂
# 16 若者の性被害 国が初調査へ
# 16 飲酒運転と知り同乗 4人立件
# 16 かに道楽のカニ 脚が「復活」
# 16 フィギュア元全米女王 GP復帰
# 16 海王星 上空に猛毒青酸ガス
# 16 大阪都構想 なぜ「黒字」試算
# 16 トランプ氏 自滅回避の討論
# 16 岡村結婚 アローン会絶滅危機
# 16 北朝鮮国境に異変 コロナ厳戒
# 17 大阪都構想 いちから争点解説
# 17 労組支持へ バイデン氏追い風
# 17 免許合宿 11月以降GoTo対象外
# 17 核禁止条約 批准へ残り1カ国
# 17 WHO 北半球は重大な岐路に
# 17 ススキノ 感染対策「二極化」
# 17 DeNA 三浦大輔氏が新監督濃厚
# 17 Eテレ曲提供 片岡知子氏死去
# 17 DeNA一筋 石川雄洋が退団へ
# 17 討論でバイデン氏勝利53% CNN
# 17 監督激怒 マルテ4失策新記録
# 17 役所に市長の私物サウナ 猛省
# 17 教員わいせつ事件 中1後遺症
# 17 女性誌JJ 月刊やめ不定期へ
# 17 研究員殺害 うそがばれ口論に
# 17 女性暴行死 警察に複数回相談
# 17 RAMPAGE鈴木昂秀 半同棲報道
# 17 携帯乗り換え無料 年明けにも
# 17 男性ビル転落 直撃の女性重体
# 17 自民県議団で視察クラスター
# 17 男性がビル転落 女性を直撃か
# 17 マルテ 1イニング3失策の珍事
# 17 記事を無断共有 環境省が謝罪
# 17 鬼滅 知識ゼロの人の疑問点
# 17 星野源 おげんさん第4弾決定
# 18 コロナ困窮 SNSでの融資横行
# 18 教授らが見解 任命拒否は違法
# 18 家に重機「ドーン」後に停電
# 18 日立、日立建機を売却へ
# 18 時事配信コラム 他媒体と酷似
# 18 東和銀とSBI 資本提携で合意
# 18 関空の旅客数95%減 過去最低
# 18 19年参院選比例は合憲 最高裁
# 18 都民の都内旅行助成 予約開始
# 18 川崎希 第2子女児を出産
# 18 沖縄県議団 計10人集団感染か
# 18 イート予約 16日間で1092万人
# 18 重量挙げ 6カ国18選手不正か
# 18 首里城の大龍柱 補修始まる
# 18 都186人感染 4日連続100人超
# 18 岩隈引退 シート打撃で脱臼
# 18 海洋放出方針 10月の決定断念
# 18 5人に1人医療福祉就業 2040年
# 18 日英EPA協定に署名 1月発効へ
# 18 NiziUミイヒ 体調不良で休養
# 18 岡村結婚 aikoは幸運の女神?
# 18 iPhone発売 今年はあっさり
# 18 竹島は日本領 米航空図に明記
# 18 学術会議の在り方 年内報告へ
# 18 眞子さま29歳 結婚への道筋は
# 19 国民 立憲との衆院会派離脱へ
# 19 配達員追突 女性がUberを提訴
# 19 住宅に重機倒れる 1人搬送
# 19 高速道で妨害 厳罰化後初逮捕
# 19 不明妻の名義で車購入 夫逮捕
# 19 米討論会 今回は落ち着き論戦
# 19 ダル 選手間投票の受賞ならず
# 19 日本人宇宙飛行士を募集へ
# 19 岡村 妻はスノボ仲間の情報も
# 19 韓国 インフル接種後死者32人
# 19 小室氏 不倫疑惑向き合う日々
# 19 米大統領選討論 対北巡り応酬
# 19 鬼滅の映画「定番化」するか
# 19 年始11日まで休み延長 提言へ
# 19 千葉の30代女性不明 夫を聴取
# 19 唐揚げ店急増 コロナ追い風?
# 19 小室哲哉氏 筒美さんは金字塔
# 19 iPhone12発売 5G契約は必須?
# 19 国 新幹線フル規格支持表明へ
# 19 金融庁 東証に立ち入り検査
# 19 サイドで156km ドラフト逸材
# 19 独に宇宙センター設置へ NATO
# 19 国会図書館 議員喫煙室廃止へ
# 19 岡村結婚 2018年秋の「異変」
# 19 重症化率 6-8月大幅に下がる
# 20 知事公用車 ミニバンが増加?
# 20 全日空 ピーチと共同運航案
# 20 露「ナゴルノ死者5千人迫る」
# 20 北日本など 強まる風雨に警戒
# 20 バイデン氏の疑惑 報道割れる
# 20 石破氏辞任 主流派転換を模索
# 20 東証1部8割 公的マネー大株主
# 20 コロナ 米でレムデシビル承認
# 20 久保が移籍後初ゴール EL初戦
# 20 岡村 妻は「厳しくて優しい」
# 20 阪神・ボーア 1年で退団へ
# 20 岡村隆史 支えられ婚です
# 20 喫煙所設置論が再浮上 道議会
# 20 巨人小林 右手人さし指骨折か
# 20 岡村結婚 矢部「良かった」
# 20 岡村隆史、結婚していた
# 20 秋篠宮家の眞子さま 29歳に

# %%
print(len(title_list))
print(len(category_list))
print(len(text_list))
# Out:
# 496
# 496
# 496

# %%
df = pd.DataFrame({'title': title_list, 'category': category_list, 'text': text_list})

# %%
df.head()
# Out:
#               title category  \
# 0      内村航平が新型コロナ陽性     スポーツ
# 1    くそたれ地震 不満のみ込む今       地域
# 2  GoToイート紙切れ 担当者憤り       地域
# 3    週末 東日本で冷え込み強まる       国内
# 4  SB周東が12戦連続盗塁 プロ新     スポーツ
#
#                                                 text
# 0   国際体操連盟FIGの渡辺守成会長らが29日オンラインで緊急会見を開き体操男子の種目別鉄棒で...
# 1   死者44人建物被害が5万棟に上った北海道胆振東部地震から2年がたった被害の大半を占める厚真...
# 2   新型コロナウイルスの影響で打撃を受けた飲食業界の支援策Go To イート事業のプレミアム付...
# 3  明日30日金は上空の寒気が日本列島の上空に南下してきます明日夜からは特に関東や東海など東日本...
# 4   ソフトバンクロッテ29日ペイペイドーム ソフトバンク周東が12試合連続盗塁のプロ野球新記録...

# %%
ls /work/data/BunshuOnline/
# Out:
# news.csv

# %%
df.to_csv('/work/data/BunshuOnline/yahoo_news.csv')
