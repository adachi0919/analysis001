# %%
import requests
from bs4 import BeautifulSoup
import re
import itertools
import pandas as pd, numpy as np
import janome
import jaconv
import string
import MeCab
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
import unicodedata
from gensim import corpora
from gensim import models
from pprint import pprint
import math

# %%
# MeCabの辞書にNEologdを指定。
# mecabは携帯素解析用、wakatiは分かち書き用
mecab = MeCab.Tagger('-d /usr/lib/x86_64-linux-gnu/mecab/dic/mecab-ipadic-neologd/')
wakati = MeCab.Tagger("-Owakati -d /usr/lib/x86_64-linux-gnu/mecab/dic/mecab-ipadic-neologd/")

# %%
# 形態素解析を行う関数を定義
# ファイルを入力するとファイルを出力し、文字列を渡すと文字列を返します。引数fileで変更します。  
# 単に分かち書きしたいだけの場合は引数にmecab=wakatiとすると実現できます。
def MecabMorphologicalAnalysis(path='./text.txt', output_file='wakati.txt', mecab=mecab, file=False):
    mecab_text = ''
    if file:
        with open(path) as f:
            for line in f:
                mecab_text += mecab.parse(line)
        with open(output_file, 'w') as f:
            print(mecab_text, file=f)
    else:
        for path in path.split('\n'):
            mecab_text += mecab.parse(path)
        return mecab_text

    
# 記号文字は分析をするにあたって邪魔になるため、記号を取り除く関数を定義します。
# 下のYahooNews関数で使用します。
def symbol_removal(soup):
    soup = unicodedata.normalize("NFKC", soup)
    exclusion = "「」『』【】《》≪≫、。・◇◆" + "\n" + "\r" + "\u3000"
    soup = soup.translate(str.maketrans("", "", string.punctuation  + exclusion))
    return soup


# Yahooニュースをスクレイピングする関数です。
# 引数で指定した数の記事をとってきてデータフレームを返します。
def YahooNews(n=30):
    url = "https://news.yahoo.co.jp/topics/top-picks"
    URL = "https://news.yahoo.co.jp/"
    res = requests.get(url)
    soup = BeautifulSoup(res.text, "html.parser")
    all_page_links = []
    all_page_links.append(url)
    all_links = []
    while True:
        try:
            next = soup.find("li", class_="pagination_item-next").find("a")["href"]
            next_link = URL + next
            all_page_links.append(next_link)
            next_res = requests.get(next_link)
            soup = BeautifulSoup(next_res.text, "html.parser")
        except:
            break
            
    title_list = []
    category_list = []
    text_list = []
    for url in all_page_links: # all_page_links: 全てのニュースのリスト
            res = requests.get(url) # url: 25個分のニュースのリスト
            soup = BeautifulSoup(res.text, "html.parser")
            page_soup = soup.find_all("a", class_="newsFeed_item_link")
            for href in page_soup:
                link = href["href"] # link: 一つのニュースのリンク(本文は一部のみ)
                all_links.append(link)
    
    if len(all_links) <= n:
        n = len(all_links)
    
    i = 0
    for link in all_links:
        link_res = requests.get(link)
        href_soup = BeautifulSoup(link_res.text, "html.parser")
        try:
            title = href_soup.find("h1", class_=re.compile("^sc")).string
        except:
            continue
        title_link = href_soup.find("a", class_="sc-eAyhxF")["href"] # title_link: 本文
        res = requests.get(title_link)
        soup = BeautifulSoup(res.text, "html.parser")

        category = soup.find_all("li", class_="current")
        try:
            category = category[1].string
        except:
            continue
        else:
            for tag in soup.find_all(["a"]):
                tag.decompose()
            try:
                soup = soup.find("div", class_="article_body").get_text()
                soup = symbol_removal(soup)
                
                text_list.append(soup)
                title_list.append(title)
                category_list.append(category)
                i += 1 # 本文が正常に保存できたことをトリガーにしてカウントを一つ増やすことにします。
                pro_bar = ('=' * math.ceil(i / (n / 20))) + (' ' * int((n / (n / 20)) - math.ceil(i / (n / 20))))
                print('\r[{0}] {1}記事'.format(pro_bar, i), end='')
                if i >= n:
                    df = pd.DataFrame({'title': title_list, 'category': category_list, 'text': text_list})
                    return df
            except:
                continue
    df = pd.DataFrame({'title': title_list, 'category': category_list, 'text': text_list})
    return df

# %%
def sortedTFIDF(sentences):
    
    # 単語にIDを添付します。
    dictionary = corpora.Dictionary(sentences)
    
    # 作品ごとの単語の出現回数をカウント
    corpus = list(map(dictionary.doc2bow, sentences))
    
    # 単語ごとにTF-IDFを算出
    test_model = models.TfidfModel(corpus)
    corpus_tfidf = test_model[corpus]
    
    # ID:TF-IDF → TF-IDF:単語 に変換。TF-IDFを左に持ってくることで、sortedを用いてTF-IDFを基準にソートすることができます。
    texts_tfidf = []
    for doc in corpus_tfidf:
        text_tfidf = []
        for word in doc:
            text_tfidf.append([word[1], dictionary[word[0]]])
        texts_tfidf.append(text_tfidf)
    
    # TF-IDFを基準にソートを行います。
    sorted_texts_tfidf = []
    for text in texts_tfidf:
        sorted_text = sorted(text, reverse=True)
        sorted_texts_tfidf.append(sorted_text)

    return sorted_texts_tfidf

# %%
def YahooNews(n=30):
    url = "https://news.yahoo.co.jp/topics/top-picks"
    URL = "https://news.yahoo.co.jp/"
    res = requests.get(url)
    soup = BeautifulSoup(res.text, "html.parser")
    all_page_links = []
    all_page_links.append(url)
    all_links = []
    while True:
        try:
            next = soup.find("li", class_="pagination_item-next").find("a")["href"]
            next_link = URL + next
            all_page_links.append(next_link)
            next_res = requests.get(next_link)
            soup = BeautifulSoup(next_res.text, "html.parser")
        except:
            break
            
    title_list = []
    category_list = []
    text_list = []
    for url in all_page_links: # all_page_links: 全てのニュースのリスト
            res = requests.get(url) # url: 25個分のニュースのリスト
            soup = BeautifulSoup(res.text, "html.parser")
            page_soup = soup.find_all("a", class_="newsFeed_item_link")
            for href in page_soup:
                link = href["href"] # link: 一つのニュースのリンク(本文は一部のみ)
                all_links.append(link)
    
    if len(all_links) <= n:
        n = len(all_links)
    
    i = 0
    for link in all_links:
        link_res = requests.get(link)
        href_soup = BeautifulSoup(link_res.text, "html.parser")
        try:
            title = href_soup.find("h1", class_=re.compile("^sc")).string
        except:
            continue
        title_link = href_soup.find("a", class_="sc-eAyhxF")["href"] # title_link: 本文
        res = requests.get(title_link)
        soup = BeautifulSoup(res.text, "html.parser")

        category = soup.find_all("li", class_="current")
        try:
            category = category[1].string
        except:
            continue
        else:
            for tag in soup.find_all(["a"]):
                tag.decompose()
            try:
                soup = soup.find("div", class_="article_body").get_text()
                soup = symbol_removal(soup)
                
                text_list.append(soup)
                title_list.append(title)
                category_list.append(category)
                i += 1 # 本文が正常に保存できたことをトリガーにしてカウントを一つ増やすことにします。
                pro_bar = ('=' * math.ceil(i / (n / 20))) + (' ' * int((n / (n / 20)) - math.ceil(i / (n / 20))))
                print('\r[{0}] {1}記事'.format(pro_bar, i), end='')
                if i >= n:
                    df = pd.DataFrame({'title': title_list, 'category': category_list, 'text': text_list})
                    return df
            except:
                continue
    df = pd.DataFrame({'title': title_list, 'category': category_list, 'text': text_list})
    return df

# %%
df = YahooNews(1000)
# Out:
# [====================] 470記事

# %%
df.shape
# Out:
# (470, 3)

# %%
df.head()
# Out:
#             title category                                               text
# 0  第3波か 愛知県知事が危機感       地域  中京テレビNEWS 愛知県で新型コロナウイルスの感染者が再び急増していることを受け2日大村秀...
# 1  紀平梨花 トヨタ自動車に入社     スポーツ   フィギュアスケート女子の紀平梨花が11月1日付けでトヨタ自動車に入社したことが2日分かった...
# 2  否決で今後の大阪は 市民の声       地域  関西テレビ大阪市を廃止し4つの特別区に再編するいわゆる大阪都構想の住民投票は反対多数で否決さ...
# 3  ウィリアム王子4月に陽性判定       国際  イギリス王室のケンブリッジ公爵ウィリアム王子38が今年4月に新型コロナウイルスに感染していた...
# 4  鬼滅の刃 歴代興収が10位に     エンタメ   10月16日に公開されたアニメ映画劇場版鬼滅の刃無限列車編の最新の興行収入が2日発表された...

# %%
texts = []
for i in range(len(df)):
    texts.append(MecabMorphologicalAnalysis(df['text'][i], mecab=wakati))

# %%
# 分かち書きができたか確認します。5作品を表示。
for i, text in enumerate(texts):
    if i < 5:
        display(text[:100])
# Out:
# '中京テレビ NEWS 愛知県 で 新型コロナウイルス の 感染者 が 再び 急増 し て いる こと を 受け 2日 大村秀章 知事 は 明らか に ステージ は 変わっ た の で は と 受け止め'
# 'フィギュアスケート 女子 の 紀平梨花 が 11月1日 付け で トヨタ自動車 に 入社 し た こと が 2日 分かっ た 同社 が 発表 し た 紀平 は 今シーズン から トヨタ自動車 に お世'
# '関西テレビ 大阪市 を 廃止 し 4つ の 特別区 に 再編 する いわゆる 大阪都構想 の 住民投票 は 反対 多数 で 否決 さ れ まし た 一夜 明け 市民 から は 今後 の 大阪 について'
# 'イギリス王室 の ケンブリッジ公爵 ウィリアム王子 38 が 今年4月 に 新型コロナウイルス に 感染 し て い た こと が 明らか に なっ た 王室 筋 が BBC に 語っ た 英 王室 '
# '10月16日 に 公開 さ れ た アニメ映画 劇場版 鬼滅の刃 無限 列車 編 の 最新 の 興行収入 が 2日 発表 さ れ た 初日 から 17日間 1日 まで の 興行収入 が 興行収入 15'

# %%
# リストに変換
sentences = []
for text in texts:
    text_list = text.split(' ')
    sentences.append(text_list)

# %%
# まずdocumentsを作り、モデルに渡す。
documents1 = [TaggedDocument(doc, [i]) for i, doc in enumerate(sentences)]
model1 = Doc2Vec(documents1, vector_size=100, window=7, min_count=1)

# %%
# モデルに渡したdocumentsの中身は番号と本文が対応したリストです。ここでは参考のため、作者も表示しています。
for i, doc in enumerate(documents1):
    print(doc[1], df['title'][i], df['category'][i], doc[0][:8])
# Out:
# [0] 第3波か 愛知県知事が危機感 地域 ['中京テレビ', 'NEWS', '愛知県', 'で', '新型コロナウイルス', 'の', '感染者', 'が']
# [1] 紀平梨花 トヨタ自動車に入社 スポーツ ['フィギュアスケート', '女子', 'の', '紀平梨花', 'が', '11月1日', '付け', 'で']
# [2] 否決で今後の大阪は 市民の声 地域 ['関西テレビ', '大阪市', 'を', '廃止', 'し', '4つ', 'の', '特別区']
# [3] ウィリアム王子4月に陽性判定 国際 ['イギリス王室', 'の', 'ケンブリッジ公爵', 'ウィリアム王子', '38', 'が', '今年4月', 'に']
# [4] 鬼滅の刃 歴代興収が10位に エンタメ ['10月16日', 'に', '公開', 'さ', 'れ', 'た', 'アニメ映画', '劇場版']
# [5] ニッチェ近藤が結婚を報告 エンタメ ['お笑いコンビ', 'ニッチェ', 'の', '近藤くみこ', '37', 'が', '2日', '所属事務所']
# [6] 首相 学術会議は既得権益化 国内 ['衆院', '予算委員会', 'は', '2日', '午前', '菅義偉', '首相', 'と']
# [7] 紅白司会 紅組は二階堂ふみ エンタメ ['NHK', 'は', '2日', '今年', 'の', '大晦日', 'に', '放送']
# [8] 松井秀喜氏が愛した店閉店 スポーツ ['お世話', 'に', 'なっ', 'て', 'ばかり', 'で', '寂しい', 'です']
# [9] ハンド宮崎大輔容疑者を逮捕 国内 ['FNN', 'プライムオンラインハンドボール', '元日本代表', 'の', '宮崎大輔', '選手', 'が', '2日']
# [10] 困った 線路に小さな落とし物 国内 ['ワイヤレス', 'イヤホン', 'が', '線路', 'に', '落ち', 'た', 'ケース']
# [11] 尚弥の超速パンチ 実は新兵器 スポーツ ['試合前', 'スパー', 'で', '見せ', 'た', '進化', '衝撃', 'の']
# [12] やっぱり青学が本命?箱根駅伝 スポーツ ['前回大会', 'の', 'トップ3', 'で', 'ある', '東海大', '青学大', '駒大']
# [13] WHO事務局長が自主隔離 国際 ['AFP', '時事', '更新', '世界保健機関', 'WHO', 'の', 'テドロスアダノムゲブレイェスス', 'Tedros']
# [14] 西武 内海哲也と契約更新へ スポーツ ['西武', 'が', '内海哲也', '投手', '38', 'と', '来季契約', '更新']
# [15] 尖閣周辺に中国船 年最多更新 国内 ['沖縄県', '尖閣諸島', '周辺', 'の', '領', '海外', '側', 'に']
# [16] 千葉市長 知事選出馬を表明 地域 ['来春', 'の', '知事選', 'で', '千葉市', 'の', '熊谷俊人', '市長']
# [17] 高橋留美子さんに紫綬褒章 エンタメ ['政府', 'は', '2020年', '秋', 'の', '褒章', '受章', '者']
# [18] 札幌2歳衰弱死 母は無罪主張 地域 ['去年6月', '札幌', 'で', '当時', '2歳', 'の', '池田', '詩']
# [19] ハロウィンに偽パトカー疾走? 国内 ['ハロウィーン', 'の', '10月31日', '夜', '札幌市内', 'で', 'パトカー', 'に']
# [20] 都構想関連に公金100億円超 国内 ['地域政党', '大阪維新の会', 'は', '2010年', 'に', '結党', 'し', 'て']
# [21] 2700ツネ キッチンカーで働く エンタメ ['昨年6月', '大', '騒動', 'に', 'なっ', 'た', '吉本芸人', 'による']
# [22] 本田望結 サッカー応援マネに エンタメ ['女優', 'で', 'フィギュアスケート', '選手', 'の', '本田望結', 'みゆ', '16']
# [23] コネリーさん 認知症だった エンタメ ['AFP', '時事', '先日', '90歳', 'で', '死去', 'し', 'た']
# [24] レナウン 再建断念し破産へ 経済 ['名門', 'レナウン', '月内', 'に', '破産', 'へ', '移行', '5月15日']
# [25] 米大統領選 期日前が過去最高 国際 ['デトロイト', 'ミシガン州', 'レディング', 'ペンシル', 'べ', 'ニア', '州', '31日']
# [26] 中韓などから入国 検査不要に 国内 ['新型コロナウイルス', 'の', '水際対策', 'が', '1日', '緩和', 'さ', 'れ']
# [27] 首相 都構想は「一石投じた」 国内 ['菅義偉', '首相', 'は', '2日', '大阪都構想', 'に関する', '住民投票', '否決']
# [28] 居酒屋大手5社 全体の1割閉店 経済 ['居酒屋チェーン', 'で', '店舗', '閉鎖', 'が', '広がっ', 'て', 'いる']
# [29] マー君 全球団との交渉可能に スポーツ ['ヤンキース', 'から', 'FA', 'フリーエージェント', 'と', 'なっ', 'た', '田中将大']
# [30] 遠隔は悪?大学名公表で波紋 ライフ ['後期', 'の', '対面', '授業', 'が', '5割', '未満', 'の']
# [31] 都幹部「首都2つに見える」 国内 ['東京都', 'の', '関係者', 'は', '都', 'が', '二つ', 'できる']
# [32] 否決で打撃 維新立て直し急務 国内 ['大阪都構想', 'という', '看板', '政策', 'の', '再', '否決', 'と']
# [33] 秋の褒章 尾畠春夫さんに緑綬 国内 ['赤い', 'ねじり', 'はちまき', 'に', 'オレンジ', 'の', 'シャツ', '姿']
# [34] 公園の乳児遺体 母親を逮捕 国内 ['東京', '新橋', 'の', '公園', 'で', '2019年', '生後', '間']
# [35] ヤクルト井野卓 現役引退へ スポーツ ['ヤクルト', '井野卓', '捕手', '36', 'が', '今季限り', 'で', '現役']
# [36] ヤクルトがSB内川の獲得調査 スポーツ ['ヤクルト', 'が', '今季限り', 'で', 'ソフトバンク', 'を', '退団', 'する']
# [37] 紅白 白組司会は大泉洋で調整 エンタメ ['大みそか', 'の', '第', '71回', '紅白歌合戦', 'で', 'NHK', 'が']
# [38] トルコ地震 迫る「72時間」 国際 ['エルサレム', '時事', 'トルコ', 'と', 'ギリシャ', 'の', '沖合', 'の']
# [39] 大阪都構想を阻止 自民は安堵 国内 ['地域政党', '大阪維新の会', 'が', '推進', 'し', 'て', 'き', 'た']
# [40] 西武・松坂 来季も現役続行へ スポーツ ['西武', 'が', '松坂大輔', '投手', '40', 'と', '来季', 'も']
# [41] ATSUSHI EXILE卒業しソロ専念 エンタメ ['EXILE', 'ATSUSHI', '40', 'が', '11月2日', 'を', 'もっ', 'て']
# [42] 板で窓覆う 米大統領選を警戒 国際 ['3日', '投開票', 'の', '米大統領選', 'で', '選挙結果', 'をめぐって', '共和党候補']
# [43] 知事 僕は都構想再挑戦ない 国内 ['1日', '投開票', 'さ', 'れ', 'た', '住民投票', 'で', '大阪都構想']
# [44] 接戦の都構想 悩んだ有権者 国内 ['大阪都構想', 'の', '賛否', 'を', '問う', '住民投票', 'は', '1日']
# [45] 天心42連勝 惜別の跳び膝蹴り スポーツ ['RISE', '1日', 'エディオンアリーナ大阪', 'キックボクシング', '界', 'の', '神童', '那須川天心']
# [46] 大阪市長 任期満了で政界引退 地域 ['速報', '大阪都構想', '反対', '多数', 'の', '結果', 'を', '受けて']
# [47] 否決 大阪市長「私の力不足」 国内 ['政令指定都市', 'の', '大阪市', 'を', '廃止', 'し', 'て', '4つ']
# [48] 元withB アメフト会心プレー スポーツ ['社会人', 'アメリカンフットボール', 'の', 'X1', 'エリア', '西日本', 'トーナメント', 'の']
# [49] 反対多数 大阪市は存続へ 国内 ['大阪市', 'を', '廃止', 'し', 'て', '四つ', 'の', '特別区']
# [50] ハナコ岡部 絶妙なかわいさ エンタメ ['コント師', 'ハナコ', '秋山寛貴', '岡部大', '菊田竜大', 'の', '3人', 'から']
# [51] 大阪投票率62.35% 前回下回る 国内 ['2度目', 'に', 'なっ', 'た', '住民投票', 'の', '投票率', 'は']
# [52] 8冠 騎手ルメールも目真っ赤 スポーツ ['第', '162回', '天皇賞秋', 'G11', '日', '東京', '芝', '2000メートル']
# [53] 大阪都構想 賛否は拮抗 国内 ['大阪市民', 'を', '対象', 'に', '大阪都構想', 'の', '是非', 'を']
# [54] 都構想 18時投票率37.60% 国内 ['大阪市民', 'を', '対象', 'に', '大阪都構想', 'の', '是非', 'を']
# [55] ネコの絵も 謎は深まるナスカ 国際 ['考古学', 'の', '大きな', '謎', 'に', '新', '技術', 'で']
# [56] 台風横断 フィリピン各地洪水 国際 ['FNN', 'プライム', 'オンライン', '非常', 'に', '強い', '台風19号', 'が']
# [57] 西武平尾コーチ解雇 私物窃取 スポーツ ['西武', 'は', '1日', '平尾', '博司', '2軍', '打撃', 'コーチ']
# [58] 安倍氏 父墓前に首相辞任報告 国内 ['安倍晋三', '前', '首相', 'は', '1日', '持病', 'の', '潰瘍性大腸炎']
# [59] 大下容子アナ 30歳定年説語る エンタメ ['情報番組', 'や', 'バラエティー', 'や', '番組', 'など', 'で', '幅広く']
# [60] 米大統領選 かたずのむイラン 国際 ['テヘラン', '共同', '米国', 'と', '敵対', 'する', 'イラン', 'で']
# [61] VTuber人気けん引 upd8終了へ エンタメ ['Activ', '8', '株式会社', 'が', '展開', 'する', 'バーチャルYouTuber', 'の']
# [62] 憲剛引退 冷静で「口達者」 スポーツ ['サッカー', 'の', 'J1', '川崎F', 'の', '元日本代表', 'MF', '中村憲剛']
# [63] SB内川 涙こらえファンに別れ スポーツ ['ウエスタンリーグ', 'ソフトバンク', '51', '阪神', '1日', 'タマスタ', '筑後', '今季限り']
# [64] 軒並み赤字 外食チェーン岐路 経済 ['居酒屋', 'など', '外食チェーン', '大手', 'の', 'ワタミ', 'は', '10月5日']
# [65] 都構想 130年の歴史変わるか 国内 ['大阪市', 'を', '廃止', 'し', 'て', '四つ', 'の', '特別区']
# [66] アーモンドアイ GI初の8冠馬 スポーツ ['11月1日', 'の', '東京', '11', 'R', 'で', '行わ', 'れ']
# [67] 都新たに116人 感染数横ばい 国内 ['東京都', 'は', '1日', '新型コロナウイルス', 'の', '感染者', 'が', '新た']
# [68] 毒ガスのよう 香害に苦しむ声 国内 ['小学生', 'の', '子ども', 'の', '友だち', 'を', '家', 'に']
# [69] 板東英二 今は仕事セーブ中 エンタメ ['ラジオ番組', 'も', 'すべて', '終了', '姿', 'も', '見', 'なく']
# [70] MF中村憲剛 今季限りで引退 スポーツ ['J1', '川崎', 'の', '元日本代表', 'MF', '中村憲剛', '40', 'が']
# [71] 福岡のハロウィン 2人を逮捕 地域 ['テレビ西日本', 'ハロウィーン', 'の', '10月31日', '夜', '福岡市天神', 'の', '公園']
# [72] 北陸新幹線 延伸遅れで懸念も 地域 ['北陸新幹線', '金沢', '―', '敦賀', '間', 'の', '2023年', '春']
# [73] トルコ 救出は時間との闘い 国際 ['AFP', '時事', 'トルコ', 'ギリシャ', '沖の', 'エーゲ海', 'Aegean', 'Sea']
# [74] 元ジャニ7人組 来年デビュー エンタメ ['タレント', 'の', '安井謙太郎', '真田佑馬', '諸星翔希', '森田美勇人', '萩谷慧悟', '阿部顕嵐']
# [75] 駅伝 駒大が「3強」激戦制す スポーツ ['学生', '3', '大', '駅伝', '開幕戦', '全日本大学駅伝', '1日', '名古屋市']
# [76] 尚弥KO勝ち 試合中に戦略変更 スポーツ ['ボクシング', 'WBA', 'IBF', '世界', 'バンタム級', 'タイトルマッチ', '31日', 'ラスベガス']
# [77] はんこ店 鬼滅キャラ名あるよ ライフ ['竈門', 'かまど', '我妻', 'あ', 'が', 'つま', '不死川', 'しな']
# [78] 山口組総本部 菓子配らず 国内 ['暴力団員', 'の', '青少年', 'へ', 'の', '菓子', '提供', 'など']
# [79] 都構想 正午時点の投票率16% 国内 ['大阪市民', 'を', '対象', 'に', '大阪都構想', 'の', '是非', 'を']
# [80] イージス代替艦 大型化を検討 国内 ['政府', 'は', '地上', '配備', '型', '迎撃', 'システム', 'イージスアショア']
# [81] 仏で教会司祭撃たれ重傷 逮捕 国際 ['AFP', '時事', '仏', 'リヨン', 'Lyon', 'で', '10月31日', '銃身']
# [82] ものすごい量 服在庫処分の今 経済 ['新型コロナウイルス', 'の', '感染拡大', 'で', 'アパレル', '業界', 'が', '苦境']
# [83] 豚解体 ベトナム人を再逮捕 国内 ['埼玉県警', 'は', '1日', '自宅', 'で', '食用', 'に', '豚']
# [84] 尚弥 ラスベガスで7回KO勝ち スポーツ ['プロボクシング', 'WBA', 'IBF', '世界', 'バンタム級', 'タイトルマッチ', '31日', '日本時間']
# [85] 火災で救助中 消防署員が死亡 国内 ['盛岡市', 'の', 'マンション', 'で', '10月31日', '夜', 'に', '起き']
# [86] 1万人超に抗体検査へ 厚労省 ライフ ['厚生労働省', 'は', '一般住民', 'を', '対象', 'に', '新型コロナウイルス', 'の']
# [87] 「誰も頼れず」産後うつ倍増 国内 ['コロナ禍', 'で', '女性', 'の', '産後うつ', 'の', 'リスク', 'が']
# [88] トルコ なお多数閉じ込めか 国際 ['エルサレム', 'パリ', '時事', 'トルコ', 'と', 'ギリシャ', 'の', '沖合']
# [89] あと3日 米大統領選追い込み 国際 ['Nippon', 'News', 'Network', 'NNN', 'アメリカ大統領選挙', 'まで', 'あと', '3日']
# [90] 元祖JJガール「本当に休刊?」 エンタメ ['光文社', 'は', '女性ファッション誌', 'JJ', 'を', '2021年', '2月', '号']
# [91] 都構想 議論かみ合わぬまま 国内 ['大阪市', 'を', 'なくし', 'て', '四つ', 'の', '特別区', 'に']
# [92] ジャポニカ表紙 写真家探検記 国内 ['小学生', 'の', 'ころ', '誰', 'も', 'が', '手', 'に']
# [93] 北海道 4日は平地でも雪か 国内 ['2日', '月', 'は', '寒冷前線', 'の', '通過', 'で', '広く']
# [94] 吉見引退へ 中日の黄金期支え スポーツ ['中日', '吉見一起', '投手', '36', 'が', '今季限り', 'で', '現役']
# [95] 「大江戸線延伸を」どんな街? 経済 ['ミニ', '地下鉄', '幅', '5km', 'の', '鉄道空白地帯', 'を', '埋める']
# [96] 危険な状況 北海道で感染急増 地域 ['10月', 'GoTo', 'や', '札幌', '往来', '増', '道内', 'の']
# [97] 現金化商法に注意 手口巧妙化 国内 ['金融庁', 'が', '3月', '給与', 'を', '受け取る', '権利', 'を']
# [98] 秋元氏「金で転ぶ」買収指示か 国内 ['金', 'を', 'ぶつけ', 'て', 'ほしい', 'と', 'の', '指示']
# [99] 迷える渋野日向子 解けぬ呪縛 スポーツ ['女子', 'ゴルフツアー', '樋口久子', '三菱電機', 'レディース', '第', '2日', '2020年']
# [100] 大阪都構想 住民投票始まる 国内 ['大阪市', 'を', '廃止', 'し', '4つ', 'の', '特別区', 'に']
# [101] 花澤香菜 棒読みだった過去 エンタメ ['昨年', '字幕版', 'が', '上映', 'と', 'なり', 'SNS', 'で']
# [102] 感染拡大 英で再び外出自粛へ 国際 ['ロンドン', '広瀬誠', '英国', 'の', 'ジョンソン首相', 'は', '10月31日', '新型コロナウイルス']
# [103] 早見あかり第1子出産していた エンタメ ['女性', 'アイドルグループ', 'ももいろクローバー', '現', 'ももいろクローバーZ', 'の', '元メンバー', 'で']
# [104] 修学旅行生 GoToで大人買い 国内 ['10月', 'から', '配布', 'が', '始まっ', 'た', 'Go', 'To']
# [105] コネリーさん死去 悲しい損失 国際 ['映画', 'で', '初めて', '007', 'こと', 'ジェイムズボンド', '役', 'を']
# [106] トランプ氏 接戦州で差縮める 国際 ['ワシントン', '横堀裕也', '米大統領選', 'は', '10月30日', '11月3日', 'の', '投開票']
# [107] 上野動物園 初めてのゾウ誕生 国内 ['東京都台東区', 'の', '上野動物園', 'は', '31日', '飼育', 'する', 'アジアゾウ']
# [108] 都構想 焦点は住民サービス 国内 ['大阪', 'の', '将来', 'を', '占う', '一', '票', 'を']
# [109] 行政事業レビュー 誤記2600件 国内 ['政府', '予算', 'の', '執行', '状況', 'を', '記載', 'する']
# [110] ショーン・コネリーさん死去 国内 ['英', 'BBC', '放送', 'は', '10月31日', '人気', 'スパイ映画', '007']
# [111] 柔道「不可解裁定」で大混乱 スポーツ ['柔道', '講道館杯', '31日', '千葉ポートアリーナ', '日本一', 'を', '争う', '大会']
# [112] 鬼滅 観客動員数1000万人突破 エンタメ ['アニメ映画', '劇場版', '鬼滅の刃', '無限', '列車', '編', '公開', '御礼']
# [113] 渋谷の街 仮装の人出は8割減? 国内 ['新型コロナウイルス', '禍', 'の', '中', 'ハロウィーン', '当日', 'と', 'なっ']
# [114] 歯ぎしり 放置して大丈夫? 科学 ['教え', 'て', 'ヨミ', 'ドック', 'トラさん', 'が', '浮か', 'ない']
# [115] 「偽陽性」で混乱 五輪へ課題 スポーツ ['国際体操連盟', 'FIG', 'は', '31日', '29日', 'に', '新型コロナウイルス', '感染']
# [116] 答弁パターン化 首相の真価は 国内 ['菅義偉', '首相', 'が', '就任後', '初めて', '臨ん', 'だ', '衆参']
# [117] 中国・千人計画 参加者の本音 国際 ['働ける', 'なら', '日本', 'で', '中国政府', 'が', '推進', 'する']
# [118] 都構想 期日前投票は前回超え 地域 ['関西テレビ', '11月1日', 'いわゆる', '大阪都構想', 'の', '投開票', 'が', '行わ']
# [119] 頭に謎の物体 古代文明と市民 国際 ['徐々', 'に', '明かさ', 'れる', '一般市民', 'の', '暮らし', '古代エジプト']
# [120] 渋谷ハロウィン 仮装まばら 国内 ['恒例行事', 'として', '定着', 'し', 'た', 'ハロウィーン', 'が', '31日']
# [121] 珍事 日差しキツくて野球中断 スポーツ ['6回', 'の', 'ロッテ', 'の', '攻撃', '中', 'に', '試合']
# [122] 英 再び全土ロックダウンか 国際 ['AFP', '時事', '英紙', 'タイムズ', 'Times', 'は', '30日', '新型コロナウイルス']
# [123] 内村航平「偽陽性」だった スポーツ ['国際体操連盟', 'FIG', 'は', '31日', '体操', '男子', 'で', '新型コロナウイルス']
# [124] 宇垣美里 報道記者目指してた エンタメ ['昨春', 'TBS', 'を', '退社', 'し', 'フリーアナウンサー', 'に', '転身']
# [125] ハロウィン夜空 46年ぶり満月 国内 ['きょう', '31日', 'ハロウィン', 'の', '夜', 'は', 'グッ', 'と']
# [126] 笑って 崖っぷち遊園地の思い 地域 ['新型コロナウイルス', 'の', '影響', 'で', '崖っぷち', 'に', '立たさ', 'れ']
# [127] 地震怖い トルコ在住の邦人 国際 ['All', 'Nippon', 'NewsNetworkANN', '強い', '揺れ', 'を', '観測', 'し']
# [128] 宇垣美里TBS時代の自分は商品 エンタメ ['昨春', 'TBS', 'を', '退社', 'し', 'フリーアナウンサー', 'に', '転身']
# [129] 女性→親子 鬼滅ファンの代謝 エンタメ ['劇場版アニメ', 'が', '史上', '最速', 'で', '100億円', 'を', '突破']
# [130] 渋野 国内2戦連続の予選落ち スポーツ ['樋口久子', '三菱電機', 'レディース', '渋野', 'は', 'ホールインワン', 'の', 'ジンクス']
# [131] 北海道で81人が感染 過去最多 地域 ['北海道', 'は', '10月31日', '石狩', 'や', '空知', '地方', 'など']
# [132] 改善しない巻き爪 医師が解説 科学 ['インターネット', 'で', '巻き爪', 'を', '検索', 'する', 'と', 'びっくり']
# [133] 日立「巨艦解体」も多難な道 経済 ['営業利益率', '10', '超', 'の', '目標', 'の', '足', 'を']
# [134] 巨人独走V 許した5球団の敗因 スポーツ ['巨人', 'が', '2年連続', '38度目', '1', 'リーグ', '時代', 'を']
# [135] 賞味期限 月単位に変更続々 経済 ['まだ', '食べ', 'られる', 'の', 'に', '廃棄', '処分', 'さ']
# [136] BTSファン 上場巡る激動1週間 国際 ['ジェットコースター', 'の', 'よう', 'に', '市場', 'の', '期待', 'と']
# [137] 都215人感染 3日連続200人超 国内 ['東京都', 'で', 'きょう', '新た', 'に', '215人', 'が', '新型コロナウイルス']
# [138] ハロウィン象徴 なぜカボチャ ライフ ['なぜ', 'ジャック', 'な', 'の', 'か', 'いつ', 'から', 'カボチャ']
# [139] トルコ地震で津波 溺死者も 国際 ['All', 'Nippon', 'NewsNetworkANN', 'トルコ西部', '沖の', 'エーゲ海', 'で', '30日']
# [140] 伊藤さん主演映画 公開へ エンタメ ['乗用車', 'を', '運転', '中', 'に', 'バイク', 'に', '衝突']
# [141] 戦力外通告の瞬間 経験者語る スポーツ ['ロッカー', 'に', '来', 'た', 'マネジャー', 'の', '姿', 'で']
# [142] 鬼滅人気「全集中」経済に光 地域 ['アニメ映画', '劇場版', '鬼滅の刃', '無限', '列車', '編', 'は', '公開']
# [143] 西武山川が抹消 本塁打王消滅 スポーツ ['西武', 'の', '山川穂高', '内野手', '28', 'が', '31日', '出場選手登録']
# [144] 厳しさ増す終盤 激戦州で訴え 国際 ['Nippon', 'News', 'Network', 'NNN', 'アメリカ大統領選挙', 'まで', 'あと', '4日']
# [145] 久保田磨希 認知症の母亡くし エンタメ ['ウェルネス', 'とーく', '少女時代', 'の', 'コンプレックス', 'を', '力', 'に']
# [146] アイマス声優 大坪由佳が結婚 エンタメ ['アニメ', 'アイドルマスター', 'シンデレラガールズ', '三村かな子', '役', 'など', 'で', '知ら']
# [147] トルコ地震 800人以上が死傷 国際 ['トルコ西部', 'で', '30日', '午後', 'に', '起き', 'た', 'マグニチュード']
# [148] 返礼品の和牛産地を偽装 大分 国内 ['大分県', '外', '産', 'の', '和牛', 'を', 'ブランド', '牛']
# [149] 捜査は尽くした 首里城火災 地域 ['首里城', '火災', 'の', '出火', '調査', 'に', '当たっ', 'た']
# [150] がん 死亡直前まで4割が痛み 国内 ['All', 'Nippon', 'NewsNetworkANN', 'がん', 'など', 'で', '亡くなっ', 'た']
# [151] 藤川 引退後は阪神に残らず スポーツ ['今季限り', 'で', 'の', '現役引退', 'を', '表明', 'し', 'て']
# [152] 未婚のパパ 結婚と法的違いは 国内 ['三代目', 'J', 'SOUL', 'BROTHERS', 'の', 'ELLY', 'さん', 'が']
# [153] 相当数に深刻な後遺症 WHO 国際 ['ベルリン', '時事', '世界保健機関', 'WHO', 'の', 'テドロス事務局長', 'は', '30日']
# [154] 速度違反捏造 警官ら書類送検 国内 ['北海道警', '交通機動隊', 'の', '警部補', 'が', '交通違反', 'の', '取り締まり']
# [155] 首里城 二度と燃えない城に 国内 ['沖縄', 'を', '象徴', 'し', 'て', 'き', 'た', '首里城']
# [156] 下平アナ 週半分は広島で主婦 エンタメ ['心', 'が', '動い', 'たら', '思い切っ', 'て', '踏み出す', 'タイプ']
# [157] G岡本 自分の成績にムカつく スポーツ ['JERA', 'セリーグ', '巨人', '3', '―', '3', 'ヤクルト', '延長']
# [158] 首里城 1年前の涙語る高校生 地域 ['沖縄タイムス', 'が', '首里城', '火災', 'を', '報じ', 'た', '昨年11月']
# [159] トルコ沖地震 死者20人超に 国際 ['イズミルローマ', '共同', '米', '地質調査所', 'USGS', 'に', 'よる', 'と']
# [160] 尚弥&モロニー距離10cmで火花 スポーツ ['プロボクシング', 'WBA', 'IBF', '世界', 'バンタム級', 'タイトルマッチ', '12回', '戦']
# [161] iPhone 知らない予定追加被害 国内 ['iPhone', 'アイフォーン', 'の', 'カレンダー', 'に', '勝手', 'に', '予定']
# [162] 信長の野望 37年売れ続ける訳 エンタメ ['文春', 'オンライン', 'で', '中間', '発表', 'さ', 'れ', 'た']
# [163] 逗子の崖崩れ 前日に亀裂発見 国内 ['神奈川県逗子市', 'で', '2月', '分譲マンション', '敷地内', 'の', '斜面', 'が']
# [164] 危険なバス停調査 6県780カ所 国内 ['12', '横断', '歩道', 'や', '交差点', 'の', 'そば', 'に']
# [165] G原監督 丸は骨折していた スポーツ ['JERA', 'セリーグ', '巨人', '3', '―', '3', 'ヤクルト', '30日']
# [166] Gドラ1平内に背番号11用意 スポーツ ['巨人', 'から', 'ドラフト1位指名', 'を', '受け', 'た', '亜大', '平内']
# [167] トルコ沖で地震 複数の死者 国際 ['エルサレム', '時事', 'トルコ西部', '沖の', 'エーゲ海', 'で', '30日', '午後2時']
# [168] ユーロ圏GDP12%増 上げ最大 国際 ['ブリュッセル', '時事', '欧州連合', 'EU', '統計局', 'が', '30日', '発表']
# [169] 嵐 被災地に寄り添った歴史 エンタメ ['大', 'ブレイク', 'を', '果たし', '国民', '的', 'アイドル', 'に']
# [170] 伊藤さん釈放 30秒超頭下げる エンタメ ['29日', 'に', '自動車運転処罰法', '違反', '過失', '傷害', 'と', '道路交通法違反']
# [171] 地中海 ギリシャでM7.0の地震 国内 ['日本時間', 'の', '10月30日', '金', '20時', '51分', '頃', '海外']
# [172] 北海道 強毒性鳥インフル確認 国内 ['北海道', 'は', '30日', '紋別', 'もん', 'べつ', '市内', 'で']
# [173] ハマスタ実証実験 目安届かず スポーツ ['セリーグ', 'DeNA', '―', '阪神', '2020年', '10月30日', '横浜', '横浜']
# [174] 巨人がリーグ2連覇 スポーツ ['JERA', 'セリーグ', '巨人', '3', '―', '3', 'ヤクルト', '延長']
# [175] 第一生命元職員 5200万円詐取 経済 ['FNN', 'プライム', 'オンライン', '第一生命', 'の', '生保', 'レディー', 'が']
# [176] KDDI 格安スマホで新会社 経済 ['FNN', 'プライム', 'オンライン', 'KDDI', 'が', '格安スマホ', 'ブランド', 'として']
# [177] 伊藤容疑者が釈放 涙ぐみ謝罪 エンタメ ['道交法違反', 'ひき逃げ', 'など', 'の', '疑い', 'で', '逮捕', '送検']
# [178] GoToトラベルに制限 7泊まで 国内 ['CopyrightC', 'Japan', 'News', 'Network', 'All', 'rights', 'reserved', 'GoTo']
# [179] 給付金 返還の申し出6千件 経済 ['新型コロナウイルス', 'の', '経済', '対策', 'の', '持続化給付金', 'を', '不適切']
# [180] 短期出張 帰国後待機を免除へ 国内 ['政府', 'は', '30日', '海外', 'へ', 'の', '短期', '出張']
# [181] 台湾で鬼滅公開 熱狂ファンも 国際 ['Nippon', 'News', 'Network', 'NNN', '驚異', '的', 'な', 'ヒット']
# [182] 首相 学術会議は旧帝大が45% 国内 ['菅義偉', '首相', 'は', '30日', 'の', '参院本会議', 'で', '日本学術会議']
# [183] 有休取得率56.3% 過去最高 経済 ['厚生労働省', 'が', '30日', '発表', 'し', 'た', '就労', '条件']
# [184] 自殺誘う情報で通報 上期最多 国内 ['警察庁', 'の', '委託', 'を', '受け', 'て', 'インターネット上', 'の']
# [185] 皿洗いで無料の店 最後の思い ライフ ['食後', '30分間', 'の', '皿洗い', 'で', '1', '食', '無料']
# [186] 内閣の資産公開 首相6277万円 国内 ['菅義偉', '首相', 'と', '閣僚', 'の', '計', '21人', 'は']
# [187] 切り捨て生む 地震が変えた町 地域 ['北海道', 'ニュース', 'UHB', '死者', '44人', '建物', '被害', 'が']
# [188] リニア工事差し止め求め 提訴 地域 ['リニア中央新幹線', 'の', '建設工事', 'を', '巡り', '大井川', '流域', 'の']
# [189] 北村匠海 映画公開も「不安」 エンタメ ['俳優', 'の', '北村匠海', '22', '女優', 'の', '山本舞香', '23']
# [190] 朗希 今季は公式戦で登板なし スポーツ ['ロッテ', '佐々木朗希', '投手', '18', 'が', '今季', 'の', '12']
# [191] DCM 島忠TOBの条件変更考えず 経済 ['東京', '30日', 'ロイター', '島忠', '8184', 'T', 'に対する', '株式公開']
# [192] 高齢者を捨て 若者優先した町 地域 ['北海道', 'ニュース', 'UHB', '死者', '44人', '建物', '被害', 'が']
# [193] 都の感染者204人 20代が最多 国内 ['東京都', 'に', 'よる', 'と', '30日', 'に', '都', 'が']
# [194] 石崎議員に罰金20万円 おわび 地域 ['NST', '新潟総合テレビ', '去年', '車内', 'で', '元', '秘書', 'の']
# [195] ハロウィン 自治体で判断に差 国内 ['31日', 'に', '迫っ', 'た', 'ハロウィーン', '例年', '繁華街', 'に']
# [196] G大阪の不祥事 監督は衝撃大 スポーツ ['ガンバ大阪', 'の', '宮本恒靖', '監督', '43', 'が', '30日', 'オンライン']
# [197] NTC 体操練習場の利用中止 スポーツ ['体操', 'の', '内村航平', '選手', 'リンガーハット', 'の', '新型コロナウイルス', '感染']
# [198] JR西日本 中間決算初の赤字 経済 ['JR西日本', 'が', '30日', '発表', 'し', 'た', '2020年', '9月']
# [199] 北 韓国人射殺は「自衛措置」 国際 ['ソウル', '30日', 'ロイター', '北朝鮮', '国営', 'の', '朝鮮中央通信社', 'KCNA']
# [200] 検査1日6万件に引き上げへ 都 国内 ['12', '東京都', 'の', '小池百合子知事', 'は', '30日', 'の', '定例記者会見']
# [201] 国産ジェット開発費20分の1に 経済 ['三菱重工業', 'は', '2020年', '10月30日', '金', '2021年度', 'から', '2023年度']
# [202] JAL 赤字最大2700億円予想 経済 ['日本航空', 'は', '30日', '2021年', '3月', '期', 'の', '純']
# [203] 伊藤容疑者 近く釈放へ 国内 ['ひき逃げ', 'など', 'の', '疑い', 'で', '逮捕', 'さ', 'れ']
# [204] 9カ国・地域の感染危険度緩和 国内 ['茂木敏充', '外相', 'は', '30日', 'の', '記者会見', 'で', '新型コロナウイルス']
# [205] 説明十分?都構想あさって投票 国内 ['11月1日', 'の', '投開票', 'で', '賛否', 'が', '明らか', 'に']
# [206] スカヨハ 俳優と3度目の結婚 エンタメ ['映画', 'アベンジャーズ', 'シリーズ', 'の', 'ブラックウィドウ', '役', 'など', 'で']
# [207] 救急車 全国無料で高速OKに 国内 ['河野太郎', '行政改革', '相', 'は', '30日', 'の', '閣議後', '会見']
# [208] 五輪チケ払い戻し 11/10から スポーツ ['東京五輪', 'パラリンピック', '組織委員会', 'は', '30日', '新型コロナウイルス', 'の', '影響']
# [209] GoToクーポン不正 国が対策 国内 ['国', 'の', '観光', '支援', '事業', 'Go', 'To', 'トラベル']
# [210] 米選挙 運命握るカトリック票 国際 ['ピューリサーチセンター', 'が', '今月', '行っ', 'た', '調査', 'に', 'よる']
# [211] 休暇分散 西村氏経済界に要請 国内 ['西村康稔', '経済', '再生', '担当相', 'は', '30日', '午前', '経済3団体']
# [212] UPLINKのパワハラ訴訟 和解 エンタメ ['今年6月', 'パワハラ', 'で', '元従業員', 'ら', 'に', '提訴', 'さ']
# [213] インフル接種 予約終了病院も 科学 ['冬', 'を', '控え', 'インフルエンザ予防接種', 'の', '予約', 'が', '医療機関']
# [214] LIXIL 希望退職1200人募集 経済 ['住宅', '設備', '大手', 'の', 'LIXIL', 'リクシルグループ', 'は', '30日']
# [215] 精神疾患で自殺 29日以下51% 国内 ['政府', 'は', '30日', '労働', '現場', 'の', '過労', 'の']
# [216] 渋野 2度目のホールインワン スポーツ ['樋口久子', '三菱電機', 'レディース', '初日', '女子ゴルフ', 'の', '樋口久子', '三菱電機']
# [217] 引き揚げ者住宅巡り退去命令 国内 ['太平洋戦争', '後', '旧', '満州', 'など', 'から', 'の', '引き揚げ']
# [218] 日本食?英料理番組に批判殺到 国際 ['ロンドン', '時事', '英', '放送局', 'チャンネル', '4', 'の', '人気']
# [219] 伊藤容疑者 事故分かっていた 国内 ['Nippon', 'News', 'Network', 'NNN', '東京渋谷区', 'で', '車', 'を']
# [220] GoTo観光以外は除外へ 国交相 国内 ['赤羽一嘉', '国土交通相', 'は', '30日', 'の', '閣議後', '記者会見', 'で']
# [221] GAFA3社最高益 際立つ好業績 経済 ['ニューヨーク', '共同', 'GAFA', 'と', '呼ば', 'れる', '米', '巨大']
# [222] NZの国民投票 安楽死賛成65% 国際 ['シドニー', '時事', '今月17日', 'の', 'ニュージーランド', 'NZ', '総選挙', 'に']
# [223] JAL ヤマトなどに500人出向 経済 ['日本航空', 'から', '外部', '企業', 'に', '一時', '的', 'に']
# [224] 元非行少年 厳罰化は解決策か 国内 ['1819', '歳', 'を', '現行', 'より', 'も', '厳罰', '化']
# [225] 転落巻き添え 遺族への補償は 国内 ['阪急', '大阪梅田駅', '近く', 'の', '繁華街', 'で', '10月23日', 'に']
# [226] 米ウォルマート 店から銃撤去 国際 ['ニューヨーク', '共同', '米', '小売り', '大手', 'ウォルマート', 'は', '29日']
# [227] 「今日俺」ポスター撤去 県警 地域 ['人気', '俳優', 'の', '伊藤健太郎', 'いとう', 'けんたろう', '容疑者', '23']
# [228] 企業の内部留保 8年連続で増 経済 ['12', '財務省', 'が', '30日', '発表', 'し', 'た', '2019年度']
# [229] 伊藤健太郎容疑者を送検 国内 ['All', 'Nippon', 'NewsNetworkANN', '東京渋谷区', 'で', 'ひき逃げ', '事件', 'を']
# [230] 川重 バイク生産を分社化へ 経済 ['大手', '重工', 'メーカー', 'の', '川崎重工業', '神戸市中央区', 'が', '新型コロナウイルス']
# [231] 0円で町が温泉売却 応募ゼロ? 国内 ['湯', 'どころ', 'として', '知ら', 'れる', '岩手県西和賀町', 'が', '町営']
# [232] 平野ノラ42歳 第1子を妊娠 エンタメ ['2017年', 'に', '一般男性', 'と', '結婚', 'し', 'た', '平野ノラ']
# [233] 巨額詐欺 倉庫の6千万円押収 国内 ['家庭', '用', '磁気', '商品', 'の', 'オーナー', '販売', '預託商法']
# [234] 米 UAEにF35を売却する方針 国際 ['ワシントン', '時事', 'トランプ', '米', '政権', 'は', '29日', 'アラブ首長国連邦']
# [235] SB周東 普通はできない走塁術 スポーツ ['1992年', 'に', '盗塁王', 'の', 'タイトル', 'を', '獲得', 'し']
# [236] 虎・福留が退団明言 現役続行 スポーツ ['阪神', 'の', '福留孝介', '外野手', '43', 'が', '29日', '鳴尾浜球場']
# [237] クラスター 全国で1761カ所に 国内 ['新型コロナウイルス', 'の', '感染拡大', 'に', '伴い', '全国各地', 'で', '発生']
# [238] 大阪市 4分割コスト試算撤回 国内 ['大阪市', 'を', '四つ', 'の', '自治体', 'に', '分割', 'し']
# [239] 石破派混乱「空中分解」の声 国内 ['自民党', '石破派', '水月会', 'で', '石破茂', '前', '会長', 'の']
# [240] 鬼滅 既刊22巻ランキング独占 エンタメ ['吾峠呼世晴', '鬼滅の刃', 'の', '最新', '22巻', 'が', '週間', '326']
# [241] 大竹しのぶ 芸歴47年初の月9 エンタメ ['女優', 'の', '大竹しのぶ', 'が', '11月30日', 'に', '放送', 'さ']
# [242] 芸能界と事故 運転禁止の傾向 エンタメ ['伊藤健太郎', '容疑者', 'ひき逃げ', 'の', '疑い', 'で', '逮捕', '2020年']
# [243] 斎藤佑 初の1軍登板なしに スポーツ ['日本ハム', 'の', '吉村', '浩', 'GM', 'が', '29日', 'オリックス']
# [244] ゴーン被告支援 2人引き渡しへ 国際 ['ボストン', '29日', 'ロイター', '米', '国務省', 'は', '日産自動車', '7201']
# [245] 伊藤容疑者 数億円の違約金か エンタメ ['俳優', '伊藤健太郎', '容疑者', '23', 'が', '自動車運転処罰法', '違反', '過失']
# [246] 仏 テロ警戒水準を最高に 国際 ['パリ', '共同', 'フランス南部', 'ニース', '中心部', 'の', 'ノートルダム教会', 'で']
# [247] 内村の感染 五輪関係者に衝撃 スポーツ ['国際体操連盟', 'の', '渡辺', '守成', '会長', 'が', '29日', '緊急会見']
# [248] 表紙に伊藤容疑者 小説誌変更 国内 ['俳優', 'の', '伊藤健太郎', '容疑者', '23', 'が', '道路交通法違反', 'ひき逃げ']
# [249] 雇用助成の特例 来年も継続へ 経済 ['企業', 'が', '従業員', 'に', '支払う', '休業手当', 'の', '一部']
# [250] ELLYもう親バカ?本当かわいい エンタメ ['人気グループ', '三', '代目', 'J', 'SOUL', 'BROTHERS', 'の', 'ELLY']
# [251] 習近平氏の長期政権化へ攻防 国際 ['北京', '西見由章', '29日', '閉幕', 'し', 'た', '中国共産党', 'の']
# [252] 学術会議会長 首相に反論 国内 ['日本学術会議', 'の', '梶田隆章', '会長', 'ら', '幹部', '4人', 'は']
# [253] 伊藤容疑者「気が動転した」 国内 ['車', 'を', '運転', '中', 'に', 'バイク', 'と', '衝突']
# [254] 米GDP、過去最大の33.1%増 経済 ['米', '商務省', 'が', '29日', '発表', 'し', 'た', '2020年']
# [255] アンゴラ村長 縄跳びでギネス エンタメ ['お笑いコンビ', 'にゃんこスター', 'の', 'アンゴラ村長', 'が', '“', 'プロ', 'な']
# [256] 巨人 今季最悪5連敗でもM1に スポーツ ['セリーグ', '巨人', '2', '―', '5', 'DeNA', '2020年', '10月29日']
# [257] 石破派 竹下派と合流構想浮上 国内 ['自民党', 'の', '石破茂', '元', '幹事長', 'が', '会長', '辞任']
# [258] 在サウジ仏領事館で刃物襲撃 国際 ['AFP', '時事', '更新', '写真', '追加', 'サウジアラビア', 'ジッダ', 'Jeddah']
# [259] 福島県 人件費求め東電を提訴 地域 ['県', 'は', '2013年度', 'に', '原発事故', 'の', '対応', 'で']
# [260] ワクチン供給3社目 政府契約 国内 ['厚生労働省', 'は', '29日', '米', 'バイオテクノロジー', '企業', 'モデルナ', 'が']
# [261] 仏で刃物襲撃3人死亡 テロか 国際 ['AFP', '時事', '更新', '写真', '追加', 'フランス南部', 'ニース', 'Nice']
# [262] ドンキ前社長 株取引で不正か 国内 ['Nippon', 'News', 'Network', 'NNN', 'ディスカウントストア', 'の', 'ドンキホーテ', 'など']
# [263] 伊藤容疑者 NHKドラマを降板 エンタメ ['NHK', 'は', '29日', '伊藤健太郎', '容疑者', 'が', '出演予定', 'だっ']
# [264] 内村航平が新型コロナ陽性 スポーツ ['国際体操連盟', 'FIG', 'の', '渡辺', '守成', '会長', 'ら', 'が']
# [265] 香港 国安法違反で活動家起訴 国際 ['AFP', '時事', '香港当局', 'は', '29日', '6月', 'に', '解散']
# [266] くそたれ地震 不満のみ込む今 地域 ['北海道', 'ニュース', 'UHB', '死者', '44人', '建物', '被害', 'が']
# [267] GoToイート紙切れ 担当者憤り 地域 ['新型コロナウイルス', 'の', '影響', 'で', '打撃', 'を', '受け', 'た']
# [268] 週末 東日本で冷え込み強まる 国内 ['明日', '30日', '金', 'は', '上空', 'の', '寒気', 'が']
# [269] SB周東が12戦連続盗塁 プロ新 スポーツ ['ソフトバンクロッテ', '29日', 'ペイペイドーム', 'ソフトバンク', '周東', 'が', '12試合', '連続']
# [270] TDR運営 511億円赤字の見通し 経済 ['オリエンタルランド', 'は', '29日', '2021年', '3月', '期', 'の', '連結']
# [271] 伊藤容疑者 事故直後の映像 国内 ['FNN', 'プライム', 'オンライン', '29日', 'ひき逃げ', 'など', 'の', '疑い']
# [272] 日本初 糖質0ビールどう実現 ライフ ['糖質ゼロ', 'と', 'いえ', 'ば', '発泡酒', 'や', '第三のビール', 'で']
# [273] 給食で100人超食中毒 鶏に菌 国内 ['東京都', 'は', '29日', '中野', '区立', '中野', '第一小学校', 'で']
# [274] ビシエド抹消 打点王は絶望的 スポーツ ['中日', 'の', 'ダヤンビシエド', '内野手', '31', 'が', '29日', '出場選手登録']
# [275] 案里被告 参院本会議を欠席 国内 ['昨年7月', 'の', '参院選', '広島選挙区', 'を', '巡る', '大規模', '買収']
# [276] 「THE W」決勝進出10組が決定 エンタメ ['女性芸人', 'の', '中', 'から', '一番', '面白い', '“', '笑い']
# [277] 巨人 きょう優勝の条件は スポーツ ['巨人', 'は', 'リーグ2', '連覇', 'へ', '優勝', 'マジック', 'を']
# [278] ニトリ 島忠にTOB実施を発表 経済 ['家具', '製造', '販売', '大手', 'の', 'ニトリホールディングス', 'は', '29日']
# [279] ウイカ 尊敬するのはリンゴ エンタメ ['オーディション', 'で', 'ひな壇', 'の', '座', 'を', '勝ち取る', 'アイドル']
# [280] 鈴木氏の出馬断念 知事は驚き 地域 ['来年', '春', 'の', '千葉県知事選', 'を', '巡り', '森田健作知事', '70']
# [281] 東京都 新たに221人感染確認 国内 ['東京都', 'に', 'よる', 'と', '29日', 'に', '都', 'が']
# [282] 伊藤容疑者 とんかつDJは公開 エンタメ ['道交法違反', 'ひき逃げ', 'など', 'の', '疑い', 'で', '俳優', 'の']
# [283] トヨタ、9月生産が過去最高 経済 ['トヨタ自動車', 'が', '29日', '発表', 'し', 'た', '9月', 'の']
# [284] GoToイベント 第1弾にUSJ 経済 ['経済産業省', 'は', '29日', '新型コロナウイルス', '対策', 'の', '需要', '喚起']
# [285] 歓楽街に検査拠点を 分科会 国内 ['政府', 'の', '新型コロナウイルス感染症', '対策', '分科会', 'が', '29日', '開か']
# [286] AIでいじめ対策 7市導入検討 国内 ['いじめ', '被害', 'を', '減らす', 'ため', '大津市', 'など', 'が']
# [287] 国内感染者 客船含め10万人超 国内 ['東京都', 'で', '29日', 'に', '新型コロナウイルス', 'の', '感染者', 'が']
# [288] デンソー中間決算赤字711億円 経済 ['トヨタ自動車', '系', 'の', '部品', 'メーカー', 'デンソー', 'が', '29日']
# [289] 伊藤容疑者 目撃者が追い説得 国内 ['28日', '午後5時', '45分', '頃', '東京都渋谷区千駄ヶ谷', 'の', '都道', '交差点']
# [290] 日銀 大規模緩和の維持決定 経済 ['日銀', 'は', '29日', '前日', 'に', '続い', 'て', '金融政策決定会合']
# [291] 伊藤容疑者逮捕 事務所が謝罪 エンタメ ['道交法違反', 'ひき逃げ', 'など', 'の', '疑い', 'で', '警視庁', 'に']
# [292] フジ 伊藤容疑者番組差し替え エンタメ ['フジテレビ', 'は', '29日', '道路交通法違反', '容疑', 'ひき逃げ', 'で', '逮捕']
# [293] 行き過ぎ指導 元生徒が提訴 地域 ['HOME', '広島ホームテレビ', '行き過ぎ', 'た', '指導', 'により', '退学', 'を']
# [294] 再審無罪 宮田浩喜さんが死去 地域 ['1985年', 'に', '熊本県宇城市', '松橋町', 'で', '男性', '当時', '59']
# [295] 李元大統領に懲役17年確定 国際 ['ソウル', '共同', '韓国', '最高裁', 'は', '29日', '大統領', '在職']
# [296] 第一生命 企業年金利率下げる 経済 ['第一生命保険', 'は', '29日', '企業年金', '保険', 'を', '運用', 'する']
# [297] 伊藤容疑者 事故現場離れた 国内 ['俳優', 'の', '伊藤健太郎', '容疑者', '23', 'が', '10月28日', '夜']
# [298] エビ中・安本彩花 治療で休養 エンタメ ['私立恵比寿中学', 'の', '安本彩花', 'が', '悪性リンパ腫', 'の', '診断', 'を']
# [299] 男性不妊 語る治療の難しさ 国内 ['27日', 'の', '記者会見', 'で', '女性', 'だけ', 'で', 'なく']
# [300] スノボ五輪銅 平岡被告に有罪 国内 ['追突事故', 'を', '起こし', '飲酒運転', 'の', '発覚', 'を', '免れる']
# [301] 伊藤健太郎容疑者を逮捕 国内 ['乗用車', 'を', '運転', '中', 'に', 'バイク', 'と', '衝突事故']
# [302] 政府 多機能イージス艦新造へ 国内 ['政府', 'が', '地上', '配備', '型', '迎撃', 'システム', 'イージスアショア']
# [303] 家に犬164匹 多頭飼育崩壊か 国内 ['島根県出雲市', 'の', '民家', 'で', '今月', '160', '匹', '以上']
# [304] 伊藤健太郎さん事故 女性重傷 国内 ['俳優', 'の', '伊藤健太郎', 'さん', 'が', 'きのう', '東京渋谷区', 'で']
# [305] 競技場の盗撮 対策の難しさ 国内 ['女子', 'アスリート', 'の', '胸', 'や', 'お', '尻', 'を']
# [306] 首里城火災1年あの日の悔しさ 地域 ['首里城', '火災', 'あれから', '1年', '上', '1031', '当日', '昨年']
# [307] 行き過ぎ指導 元生徒が提訴へ 国内 ['行き過ぎ', 'た', '生徒指導', 'により', '退学', 'を', '余儀なく', 'さ']
# [308] ニトリ、島忠の全株取得へ 経済 ['家具', '日用品', '大手', 'の', 'ニトリホールディングス', 'が', 'ホームセンター', '中堅']
# [309] 仏 ロックダウン再導入へ 国際 ['AFP', '時事', '更新', 'フランス', 'の', 'エマニュエルマクロン', 'Emmanuel', 'Macron']
# [310] 鬼滅 ファンが生んだ「聖地」 エンタメ ['今や', '社会現象', 'と', 'なっ', 'て', 'いる', 'アニメ', '鬼滅の刃']
# [311] 鈴木大地氏 知事選出馬を断念 地域 ['来年4月', 'の', '任期満了', 'に', '伴う', '千葉県知事選', 'で', '自民党']
# [312] 深田恭子 新婚生活を「妄想」 エンタメ ['年々', '美し', 'さ', 'と', '輝き', 'を', '増す', '女優']
# [313] GoTo 電子クーポン不正取得か 国内 ['All', 'Nippon', 'NewsNetworkANNGoTo', 'トラベル', 'キャンペーン', 'の', '期間', '延長']
# [314] YouTuber事務所VAZ 社長退任 エンタメ ['大手', 'ユーチューバー', '事務所', 'VAZ', 'の', '森', '泰輝', '氏']
# [315] NY株943ドル安 3カ月ぶり安値 経済 ['ニューヨーク', '共同', '28日', 'の', 'ニューヨーク株式市場', 'の', 'ダウ工業株30種平均', 'は']
# [316] 阪神一筋の上本博紀 退団へ スポーツ ['阪神', 'の', '上本博紀', '内野手', '34', 'が', '球団', 'から']
# [317] 白石 卒コンで何度も「幸せ」 エンタメ ['人気', 'アイドルグループ', '乃木坂46', 'の', '白石麻衣', '28', 'が', '28日']
# [318] 錦織圭 右肩負傷で今季終了 スポーツ ['錦織圭', '男子テニス', 'で', '世界ランク', '37位', 'の', '錦織圭', 'は']
# [319] 白石 卒コン序盤から涙腺崩壊 エンタメ ['乃木坂46', '白石麻衣', '28', 'の', '卒業コンサート', 'NOGIZAKA', '46', 'Mai']
# [320] かんぽ不正 新たに490人処分 経済 ['日本郵政グループ', 'は', '28日', '傘下', 'の', 'かんぽ生命保険', 'の', '不適切']
# [321] 関テレ デヴィ夫人発言で謝罪 ライフ ['関西テレビ', '大阪市', 'は', '28日', '関西地区', 'など', 'で', '24日']
# [322] 4連敗 G監督そうですね10連発 スポーツ ['DeNA', '106', '巨人', '28日', '横浜', '巨人', 'は', '今季']
# [323] 森元首相 鈴木大地氏出馬に反対 国内 ['東京五輪', 'パラリンピック', '組織委員会', '会長', 'の', '森喜朗', '元首相', 'は']
# [324] シリアの停戦 崩壊の危機に 国際 ['カイロ', '共同', 'トルコ', 'の', 'エルドアン', '大統領', 'は', '28日']
# [325] 今年台風上陸なし?幸運重なる 国内 ['昨年', '日本列島', 'に', '再三', '上陸', 'し', 'て', '甚大']
# [326] SB周東11試合連続盗塁に成功 スポーツ ['ソフトバンクロッテ', '28日', 'ペイペイドーム', 'ソフトバンク', '周東', 'が', '3回', '二死']
# [327] 時速380km「圧力感じない」 地域 ['仙台放送', '時速', '380キロ', 'の', '世界', 'を', '体験', 'です']
# [328] 大麻所持 東海大生ら2人逮捕 国内 ['FNN', 'プライム', 'オンライン', '東海大学', 'の', '学生', 'ら', 'が']
# [329] JTB 転勤でも引っ越しせずOK 経済 ['旅行', '大手', 'の', 'JTB', 'は', '28日', '従来', 'なら']
# [330] 嵐が謝罪 中日「恐縮です」 エンタメ ['プロ野球', 'の', '〝', '試合', '中断', '騒動', '〟', 'を']
# [331] コロナ感染「微増傾向続く」 国内 ['新型コロナウイルス', '対策', 'を', '助言', 'する', '厚生労働省', 'の', '専門家']
# [332] 集配所殺傷 遺族「許さない」 地域 ['神戸市北区', 'の', 'ヤマト運輸', '配送センター', 'で', '従業', '員', 'の']
# [333] 日立製作所 営業利益39%減 経済 ['日立製作所', 'が', '28日', '発表', 'し', 'た', '20年', '9月']
# [334] 紙不足 京都がGoTo食事券停止 国内 ['新型コロナウイルス', 'の', '影響', 'で', '打撃', 'を', '受け', 'た']
# [335] 三代目ELLYがパパに 結婚せず エンタメ ['三代目', 'J', 'SOUL', 'BROTHERS', 'の', 'パフォーマー', 'ELLY', '33']
# [336] 菅首相 任命拒否の判断変えず 国内 ['菅首相', 'は', '28日', '午後', '衆院本会議', 'の', '代表質問', 'で']
# [337] JR東海 純損益1135億円の赤字 経済 ['JR東海', 'が', '28日', '発表', 'し', 'た', '2020年', '9月']
# [338] 調布の陥没 東日本高速が陳謝 国内 ['東京都調布市', 'の', '東京外郭環状道路', 'トンネル', '工事', '現場近く', 'で', '起き']
# [339] 貯水槽に男性遺体 殺人で捜査 地域 ['28日', '午前11時', '5分', 'ごろ', '千葉県印西市小林', 'の', '防火', '貯水槽']
# [340] トヨタ 39車種21万台リコール 国内 ['トヨタ自動車', 'は', '28日', '走行', '中', 'に', 'エンスト', 'する']
# [341] 若年女性の失業4.7% 最も悪化 経済 ['新型コロナウイルス', '感染拡大', 'の', '影響', 'で', '雇用', '環境', 'が']
# [342] 土砂崩れ作業員1人死亡 大阪 国内 ['28日', '正午', '頃', '大阪府茨木市千提寺', 'の', '資材', '置き場', 'で']
# [343] 試合中断 嵐がおわびの色紙 エンタメ ['24日', 'に', 'アイドルグループ嵐', 'が', '国立競技場', 'で', '行っ', 'た']
# [344] アパート内で豚解体 4人逮捕 国内 ['許可', 'を', '得', 'て', 'い', 'ない', '場所', 'で']
# [345] 漁業被害 アザラシがゴロゴロ 国内 ['冬', 'が', '近づく', '中', '北海道北', 'の', '宗谷', '地域']
# [346] デヴィ夫人 不妊巡る発言謝罪 エンタメ ['デヴィ夫人', 'こと', 'タレント', 'の', 'デヴィスカルノ', '氏', 'が', '28日']
# [347] 土砂崩れ1人心肺停止 大阪 地域 ['大阪府茨木市', 'の', '土木工事', '会社', 'の', '資材', '置き場', 'で']
# [348] 正月休み分散 自民幹部が苦言 国内 ['自民党', 'の', '下村博文', '政調会長', 'は', '28日', '新型コロナウイルス', '感染拡大']
# [349] 首相 任命拒否の違法性否定 国内 ['菅首相', 'は', '28日', '午後', '衆院本会議', 'の', '代表質問', 'で']
# [350] 東京都 新たに171人感染確認 国内 ['東京都', 'に', 'よる', 'と', '28日', 'に', '都', 'が']
# [351] 大好きだった祖母殺害 介護限界 国内 ['黒髪', 'を', 'キュッと', '結ん', 'だ', 'ポニーテール', '白い', 'ブラウス']
# [352] 6人死傷火災 元店長に有罪 地域 ['2015年', 'に', '3人', 'が', '死亡', 'し', '3人', 'が']
# [353] 国税庁「路線価」引き下げず 経済 ['国税庁', 'は', '28日', '相続税', 'や', '贈与税', 'の', '算定']
# [354] MLBド軍優勝 監督は沖縄出身 スポーツ ['6回', 'に', 'ベッツ', 'の', '好', '走塁', 'で', '逆転']
# [355] ノブコブ徳井、離婚していた エンタメ ['お笑いコンビ', '平成ノブシコブシ', 'の', '徳井健太', '40', 'が', '27日', 'に']
# [356] 加藤氏 原発の新増設想定せず 国内 ['加藤勝信', '官房長官', 'は', '28日', '午前', 'の', '記者会見', 'で']
# [357] 三男死なせた長女 家族に何が 国内 ['知的障害', 'が', 'ある', '長女', 'が', '自宅', 'で', '三男']
# [358] MLBドジャース32年ぶり世界一 スポーツ ['レイズ', '13', 'ドジャース', 'グローブライフフィールド', 'ドジャース', 'は', 'レイズ', 'と']
# [359] 感染対策が不足 受刑者が提訴 地域 ['読売テレビ', '刑務所', '内', 'の', '新型コロナウイルス', 'へ', 'の', '対策']
# [360] 大塚家具 久美子社長が辞任へ 経済 ['大塚家具', 'の', '社名', 'は', 'そのまま', '変え', 'ない', '方針']
# [361] ハワイ 日本の観光客受け入れ 国際 ['FNN', 'プライム', 'オンライン', '新型コロナウイルス', 'の', '影響', 'で', '訪問']
# [362] メッシと対立 バルサ会長辞任 スポーツ ['前日', 'に', 'は', '辞任', 'が', '頭', 'を', 'よぎっ']
# [363] 北海道 警戒ステージ引き上げ 地域 ['北海道', 'は', '28日', '午前', 'の', '新型コロナウイルス感染症対策本部', '会議', 'で']
# [364] 間宮祥太朗 成田凌から相談も エンタメ ['15歳', 'の', '役者', 'デビュー', '以降', 'コメディ', 'から', 'シリアス']
# [365] 間宮祥太朗 ブレイクなかった エンタメ ['15歳', 'の', '役者', 'デビュー', '以降', 'コメディ', 'から', 'シリアス']
# [366] 携帯値下げ SBとKDDIが新料金 経済 ['All', 'Nippon', 'NewsNetworkANN', '政府', 'の', '携帯', '料金', '引き下げ']
# [367] 静岡銀と山梨中銀が提携へ 経済 ['静岡銀行', 'と', '山梨中央銀行', 'が', '業務', '提携', 'する', 'こと']
# [368] 国家公務員の月給 据え置きへ 国内 ['人事院', 'は', '28日', '2020年度', 'の', '国家公務員', '月給', 'について']
# [369] ALFA-X初試乗会 時速382km 国内 ['JR東日本', 'は', '27日', '深夜', 'から', '翌日', '未明', 'にかけ']
# [370] 鬼滅特需も 続くシネコン苦境 エンタメ ['鬼滅の刃', '異例', 'の', '大', 'ヒット', '今年', '最大', 'の']
# [371] 米で警官撃ち黒人死亡 波紋 国際 ['Nippon', 'News', 'Network', 'NNN', '1週間', '後', 'に', '迫っ']
# [372] 首里城再建の寄付 50億円突破 地域 ['首里城', '火災', 'から', '31日', 'で', '1年', 'が', 'たつ']
# [373] 卒後3年は新卒扱い 政府要請  経済 ['田村憲久', '厚生労働相', 'は', '27日', '萩生田光一', '文部科学相', '坂本哲志', '1億総活躍']
# [374] トヨタ系に出向 三菱重が打診 経済 ['東京', '28日', 'ロイター', '新型コロナウイルス', 'の', '影響', 'で', '業績']
# [375] ツキヨタケ中毒相次ぐ 県注意 地域 ['毒キノコ', 'ツキヨタケ', 'の', '食中毒', '発生', 'が', '県内', 'で']
# [376] 学術会議 官邸14年選考も関心 国内 ['日本学術会議', 'が', '推薦', 'し', 'た', '会員', '候補', '6人']
# [377] 陸上コールマン 五輪は絶望的 スポーツ ['陸上', '男子', '100メートル', 'で', '19年', '世界選手権', '金', 'メダリスト']
# [378] 「女性活躍」重い?現場の疲弊 地域 ['輝け', '輝け', 'って', 'ホタル', 'じゃ', 'ない', 'ん', 'だ']
# [379] 米、香港活動家の亡命拒絶か 国際 ['香港', '共同', '香港', '英字紙', 'サウスチャイナモーニングポスト', '電子版', 'は', '27日']
# [380] 米大統領選まで1週間 接戦へ 国際 ['ワシントンロサンゼルスウォームスプリングス', '米', 'ジョージア州', '27日', 'ロイター', '米大統領選', 'が', '1週間']
# [381] 伊の新規感染2.2万人過去最多 国内 ['ローマ', '共同', 'イタリア政府', 'は', '27日', '新型コロナウイルス', 'の', '感染者']
# [382] ANA 「再浮揚」なお視界不良 経済 ['ANAホールディングス', 'HD', 'が', '27日', '発表', 'し', 'た', '事業']
# [383] 消費税不正 40億円を追徴課税 国内 ['国税', '当局', 'が', '全国', 'の', '免税店', 'など', 'を']
# [384] 病で収監延期 田代まさしの今 エンタメ ['2019年', '11月', 'に', '覚醒剤取締法', '違反', 'の', '罪', 'など']
# [385] GoToトラベル延長へ 政府調整 国内 ['政府', '与党', 'は', '27日', '来年1月', '末', 'に', '期限']
# [386] FIFA会長がコロナ陽性 隔離 スポーツ ['国際サッカー連盟', 'FIFA', 'は', '27日', 'ジャンニインファンティーノ', '会長', '50', 'が']
# [387] ミラクル9 入社1年目アナ起用 エンタメ ['テレビ朝日', '系', 'で', '放送', '中', 'の', 'クイズ番組', 'ミラクル9']
# [388] LVMH ティファニー買収再交渉 経済 ['ニューヨーク', '27日', 'ロイター', '仏', '高級', 'ブランド', 'LVMH', 'モエヘネシールイヴィトン']
# [389] 斎藤佑樹 右肘手術を検討  スポーツ ['日本ハム', 'の', '斎藤佑樹', '投手', '32', 'が', '右肘', 'の']
# [390] SB内川退団へ 現役続行は模索 スポーツ ['2軍', 'で', '結果', 'も', '今季', '1軍', '昇格', 'なし']
# [391] 個人番号夜間も対応を 総務相 国内 ['武田良太', '総務相', 'は', '27日', 'の', '閣議後', '記者会見', 'で']
# [392] SB優勝 ロボット踊る祝勝会 スポーツ ['ソフトバンク', '51', 'ロッテ', '27日', 'ペイペイドーム', 'ソフトバンク', 'は', '優勝']
# [393] ANA コロナ後にらみ雇用維持 経済 ['ANAホールディングス', 'HD', 'が', '27日', 'に', '事業', '構造改革', 'で']
# [394] トランプ氏 本当に負けるのか 国際 ['1週間', '後', 'に', '控える', '米大統領選', 'で', '再選', 'を']
# [395] コロチキ西野 第1子男児誕生 エンタメ ['お笑いコンビ', 'コロコロチキチキペッパーズ', 'の', '西野創人', '29', 'が', '27日', '自身']
# [396] 中国 35年にガソリン車全廃へ 国際 ['中国工業', '情報化', '省', 'など', 'は', '27日', '2035年', 'に']
# [397] SBがV奪回 裏に「老将の知」 スポーツ ['ソフトバンク', '51', 'ロッテ', '27日', 'ペイペイドーム', 'ソフトバンク', 'が', '27日']
# [398] 「17連休」要請 西村氏が否定 国内 ['西村康稔', '経済', '再生', '担当相', 'は', '27日', 'の', '記者会見']
# [399] 河井案里被告を保釈 国内 ['昨年7月', 'の', '参院選', '広島選挙区', 'を', '巡る', '大規模', '買収']
# [400] ソフトバンク3年ぶり優勝 スポーツ ['ソフトバンク', '51', 'ロッテ', '27日', 'ペイペイドーム', 'パリーグ', '優勝', 'へ']
# [401] 座間事件 2つのアカ使い接触 国内 ['All', 'Nippon', 'NewsNetworkANN', 'ツイッター', 'で', '異なる', 'キャラクター', 'を']
# [402] ロイヤルHD早期退職200人募集 経済 ['ロイヤルホールディングス', 'HD', '福岡市', 'は', '27日', '12月', '末', '時点']
# [403] 大阪 新たに142人の感染確認 地域 ['大阪府', 'は', '27日', '新た', 'に', '142人', 'の', '新型コロナウイルス']
# [404] 原子力規制委に不正アクセス 国内 ['原子力規制委員会', 'は', '27日', '全', '職員', 'が', '利用', 'する']
# [405] 発言物議 デヴィ夫人は反論 国内 ['デヴィ夫人', 'こと', 'タレント', 'の', 'デヴィスカルノ', 'さん', 'が', '不妊']
# [406] KDDI 20ギガ4千円弱で調整 経済 ['KDDI', 'が', '携帯電話', 'の', '料金', '体系', 'を', '見直し']
# [407] 日立金属 3200人リストラへ 経済 ['日立製作所', 'の', '上場', '子会社', 'の', '日立金属', 'は', '27日']
# [408] 西武1位 爆笑会見の裏明かす スポーツ ['西武', 'から', 'ドラフト1位指名', 'さ', 'れ', 'た', '桐蔭横浜大', '渡部']
# [409] 作家・大城立裕さん死去 95歳 地域 ['沖縄出身', '者', 'で', '初', 'の', '芥川賞', 'を', '受賞']
# [410] エコリカがキヤノンを提訴 国内 ['キヤノン', '東京', 'が', 'インクカートリッジ', 'の', '仕様', 'を', '変更']
# [411] GWまでGoToの継続を 公明提言 国内 ['Nippon', 'News', 'Network', 'NNN', '公明党', 'は', '菅総理', '大臣']
# [412] 克行被告の公判 11月4日再開 国内 ['昨年7月', 'の', '参院選', 'で', '公職選挙法違反', '加重', '買収', 'など']
# [413] 脱臼 首位打者DeNA佐野を抹消 スポーツ ['セリーグ', '首位打者', 'の', 'DeNA', '佐野恵太', '内野手', '25', 'が']
# [414] 米 対中関税巡りWTOに上訴 経済 ['ブルームバーグ', 'トランプ', '米', '政権', 'は', '26日', '中国', 'から']
# [415] 西武1位 会見で頭が真っ白 スポーツ ['西武', 'から', 'ドラフト1位指名', 'さ', 'れ', 'た', '桐蔭横浜大', '渡部']
# [416] LCC新ブランド立ち上げへ ANA 経済 ['エアージャパン', '活用', 'ANA', 'の', 'ボーイング787', '型', '機', 'を']
# [417] 手越祐也 独立で「やりがい」 エンタメ ['手越', 'さん', 'の', '新居', 'は', '築', '年数', 'こそ']
# [418] 親子2人切られ父死亡 男逮捕 国内 ['27日', '午前8時', '前', '茨城県常陸太田市町屋町', 'の', '根本', '昇', 'さん']
# [419] 露の下院議員91人感染1人死亡 国際 ['モスクワ', '田村', '雄', 'ロシア', '議会', '下院', 'の', 'ビャチェスラフウォロジン']
# [420] 古坂大魔王 第2子女児誕生 エンタメ ['ピコ太郎', 'の', '“', 'プロデューサー', '”', 'こと', 'お笑いタレント', '古坂大魔王']
# [421] ギャグ打撃 ダチョウ久々キス エンタメ ['お笑いトリオ', 'ダチョウ倶楽部', 'が', '27日', '都内', 'で', '行わ', 'れ']
# [422] ANA 5100億円の赤字見通し 経済 ['ANAホールディングス', 'HD', 'は', '27日', '未定', 'と', 'し', 'て']
# [423] 東京都 新たに158人感染確認 国内 ['東京都', 'に', 'よる', 'と', '27日', 'に', '都', 'が']
# [424] ダチョウ倶楽部 久々のキス芸 エンタメ ['お笑いトリオ', 'ダチョウ倶楽部', 'が', '27日', '都内', 'で', '行わ', 'れ']
# [425] 血の入れ替え G最多19人指名 スポーツ ['プロ野球ドラフト会議', 'supported', 'by', 'リポビタンD', 'が', '26日', '都内', 'の']
# [426] 巨人メルセデス手術 今季絶望 スポーツ ['巨人', 'の', 'クリストファークリソストモメルセデス', '投手', '26', 'が', '左肘', 'の']
# [427] JAL 再上場後初の赤字見通し 経済 ['日本航空', 'JAL', 'の', '2021年', '3月', '期', '連結決算', 'の']
# [428] 携帯値下げへ3つの柱 総務省 経済 ['CopyrightC', 'Japan', 'News', 'Network', 'All', 'rights', 'reserved', '菅政権']
# [429] 漫才初 西川きよし文化功労者 エンタメ ['お笑いタレント', 'の', '西川きよし', '74', 'が', '27日', 'に', '政府']
# [430] 出産一時金 引き上げ含め検討 国内 ['田村憲久', '厚生労働相', 'は', '27日', 'の', '記者会見', 'で', '出産']
# [431] 野口さん搭乗 11月15日宇宙へ 科学 ['NASA', 'アメリカ航空宇宙局', 'は', '日本人宇宙飛行士', '野口聡一', 'さん', 'が', '搭乗']
# [432] 盗撮被害 女子選手が語る苦悩 国内 ['競技会', 'で', '女子', 'アスリート', 'の', 'パフォーマンス', 'を', '撮影']
# [433] 煉獄ファン「300億円の男に」 エンタメ ['興行収入', '107', '億', '円', 'を', '突破', 'し', 'た']
# [434] 再審無罪 女性に補償5997万円 国内 ['12', '滋賀県東近江市', 'の', '湖東', '記念病院', 'で', '2003年', 'に']
# [435] 判事承認 トランプ氏は自賛 国際 ['Nippon', 'News', 'Network', 'NNN', 'アメリカ大統領選挙', 'が', '1週間', '後']
# [436] 米大統領選 期日前6000万人に 経済 ['ワシントン', '26日', 'ロイター', '米', 'フロリダ大学', 'の', '米', '選挙']
# [437] 橋田寿賀子氏ら5人に文化勲章 ライフ ['12', '政府', 'は', '27日', '2020年度', 'の', '文化勲章', 'を']
# [438] 都構想 隣接2市も特別区移行? 国内 ['12', '大阪都構想', 'の', '住民投票', '11月1日', '投開票', 'の', '手続き']
# [439] 冬休み一律延長求めず 文科相 国内 ['萩生田光一', '文部科学相', 'は', '27日', 'の', '閣議後', '記者会見', 'で']
# [440] かつや好調 裏に高いシェア? 経済 ['飲食店', 'コンサルタント', 'の', '三ツ井', '創太郎', 'です', 'Go', 'To']
# [441] R・ナダル プロゴルフ大会6位 スポーツ ['AFP', '時事', '男子テニス', '世界ランク', '2位', 'の', 'ラファエルナダル', 'Rafael']
# [442] 逃げた警察犬を無事保護 兵庫 国内 ['兵庫県福崎町田口', 'の', '山中', 'で', '行方不明者', 'の', '捜索', '中']
# [443] 任命拒否想定せず 04年資料に 国内 ['日本学術会議', 'の', '任命', '拒否', '問題', 'を', '巡り', '推薦']
# [444] ネット中傷 裁判手続き創設へ 国内 ['総務省', 'は', '26日', 'インターネット上', 'で', '誹謗中傷', 'を', '受け']
# [445] 潜水漁業中2人溺れ死亡 沖縄 国内 ['26日', '午後10時', '40分', 'ごろ', '沖縄県糸満市', 'の', '喜屋武岬', 'の']
# [446] 河井案里被告の保釈認める 国内 ['昨年7月', 'の', '参院選', 'を', 'めぐり', '公職選挙法違反', '買収', 'の']
# [447] 所信表明「処理水」は触れず 国内 ['菅義偉', '首相', 'は', '26日', 'の', '所信表明演説', 'で', '福島']
# [448] 首相のガスゼロ宣言 国連評価 国際 ['ニューヨーク', 'ブリュッセル', '共同', 'グテレス', '国連事務総長', 'は', '26日', '菅義偉']
# [449] 保守派の米最高裁判事を承認 国際 ['米上院', '定数', '100', 'は', '26日', 'の', '本会議', 'で']
# [450] 目黒 強盗疑いで少年3人逮捕 国内 ['Nippon', 'News', 'Network', 'NNN', '26日', '東京目黒区', 'の', 'タワーマンション']
# [451] 沢村にMLB複数球団が興味か スポーツ ['ロッテ', '沢村拓一', '投手', '32', 'に', '複数', 'の', 'メジャー']
# [452] フィギュア今季GP 得点非公認 スポーツ ['ジュネーブ', '共同', '国際スケート連盟', 'ISU', 'の', '広報担当者', 'は', '26日']
# [453] 消える日立マーク 市民寂しさ 地域 ['日立製作所', '創業', 'の', '地', '日立市内', 'から', '日立', 'を']
# [454] 京都高島屋「くぼ地」店に幕 地域 ['12', '京都市', '下京区', '四条通', '河原町', 'に', 'ある', '京都']
# [455] 栃木知事選「魅力度」争点に 国内 ['今年', 'の', '都道府県', '魅力', '度', 'ランキング', 'で', '初めて']
# [456] EU ナイジェリアWTO候補支持 国際 ['ブリュッセル', '26日', 'ロイター', '欧州連合', 'EU', 'の', '当局者', 'は']
# [457] 政府 デジタル庁恒久化の方針 国内 ['政府', 'は', '来年', '中', 'の', '創設', 'を', 'めざす']
# [458] 製油所12カ所 耐震不足の恐れ 国内 ['南海トラフ地震', 'や', '首都直下地震', 'が', '起き', 'て', 'も', '石油']
# [459] 月の水 想定より大量に存在か 科学 ['AFP', '時事', '月面', 'に', 'は', 'これ', 'まで', '考え']
# [460] トランプ氏 南部州死守の重圧 国際 ['ワシントン', '時事', '来月3日', 'の', '米大統領選', 'まで', '27日', 'で']
# [461] 日産、中国の生産能力3割増へ 経済 ['日産自動車', 'が', '2021年', '中', 'に', '中国', 'で', 'の']
# [462] 乃木坂樋口 役作り30cm髪切る エンタメ ['人気', 'アイドルグループ', '乃木坂46', 'の', '樋口日奈', 'が', '2021年', '新春']
# [463] 広瀬すず「戦後初のCA」役に エンタメ ['広瀬すず', 'が', '2021年', '春', '放送', 'の', 'スペシャルドラマ', 'エア']
# [464] 指名漏れ妥当? 田沢に残る3択 スポーツ ['2020', 'ドラフト会議', '元', 'メジャー', '世界一', '右腕', 'を', '待ち受け']
# [465] Zeebra、家族と別居報道 エンタメ ['自分', 'の', '不甲斐ない', '行い', 'により', '大切', 'な', '家族']
# [466] NYダウ大幅続落 650ドル安 経済 ['ニューヨーク', '共同', '週明け', '26日', 'の', 'ニューヨーク株式市場', 'の', 'ダウ工業株30種平均']
# [467] ももクロ高城 阪神D1にエール エンタメ ['阪神', 'が', 'ドラフト1位', 'で', '交渉', '権', 'を', '獲得']
# [468] アント 史上最高額で上場へ 経済 ['上海', '共同', '中国', 'の', '電子商取引', '最大手', 'アリババグループ', '傘下']
# [469] 所信表明 言い間違い6カ所 国内 ['菅義偉', '首相', 'が', '26日', 'の', '所信表明演説', 'で', '新型コロナウイルス']

# %%
# 6は太宰治の「人間失格」です。
# 自分の人生に迷いながら苦悩するみたいな話だったはず。
# 最後は精神病院送りにされて、、重苦しいまま終わる感じだった。
ranking1 = model1.docvecs.most_similar(15, topn=50)

# %%
ranking1[:5] # コサイン類似度が大きい作品トップ5
# Out:
# [(291, 0.999182939529419),
#  (50, 0.9991813898086548),
#  (351, 0.9991661310195923),
#  (440, 0.9991401433944702),
#  (307, 0.9991275668144226)]

# %%
# sentencesの中身を確認
for i, sentence in enumerate(sentences):
    if i < 5:
        print(sentence[:10])
# Out:
# ['中京テレビ', 'NEWS', '愛知県', 'で', '新型コロナウイルス', 'の', '感染者', 'が', '再び', '急増']
# ['フィギュアスケート', '女子', 'の', '紀平梨花', 'が', '11月1日', '付け', 'で', 'トヨタ自動車', 'に']
# ['関西テレビ', '大阪市', 'を', '廃止', 'し', '4つ', 'の', '特別区', 'に', '再編']
# ['イギリス王室', 'の', 'ケンブリッジ公爵', 'ウィリアム王子', '38', 'が', '今年4月', 'に', '新型コロナウイルス', 'に']
# ['10月16日', 'に', '公開', 'さ', 'れ', 'た', 'アニメ映画', '劇場版', '鬼滅の刃', '無限']

# %%
sorted_texts_tfidf = sortedTFIDF(sentences)

# %%
# 作品ごとにTF-IDFの高い単語を確認
for i, tfidf in enumerate(sorted_texts_tfidf):
    if i < 5:
        print('%s.' % i, '〜%s〜' % df['title'][i]) # 一応タイトルも表示
        pprint(tfidf[:10])
        print('')
# Out:
# 0. 〜第3波か 愛知県知事が危機感〜
# [[0.29528257273473774, '大村'],
#  [0.29528257273473774, '中京テレビ'],
#  [0.29528257273473774, 'NEWS'],
#  [0.270303808686991, '知事'],
#  [0.24255786013424685, '愛知県'],
#  [0.18020253912466067, '受け止め'],
#  [0.15656755760560231, '感染者'],
#  [0.14764128636736887, '豊橋市'],
#  [0.14764128636736887, '犬山市'],
#  [0.14764128636736887, '大村秀章']]
#
# 1. 〜紀平梨花 トヨタ自動車に入社〜
# [[0.29338687025985244, 'トヨタ自動車'],
#  [0.2860640414876848, 'トヨタ'],
#  [0.25383698179639624, 'フィギュアスケート'],
#  [0.22160992210510766, 'いただける'],
#  [0.16336418714861306, 'とても'],
#  [0.1467810067922927, '所属'],
#  [0.1430320207438424, '長野五輪'],
#  [0.1430320207438424, '紀平梨花'],
#  [0.1430320207438424, '紀平'],
#  [0.1430320207438424, '精一杯']]
#
# 2. 〜否決で今後の大阪は 市民の声〜
# [[0.29922280946736857, '大阪市民'],
#  [0.25458232022231747, '大阪市役所'],
#  [0.23345245298685652, '職員'],
#  [0.19628266409041234, '大阪'],
#  [0.18993894499709374, '否決'],
#  [0.16972154681487833, '一夜'],
#  [0.15711689667261067, '明け'],
#  [0.14817375507313707, '半分'],
#  [0.14817375507313707, '任期'],
#  [0.14123691552868867, '政治家']]
#
# 3. 〜ウィリアム王子4月に陽性判定〜
# [[0.5136250782558011, '王子'],
#  [0.2848510751328632, '王室'],
#  [0.25681253912790053, 'ウィリアム王子'],
#  [0.2036191283774135, '感染'],
#  [0.14921188581351036, 'BBC'],
#  [0.1422264455815207, '判定'],
#  [0.13169328571739466, '陽性'],
#  [0.12840626956395026, 'チャールズ皇太子'],
#  [0.12840626956395026, 'ケンブリッジ公爵'],
#  [0.10547845639787384, '新型']]
#
# 4. 〜鬼滅の刃 歴代興収が10位に〜
# [[0.3462202717689082, '興行収入'],
#  [0.3356279444688104, '億'],
#  [0.24332928597755482, '円'],
#  [0.21731001025243143, '公開'],
#  [0.20773216306134493, '鬼'],
#  [0.1794534139386184, '動員'],
#  [0.1731101358844541, '無限'],
#  [0.16761533849967242, '列車'],
#  [0.1495647355860781, '炭'],
#  [0.12674641105489148, '鬼滅の刃']]

# %%
all_title = []
for tfidf in sorted_texts_tfidf:
    title = []
    for word in tfidf[:100]: # 100語に絞る
        title.append(word[1])
    all_title.append(title)

# %%
# all_titleリストの中身を確認
for i, text in enumerate(all_title):
    if i < 5:
        print(i, text[:10])
# Out:
# 0 ['大村', '中京テレビ', 'NEWS', '知事', '愛知県', '受け止め', '感染者', '豊橋市', '犬山市', '大村秀章']
# 1 ['トヨタ自動車', 'トヨタ', 'フィギュアスケート', 'いただける', 'とても', '所属', '長野五輪', '紀平梨花', '紀平', '精一杯']
# 2 ['大阪市民', '大阪市役所', '職員', '大阪', '否決', '一夜', '明け', '半分', '任期', '政治家']
# 3 ['王子', '王室', 'ウィリアム王子', '感染', 'BBC', '判定', '陽性', 'チャールズ皇太子', 'ケンブリッジ公爵', '新型']
# 4 ['興行収入', '億', '円', '公開', '鬼', '動員', '無限', '列車', '炭', '鬼滅の刃']
